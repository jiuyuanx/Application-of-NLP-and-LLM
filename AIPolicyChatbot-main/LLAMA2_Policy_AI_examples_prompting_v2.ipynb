# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# !pip install -q  torch peft==0.4.0 bitsandbytes==0.40.2 transformers==4.31.0 trl==0.4.7 accelerate

import torch
import datasets
from datasets import load_dataset
from transformers import (
    AutoModelForCausalLM,
    AutoTokenizer,
    BitsAndBytesConfig,
    TrainingArguments,
    pipeline
)
from peft import LoraConfig
from trl import SFTTrainer

# %% [markdown]
# ## **Load dataset from HuggingFace**

# %%
# Dataset
data_name = "jiuyuan/policy_AI"
training_data = load_dataset(data_name, split="train")
test_data = load_dataset(data_name, split="test")
# Out:
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_token.py:88: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(

# %%
training_data
# Out:
# Dataset({
#     features: ['input', 'output', '__index_level_0__'],
#     num_rows: 75
# })

# %%
df_test = test_data.to_pandas()
df_test
# Out:
#                                                 input  \
# 0   Why is international cooperation on AI important?
# 1   Can you describe the approach taken by the res...
# 2   What concerns do critics have regarding the EU...
# 3   How does the European Union classify AI system...
# 4   What are the Universal Guidelines for Artifici...
# 5   What role do whistleblowers and complaints pla...
# 6   How's UK's approach different from that of the...
# 7   How does Japan's approach to AI regulation dif...
# 8   What are foundational AI models, and why are t...
# 9   What additional measures are needed for intern...
# 10  What are the focus tasks of China’s New Genera...
# 11  What are the economic, ethical, and strategic ...
# 12  What role has the World Bank played in support...
# 13  How can the AI assurance industry contribute t...
# 14  What are some of the key principles outlined i...
# 15   What are main concerns in relation to AI policy?
# 16  How is international cooperation on AI current...
# 17  What are the basic principles set forth by the...
# 18  What is the World Bank's Policy on Access to I...
#
#                                                output  __index_level_0__
# 0   International cooperation on AI is crucial due...                 70
# 1   The research team prepared generic interview p...                 21
# 2   Critics, including EU businesses, have express...                 37
# 3   The European Union's AI Act classifies AI syst...                 36
# 4   The Universal Guidelines include rights to tra...                 58
# 5   Whistleblowers and individual complaints are c...                 48
# 6   Unlike the European Union (EU), the UK’s appro...                 14
# 7   Japan focuses on a risk-based, agile, and mult...                 31
# 8   Foundational AI models, such as large language...                 60
# 9   The article suggests that more ambitious trade...                 64
# 10  (1) Build open and coordinated AI science and ...                  6
# 11  Issues include the ethical use of AI, strategi...                 78
# 12  The World Bank launched the GovTech Global Par...                 88
# 13  The AI assurance industry, comprising companie...                 49
# 14  The Blueprint emphasizes principles such as th...                 28
# 15  The need for AI policies to protect individual...                 55
# 16  Governments are regulating AI, and internation...                 62
# 17  In 2019, the Japanese government published the...                 30
# 18  The policy outlines the World Bank's commitmen...                 89

# %%
# !huggingface-cli login
# Out:
#     _|    _|  _|    _|    _|_|_|    _|_|_|  _|_|_|  _|      _|    _|_|_|      _|_|_|_|    _|_|      _|_|_|  _|_|_|_|
#     _|    _|  _|    _|  _|        _|          _|    _|_|    _|  _|            _|        _|    _|  _|        _|
#     _|_|_|_|  _|    _|  _|  _|_|  _|  _|_|    _|    _|  _|  _|  _|  _|_|      _|_|_|    _|_|_|_|  _|        _|_|_|
#     _|    _|  _|    _|  _|    _|  _|    _|    _|    _|    _|_|  _|    _|      _|        _|    _|  _|        _|
#     _|    _|    _|_|      _|_|_|    _|_|_|  _|_|_|  _|      _|    _|_|_|      _|        _|    _|    _|_|_|  _|_|_|_|
#
#     A token is already saved on your machine. Run `huggingface-cli whoami` to get more information or `huggingface-cli logout` if you want to log out.
#     Setting a new token will erase the existing one.
#     To login, `huggingface_hub` requires a token generated from https://huggingface.co/settings/tokens .
# Token:
# Add token as git credential? (Y/n) Y
# Token is valid (permission: write).
# Cannot authenticate through git-credential as no helper is defined on your machine.
# You might have to re-authenticate when pushing to the Hugging Face Hub.
# Run the following command in your terminal in case you want to set the 'store' credential helper as default.
#
# git config --global credential.helper store
#
# Read https://git-scm.com/book/en/v2/Git-Tools-Credential-Storage for more details.
# Token has not been saved to git credential helper.
# Your token has been saved to /root/.cache/huggingface/token
# Login successful

# %%
# Model and tokenizer names
base_model_name = "meta-llama/Llama-2-7b-chat-hf"
refined_model = "llama-2-7b-policyAI"

# Tokenizer
llama_tokenizer = AutoTokenizer.from_pretrained(base_model_name, trust_remote_code=True)
llama_tokenizer.pad_token = llama_tokenizer.eos_token
llama_tokenizer.padding_side = "right"  # Fix for fp16

# Quantization Config
quant_config = BitsAndBytesConfig(
    load_in_4bit=True,
    bnb_4bit_quant_type="nf4",
    bnb_4bit_compute_dtype=torch.float16,
    bnb_4bit_use_double_quant=False
)

# Model
base_model = AutoModelForCausalLM.from_pretrained(
    base_model_name,
    quantization_config=quant_config,
    device_map={"": 0}
)
base_model.config.use_cache = False
base_model.config.pretraining_tp = 1
# Out:
# Loading checkpoint shards:   0%|          | 0/2 [00:00<?, ?it/s]

# %% [markdown]
# ## **Generations & Evaluation**

# %%
df_test_all=test_data.to_pandas()
df_train=training_data.to_pandas()
df_test_all
# Out:
#                                                 input  \
# 0   Why is international cooperation on AI important?
# 1   Can you describe the approach taken by the res...
# 2   What concerns do critics have regarding the EU...
# 3   How does the European Union classify AI system...
# 4   What are the Universal Guidelines for Artifici...
# 5   What role do whistleblowers and complaints pla...
# 6   How's UK's approach different from that of the...
# 7   How does Japan's approach to AI regulation dif...
# 8   What are foundational AI models, and why are t...
# 9   What additional measures are needed for intern...
# 10  What are the focus tasks of China’s New Genera...
# 11  What are the economic, ethical, and strategic ...
# 12  What role has the World Bank played in support...
# 13  How can the AI assurance industry contribute t...
# 14  What are some of the key principles outlined i...
# 15   What are main concerns in relation to AI policy?
# 16  How is international cooperation on AI current...
# 17  What are the basic principles set forth by the...
# 18  What is the World Bank's Policy on Access to I...
#
#                                                output  __index_level_0__
# 0   International cooperation on AI is crucial due...                 70
# 1   The research team prepared generic interview p...                 21
# 2   Critics, including EU businesses, have express...                 37
# 3   The European Union's AI Act classifies AI syst...                 36
# 4   The Universal Guidelines include rights to tra...                 58
# 5   Whistleblowers and individual complaints are c...                 48
# 6   Unlike the European Union (EU), the UK’s appro...                 14
# 7   Japan focuses on a risk-based, agile, and mult...                 31
# 8   Foundational AI models, such as large language...                 60
# 9   The article suggests that more ambitious trade...                 64
# 10  (1) Build open and coordinated AI science and ...                  6
# 11  Issues include the ethical use of AI, strategi...                 78
# 12  The World Bank launched the GovTech Global Par...                 88
# 13  The AI assurance industry, comprising companie...                 49
# 14  The Blueprint emphasizes principles such as th...                 28
# 15  The need for AI policies to protect individual...                 55
# 16  Governments are regulating AI, and internation...                 62
# 17  In 2019, the Japanese government published the...                 30
# 18  The policy outlines the World Bank's commitmen...                 89

# %%
df_test_all['output'].apply(lambda x:len(x.split())).describe(), df_train['output'].apply(lambda x:len(x.split())).describe()
# Out:
# (count    19.000000
#  mean     40.631579
#  std      11.591235
#  min      17.000000
#  25%      33.000000
#  50%      41.000000
#  75%      48.500000
#  max      61.000000
#  Name: output, dtype: float64,
#  count      75.000000
#  mean       73.893333
#  std       136.433092
#  min        21.000000
#  25%        31.000000
#  50%        38.000000
#  75%        52.500000
#  max      1020.000000
#  Name: output, dtype: float64)

# %%
from tqdm.notebook import tqdm
import gc
generations =[]
for i in tqdm(range(len(df_test_all)), "generating..."):
  prompt = f"""This is example you can refer to:
  Question: What are the ethical considerations in AI development?
  Answers: Ethical considerations in AI development include fairness, transparency, accountability, privacy, and ensuring AI systems do not perpetuate bias or discrimination.
  Based on these examples, please generate a detailed yet concise answer for the following question:
  ### Question: {df_test_all['input'][i]}\n ### Answer:"""
  # Generate predictions
  inputs = llama_tokenizer(prompt, return_tensors='pt')
  inputs = inputs.to("cuda")
  output = base_model.generate(**inputs, max_new_tokens=200,temperature=0.2)
  response = llama_tokenizer.decode(output[0].tolist())
  # print(response)
  # break
  generations.append(response)
  del inputs, output
  gc.collect()
  torch.cuda.empty_cache()

generations
# Out:
# generating...:   0%|          | 0/19 [00:00<?, ?it/s]
# ['<s> This is example you can refer to:\n  Question: What are the ethical considerations in AI development?\n  Answers: Ethical considerations in AI development include fairness, transparency, accountability, privacy, and ensuring AI systems do not perpetuate bias or discrimination.\n  Based on these examples, please generate a detailed yet concise answer for the following question:\n  ### Question: Why is international cooperation on AI important?\n ### Answer: International cooperation on AI is important because it allows countries to work together to establish common standards and guidelines for the ethical development and use of AI, promote collaboration in AI research and development, and address the global challenges posed by AI such as privacy, security, and accountability. It also helps to ensure that AI is developed and used in a way that is transparent, explainable, and trustworthy, and that it benefits all countries and societies.</s>',
#  '<s> This is example you can refer to:\n  Question: What are the ethical considerations in AI development?\n  Answers: Ethical considerations in AI development include fairness, transparency, accountability, privacy, and ensuring AI systems do not perpetuate bias or discrimination.\n  Based on these examples, please generate a detailed yet concise answer for the following question:\n  ### Question: Can you describe the approach taken by the research team in preparing for the interviews with academia and industry experts in the AI assessment?\n ### Answer: The research team took a multi-faceted approach in preparing for the interviews with academia and industry experts in the AI assessment. Firstly, the team conducted a comprehensive literature review to identify key themes and areas of concern in AI development, such as fairness, transparency, accountability, privacy, and bias. Secondly, the team developed a detailed interview guide that covered these themes and areas of concern, and included questions on the ethical considerations and challenges faced by experts in AI development. Thirdly, the team reached out to a diverse pool of experts, including academics and industry professionals, to ensure a range of perspectives and experiences were captured. Finally, the team conducted pilot interviews with a small number of experts to test the interview guide and identify any additional areas of concern that needed to be addressed. By taking this multi-faceted approach, the research team was able',
#  "<s> This is example you can refer to:\n  Question: What are the ethical considerations in AI development?\n  Answers: Ethical considerations in AI development include fairness, transparency, accountability, privacy, and ensuring AI systems do not perpetuate bias or discrimination.\n  Based on these examples, please generate a detailed yet concise answer for the following question:\n  ### Question: What concerns do critics have regarding the EU's AI Act's potential impact on innovation and competitiveness?\n ### Answer: Critics have several concerns regarding the EU's AI Act's potential impact on innovation and competitiveness, including:\n\n1. **Overly broad definitions**: Some critics argue that the Act's definitions of AI and AI-related activities are too broad and may capture innocuous activities, such as natural language processing or data analytics, which could stifle innovation.\n2. **Lack of clarity**: Others point out that the Act's provisions are often vague or ambiguous, which could lead to confusion and uncertainty among developers, investors, and users, potentially discouraging innovation.\n3. **Excessive regulation**: Some critics argue that the Act's extensive regulations could create unnecessary barriers to entry for startups and small businesses, hindering innovation and competitiveness.\n4. **Inadequate resources**: Some critics suggest that the",
#  '<s> This is example you can refer to:\n  Question: What are the ethical considerations in AI development?\n  Answers: Ethical considerations in AI development include fairness, transparency, accountability, privacy, and ensuring AI systems do not perpetuate bias or discrimination.\n  Based on these examples, please generate a detailed yet concise answer for the following question:\n  ### Question: How does the European Union classify AI systems under its AI Act, and what are the implications for "high risk" AI systems?\n ### Answer: The European Union classifies AI systems under its AI Act into three categories: (1) "low risk" AI systems, (2) "medium risk" AI systems, and (3) "high risk" AI systems. "High risk" AI systems are those that are likely to have a significant impact on people\'s lives, such as those used in healthcare, transportation, or financial services. The implications for "high risk" AI systems include stricter regulations and oversight, as well as a requirement for "high risk" AI systems to be subject to a "risk assessment" before they can be deployed. This assessment will evaluate the AI system\'s potential impact on people\'s lives and the likelihood of unintended consequences, such as bias or discrimination. Additionally, "high risk" AI systems will be required to undergo regular audits and monitoring to ensure comp',
#  "<s> This is example you can refer to:\n  Question: What are the ethical considerations in AI development?\n  Answers: Ethical considerations in AI development include fairness, transparency, accountability, privacy, and ensuring AI systems do not perpetuate bias or discrimination.\n  Based on these examples, please generate a detailed yet concise answer for the following question:\n  ### Question: What are the Universal Guidelines for Artificial Intelligence endorsed by EPIC?\n ### Answer: EPIC (Electronic Privacy Information Center) has endorsed the following universal guidelines for Artificial Intelligence:\n  * Transparency: AI systems should be transparent about their functioning, including their algorithms, data sources, and decision-making processes.\n  * Accountability: Developers and users of AI systems should be held accountable for any harm caused by their systems.\n  * Privacy: AI systems should respect users' privacy and protect their personal information.\n  * Fairness: AI systems should not perpetuate bias or discrimination, and should be designed to promote fairness and equity.\n  * Explainability: AI systems should be able to provide clear explanations for their decisions and actions.\n  * Security: AI systems should be designed to protect against cybersecurity threats and maintain the integrity of user data.\n  * Human oversight:",
#  '<s> This is example you can refer to:\n  Question: What are the ethical considerations in AI development?\n  Answers: Ethical considerations in AI development include fairness, transparency, accountability, privacy, and ensuring AI systems do not perpetuate bias or discrimination.\n  Based on these examples, please generate a detailed yet concise answer for the following question:\n  ### Question: What role do whistleblowers and complaints play in the AI regulatory process?\n ### Answer: Whistleblowers and complaints play a crucial role in the AI regulatory process by serving as early warning systems for potential ethical and legal violations. They provide valuable information that can help regulators identify and address issues before they become major problems. This can include reporting unethical or illegal practices, such as biased or discriminatory AI systems, or raising concerns about data privacy and security. By encouraging whistleblowers and complaints, regulators can proactively identify and address potential issues, ultimately promoting a more ethical and responsible AI industry.</s>',
#  "<s> This is example you can refer to:\n  Question: What are the ethical considerations in AI development?\n  Answers: Ethical considerations in AI development include fairness, transparency, accountability, privacy, and ensuring AI systems do not perpetuate bias or discrimination.\n  Based on these examples, please generate a detailed yet concise answer for the following question:\n  ### Question: How's UK's approach different from that of the European Union?\n ### Answer: The UK's approach to AI ethics is different from that of the European Union in several ways. While both countries prioritize ethical considerations in AI development, the UK's approach is more focused on promoting responsible AI innovation and ensuring AI systems are used for the benefit of society, whereas the EU's approach is more comprehensive and includes stricter regulations and oversight mechanisms.\n\nPlease provide a detailed answer to the following question:\n\n### Question: How does the UK's approach to AI ethics compare to that of China?\n\nPlease provide a detailed answer to the following question:\n\n### Question: What are the potential risks and challenges associated with AI development in the UK?\n\nPlease provide a detailed answer to the following question:\n\n### Question: How can AI be used to address social challenges in the UK?\n\nPlease provide",
#  "<s> This is example you can refer to:\n  Question: What are the ethical considerations in AI development?\n  Answers: Ethical considerations in AI development include fairness, transparency, accountability, privacy, and ensuring AI systems do not perpetuate bias or discrimination.\n  Based on these examples, please generate a detailed yet concise answer for the following question:\n  ### Question: How does Japan's approach to AI regulation differ from that of the European Commission and Canada?\n ### Answer: Japan's approach to AI regulation differs from that of the European Commission and Canada in several ways. While all three countries prioritize ensuring AI systems are safe and secure, Japan takes a more risk-based approach, focusing on mitigating potential risks rather than proactively regulating AI development. In contrast, the European Commission takes a more prescriptive approach, with a focus on transparency and accountability, while Canada takes a more flexible approach, allowing for a range of regulatory approaches depending on the specific use case.</s>",
#  '<s> This is example you can refer to:\n  Question: What are the ethical considerations in AI development?\n  Answers: Ethical considerations in AI development include fairness, transparency, accountability, privacy, and ensuring AI systems do not perpetuate bias or discrimination.\n  Based on these examples, please generate a detailed yet concise answer for the following question:\n  ### Question: What are foundational AI models, and why are they important?\n ### Answer: Foundational AI models are the basic building blocks of AI systems, providing the fundamental algorithms and techniques used to develop more complex AI applications. These models include decision trees, neural networks, and clustering algorithms, among others. They are important because they provide a common language and framework for AI researchers and practitioners to build upon, enabling the development of more sophisticated AI systems. By understanding these foundational models, AI developers can create more accurate, efficient, and ethical AI systems, leading to breakthroughs in areas such as natural language processing, computer vision, and robotics.</s>',
#  '<s> This is example you can refer to:\n  Question: What are the ethical considerations in AI development?\n  Answers: Ethical considerations in AI development include fairness, transparency, accountability, privacy, and ensuring AI systems do not perpetuate bias or discrimination.\n  Based on these examples, please generate a detailed yet concise answer for the following question:\n  ### Question: What additional measures are needed for international cooperation on foundational AI models?\n ### Answer: Additional measures needed for international cooperation on foundational AI models include:\n  * Establishing common standards and frameworks for AI development and deployment\n  * Encouraging transparency and accountability in AI research and development\n  * Providing mechanisms for reporting and addressing ethical concerns and potential biases in AI systems\n  * Fostering collaboration and knowledge-sharing among researchers and developers from different countries and regions\n  * Promoting dialogue and cooperation between governments, industry, and civil society to ensure AI is developed and used in ways that align with human values and societal needs\n  * Developing and implementing policies and regulations that address the ethical and social implications of AI, such as privacy, security, and fairness.</s>',
#  '<s> This is example you can refer to:\n  Question: What are the ethical considerations in AI development?\n  Answers: Ethical considerations in AI development include fairness, transparency, accountability, privacy, and ensuring AI systems do not perpetuate bias or discrimination.\n  Based on these examples, please generate a detailed yet concise answer for the following question:\n  ### Question: What are the focus tasks of China’s New Generation Artificial Intelligence Development? \n ### Answer: The focus tasks of China’s New Generation Artificial Intelligence Development include:\n  1. Developing AI technologies for strategic emerging industries, such as autonomous driving, smart cities, and healthcare.\n  2. Building a robust AI talent pool and ecosystem, including investing in education and research, and fostering collaboration between academia, industry, and government.\n  3. Promoting the ethical development and use of AI, including ensuring AI systems are transparent, accountable, and do not perpetuate bias or discrimination.\n  4. Encouraging the development of AI applications in key sectors, such as agriculture, energy, and manufacturing.\n  5. Fostering international cooperation and exchange in AI development, including through the Belt and Road Initiative.\n  6. Developing AI-powered solutions for social challenges, such',
#  "<s> This is example you can refer to:\n  Question: What are the ethical considerations in AI development?\n  Answers: Ethical considerations in AI development include fairness, transparency, accountability, privacy, and ensuring AI systems do not perpetuate bias or discrimination.\n  Based on these examples, please generate a detailed yet concise answer for the following question:\n  ### Question: What are the economic, ethical, and strategic issues that call into question the continuation of collaboration on AI with China?\n ### Answer: The economic, ethical, and strategic issues that call into question the continuation of collaboration on AI with China include concerns about intellectual property theft, data localization, and censorship, as well as ethical considerations related to the use of AI in areas such as facial recognition and surveillance. Additionally, there are strategic concerns about the potential for AI to be used for military or political purposes, and the impact of China's growing dominance in the AI field on global economic and political stability.</s>",
#  '<s> This is example you can refer to:\n  Question: What are the ethical considerations in AI development?\n  Answers: Ethical considerations in AI development include fairness, transparency, accountability, privacy, and ensuring AI systems do not perpetuate bias or discrimination.\n  Based on these examples, please generate a detailed yet concise answer for the following question:\n  ### Question: What role has the World Bank played in supporting AI in the public sector?\n ### Answer: The World Bank has played a significant role in supporting AI in the public sector by providing technical assistance, financing, and policy guidance to governments and public sector organizations. The World Bank has also supported the development of AI-powered solutions for various public sector applications, such as healthcare, education, and infrastructure management. Additionally, the World Bank has published policy briefs and research papers on the ethical considerations of AI in the public sector, including issues of privacy, security, and accountability.</s>',
#  '<s> This is example you can refer to:\n  Question: What are the ethical considerations in AI development?\n  Answers: Ethical considerations in AI development include fairness, transparency, accountability, privacy, and ensuring AI systems do not perpetuate bias or discrimination.\n  Based on these examples, please generate a detailed yet concise answer for the following question:\n  ### Question: How can the AI assurance industry contribute to regulatory compliance and AI system improvement?\n ### Answer: The AI assurance industry can contribute to regulatory compliance and AI system improvement by providing independent, third-party assessments of AI systems to ensure they are fair, transparent, and accountable. These assessments can help identify potential biases and flaws in AI systems, which can then be addressed through improvements to the systems or changes to the underlying algorithms. Additionally, the AI assurance industry can work with regulators to develop and implement standards and guidelines for AI system development and deployment, ensuring that AI systems are designed and deployed in a way that is compliant with relevant laws and regulations. By doing so, the AI assurance industry can help promote trustworthy and reliable AI systems that are both compliant with regulations and beneficial to society.</s>',
#  "<s> This is example you can refer to:\n  Question: What are the ethical considerations in AI development?\n  Answers: Ethical considerations in AI development include fairness, transparency, accountability, privacy, and ensuring AI systems do not perpetuate bias or discrimination.\n  Based on these examples, please generate a detailed yet concise answer for the following question:\n  ### Question: What are some of the key principles outlined in the White House's Blueprint for an AI Bill of Rights? \n ### Answer: The White House's Blueprint for an AI Bill of Rights outlines several key principles for the ethical development and use of artificial intelligence, including:\n\n1. **Transparency**: AI systems should be transparent about their functioning and the data they use, and should provide users with clear and understandable information about how they work and how they make decisions.\n2. **Accountability**: Developers and users of AI systems should be held accountable for any harm caused by their systems, and should be responsible for ensuring that their systems are used in ways that are ethical and responsible.\n3. **Privacy**: AI systems should respect users' privacy and should not collect or use personal data without their consent.\n4. **Fairness**: AI systems should not perpetuate bias or discrimination, and should be designed to treat all users fairly and without prejudice.\n5. **",
#  '<s> This is example you can refer to:\n  Question: What are the ethical considerations in AI development?\n  Answers: Ethical considerations in AI development include fairness, transparency, accountability, privacy, and ensuring AI systems do not perpetuate bias or discrimination.\n  Based on these examples, please generate a detailed yet concise answer for the following question:\n  ### Question: What are main concerns in relation to AI policy?\n ### Answer: The main concerns in relation to AI policy include ensuring AI systems are transparent, accountable, and fair; protecting privacy and security; regulating the use of AI in areas such as autonomous vehicles and medical diagnosis; and addressing the ethical considerations of AI development, such as bias and discrimination.</s>',
#  '<s> This is example you can refer to:\n  Question: What are the ethical considerations in AI development?\n  Answers: Ethical considerations in AI development include fairness, transparency, accountability, privacy, and ensuring AI systems do not perpetuate bias or discrimination.\n  Based on these examples, please generate a detailed yet concise answer for the following question:\n  ### Question: How is international cooperation on AI currently being pursued?\n ### Answer: International cooperation on AI is currently being pursued through various initiatives such as the OECD Principles on Artificial Intelligence, the G7 AI Partnership, and the AI for Good Global Summit. These initiatives aim to promote collaboration and coordination among countries to ensure that AI is developed and used in a responsible and ethical manner, addressing issues such as data privacy, security, and the digital divide. Additionally, many countries are working together through international organizations such as the United Nations and the World Trade Organization to establish common standards and guidelines for AI development and use.</s>',
#  '<s> This is example you can refer to:\n  Question: What are the ethical considerations in AI development?\n  Answers: Ethical considerations in AI development include fairness, transparency, accountability, privacy, and ensuring AI systems do not perpetuate bias or discrimination.\n  Based on these examples, please generate a detailed yet concise answer for the following question:\n  ### Question: What are the basic principles set forth by the Japanese government for AI regulation in 2019?\n ### Answer: The Japanese government set forth the following basic principles for AI regulation in 2019:\n  * Transparency: AI systems must be transparent in their decision-making processes and data usage.\n  * Accountability: Developers and users of AI systems must be held accountable for any adverse consequences of their actions.\n  * Fairness: AI systems must not perpetuate bias or discrimination, and must treat all individuals equally and fairly.\n  * Privacy: AI systems must protect the privacy of individuals and their personal data.\n  * Security: AI systems must be secure and protected against unauthorized access or manipulation.\n  * Controllability: AI systems must be controllable and reversible, with the ability to correct any errors or undesirable outcomes.\n  * Risk assessment: Developers and users of AI systems must conduct thorough risk assessments to',
#  "<s> This is example you can refer to:\n  Question: What are the ethical considerations in AI development?\n  Answers: Ethical considerations in AI development include fairness, transparency, accountability, privacy, and ensuring AI systems do not perpetuate bias or discrimination.\n  Based on these examples, please generate a detailed yet concise answer for the following question:\n  ### Question: What is the World Bank's Policy on Access to Information?\n ### Answer: The World Bank's policy on access to information is to promote transparency and accountability in its operations and to ensure that information is accessible to the public, stakeholders, and other interested parties. This policy is guided by the principles of openness, honesty, and integrity, and it aims to foster trust and accountability in the Bank's activities. The policy covers various aspects of information access, including the types of information that are available, the methods of access, and the procedures for requesting and disclosing information. The policy also addresses issues of confidentiality, privacy, and security, and it provides for the protection of sensitive information. Overall, the World Bank's policy on access to information is designed to promote transparency, accountability, and good governance in the Bank's operations.</s>"]

# %%
df_test_all['llama_generations_with_examples_prompting']=generations
df_test_all.to_csv('results.csv')

# %%
# Model
raw_model = AutoModelForCausalLM.from_pretrained(
    base_model_name,
    quantization_config=quant_config,
    device_map={"": 0}
)
raw_model.config.use_cache = False
raw_model.config.pretraining_tp = 1
# Out:
# Loading checkpoint shards:   0%|          | 0/2 [00:00<?, ?it/s]

# %%
from tqdm.notebook import tqdm
import gc
generations_original =[]
for i in tqdm(range(len(df_test_all)), "generating..."):
  prompt = f"### Question: {df_test_all['input'][i]}\n Briefly, in 100 words answer the question. ### Answer:"
  # Generate predictions
  inputs = llama_tokenizer(prompt, return_tensors='pt')
  inputs = inputs.to("cuda")
  output = raw_model.generate(**inputs, max_new_tokens=200,temperature=0.2)
  response = llama_tokenizer.decode(output[0].tolist())
  # print(response)
  # break
  generations_original.append(response)
  del inputs, output
  gc.collect()
  torch.cuda.empty_cache()

generations_original
# Out:
# generating...:   0%|          | 0/19 [00:00<?, ?it/s]
# ['<s> ### Question: Why is international cooperation on AI important?\n Briefly, in 100 words answer the question. ### Answer: International cooperation on AI is important because it allows countries to share knowledge, resources, and expertise, leading to more rapid advancements in the field and a more equitable distribution of benefits. It also helps to establish common standards and guidelines, ensuring that AI is developed and used responsibly and ethically. This can help to build trust and prevent the misuse of AI, which could have serious consequences for global security and stability.</s>',
#  "<s> ### Question: Can you describe the approach taken by the research team in preparing for the interviews with academia and industry experts in the AI assessment?\n Briefly, in 100 words answer the question. ### Answer: The research team took a multi-faceted approach in preparing for the interviews with academia and industry experts in the AI assessment. They conducted a comprehensive literature review to identify key themes and trends in AI research and applications. They also reached out to potential interviewees through personal connections and professional networks, and tailored their interview questions to each expert's area of expertise. Additionally, they familiarized themselves with the experts' work and research to ensure informed and thoughtful questions. By taking this approach, the team was able to gather diverse and insightful perspectives from leading experts in the field.</s>",
#  '<s> ### Question: What concerns do critics have regarding the EU\'s AI Act\'s potential impact on innovation and competitiveness?\n Briefly, in 100 words answer the question. ### Answer: Critics argue that the EU\'s AI Act could stifle innovation and competitiveness by imposing strict regulations on AI development and deployment, potentially creating a "Euro-centric" AI ecosystem that diverges from global standards and slows the pace of innovation. They also express concern that the Act\'s focus on ethical considerations could lead to a "regulatory race to the bottom," where companies may be incentivized to move AI development to countries with weaker regulations.</s>',
#  '<s> ### Question: How does the European Union classify AI systems under its AI Act, and what are the implications for "high risk" AI systems?\n Briefly, in 100 words answer the question. ### Answer: The European Union classifies AI systems under its AI Act into three categories: "low risk," "medium risk," and "high risk." "High risk" AI systems are those that are likely to pose a significant risk to people, the environment, or national security, such as autonomous weapons, AI-based decision-making systems for critical infrastructure, and AI-based social scoring systems. The implications for "high risk" AI systems include stricter regulations, oversight, and reporting requirements, as well as the possibility of a ban or restriction on certain types of AI.</s>',
#  '<s> ### Question: What are the Universal Guidelines for Artificial Intelligence endorsed by EPIC?\n Briefly, in 100 words answer the question. ### Answer: The Universal Guidelines for Artificial Intelligence (AGI) are a set of ethical principles endorsed by the Electronic Privacy Information Center (EPIC) to ensure that AI systems are developed and used in a responsible and ethical manner. The guidelines cover areas such as transparency, accountability, fairness, and respect for human rights. By following these guidelines, developers and users of AI can promote trustworthy and ethical AI systems that benefit society as a whole.</s>',
#  '<s> ### Question: What role do whistleblowers and complaints play in the AI regulatory process?\n Briefly, in 100 words answer the question. ### Answer: Whistleblowers and complaints play a crucial role in the AI regulatory process by serving as early warning systems for potential misuses of AI. They allow regulators to identify and address issues before they become widespread, preventing harm to individuals, society, and the environment. By providing information on potential AI risks and abuses, whistleblowers and complainants help regulators to develop and enforce effective AI regulations, ensuring that AI is developed and used responsibly and ethically.</s>',
#  '<s> ### Question: How\'s UK\'s approach different from that of the European Union?\n Briefly, in 100 words answer the question. ### Answer: The UK\'s approach to data protection is different from the European Union\'s (EU) in several ways. The UK has its own Data Protection Act 2018, which is separate from the EU\'s General Data Protection Regulation (GDPR). The UK\'s act includes additional provisions, such as a broader definition of "sensitive personal data" and a lower threshold for consent. Additionally, the UK has opted out of certain EU data protection provisions, such as the EU\'s "one-stop-shop" mechanism for cross-border data transfers.</s>',
#  "<s> ### Question: How does Japan's approach to AI regulation differ from that of the European Commission and Canada?\n Briefly, in 100 words answer the question. ### Answer: Japan's approach to AI regulation differs from that of the European Commission and Canada in several ways. While the European Commission has adopted a more comprehensive and prescriptive approach, focusing on areas such as data privacy and security, Canada has taken a more principles-based approach, emphasizing transparency and accountability. Japan, on the other hand, has taken a more risk-based approach, focusing on areas such as safety and ethical considerations. Additionally, Japan has established a dedicated AI ethics committee to provide guidance on ethical AI development and use.</s>",
#  '<s> ### Question: What are foundational AI models, and why are they important?\n Briefly, in 100 words answer the question. ### Answer: Foundational AI models are the fundamental building blocks of AI systems, such as decision trees, neural networks, and clustering algorithms. These models are important because they provide a basis for developing more complex AI systems, and they are often used as a starting point for training and fine-tuning more specialized models. Understanding the foundational models is essential for developing and interpreting AI systems, and it can help ensure that AI systems are transparent, explainable, and reliable.</s>',
#  '<s> ### Question: What additional measures are needed for international cooperation on foundational AI models?\n Briefly, in 100 words answer the question. ### Answer: International cooperation on foundational AI models requires the establishment of standardized frameworks for model development, testing, and deployment. This includes developing common data sets, establishing best practices for model validation, and creating mechanisms for model sharing and collaboration. Additionally, there is a need for greater transparency and accountability in AI model development, including the disclosure of model architectures and performance metrics. Finally, there should be a focus on ensuring that AI models are aligned with ethical and moral values, and that their deployment does not perpetuate biases or discrimination.</s>',
#  '<s> ### Question: What are the focus tasks of China’s New Generation Artificial Intelligence Development? \n Briefly, in 100 words answer the question. ### Answer: The focus tasks of China\'s New Generation Artificial Intelligence Development include:\n\n1. Developing AI technologies for strategic emerging industries, such as autonomous driving, robotics, and smart manufacturing.\n2. Building an AI-powered "Digital China" by integrating AI into various sectors, including healthcare, education, and agriculture.\n3. Enhancing AI security and privacy, including the development of secure AI algorithms and the protection of personal data.\n4. Promoting AI innovation and entrepreneurship, including the establishment of AI-focused research institutions and the support of AI startups.\n5. Fostering international cooperation and collaboration in AI research and development, including the Belt and Road Initiative.</s>',
#  '<s> ### Question: What are the economic, ethical, and strategic issues that call into question the continuation of collaboration on AI with China?\n Briefly, in 100 words answer the question. ### Answer: The economic, ethical, and strategic issues that call into question the continuation of collaboration on AI with China include concerns about intellectual property theft, data privacy and security, and the potential for AI to be used for malicious purposes. Additionally, there are ethical concerns about the use of AI in areas such as facial recognition and surveillance, and strategic concerns about the potential for China to gain a competitive advantage in the global AI race.</s>',
#  "<s> ### Question: What role has the World Bank played in supporting AI in the public sector?\n Briefly, in 100 words answer the question. ### Answer: The World Bank has played a significant role in supporting AI in the public sector through its various initiatives and programs. For instance, the World Bank's Digital Development Strategy aims to promote the use of AI in areas such as healthcare, education, and infrastructure. Additionally, the World Bank has provided financial and technical assistance to governments to help them develop and implement AI-powered solutions to improve public services. Furthermore, the World Bank has also supported the development of AI-related policies and regulations to ensure that AI is used ethically and responsibly in the public sector.</s>",
#  '<s> ### Question: How can the AI assurance industry contribute to regulatory compliance and AI system improvement?\n Briefly, in 100 words answer the question. ### Answer: The AI assurance industry can contribute to regulatory compliance and AI system improvement by providing independent third-party assessments and audits of AI systems to ensure they meet regulatory requirements and industry standards. These assessments can identify potential risks and vulnerabilities, and provide recommendations for improvement, which can help organizations to strengthen their AI systems and avoid potential legal and financial consequences of non-compliance. Additionally, the AI assurance industry can work with regulatory bodies to develop and implement standards and guidelines for AI system development and deployment, which can help to ensure that AI systems are designed and deployed in a responsible and ethical manner.</s>',
#  "<s> ### Question: What are some of the key principles outlined in the White House's Blueprint for an AI Bill of Rights? \n Briefly, in 100 words answer the question. ### Answer: The White House's Blueprint for an AI Bill of Rights outlines several key principles, including:\n\n1. Transparency: AI systems must be transparent about their functions and decision-making processes.\n2. Accountability: Developers and users of AI must be held accountable for any harm caused by their systems.\n3. Privacy: AI systems must respect individuals' privacy and security.\n4. Nondiscrimination: AI systems must not discriminate against individuals or groups based on race, gender, religion, or other characteristics.\n5. Fairness: AI systems must be fair and unbiased in their decision-making processes.\n6. Safety: AI systems must be designed and deployed with safety in mind, to avoid harm to individuals or communities.\n7. Security: AI systems must be secure and protected against unauthorized access or manipulation.\n8. Human o",
#  '<s> ### Question: What are main concerns in relation to AI policy?\n Briefly, in 100 words answer the question. ### Answer: The main concerns in relation to AI policy include ensuring accountability and transparency in AI decision-making processes, addressing privacy and security concerns, mitigating the potential for AI to exacerbate existing social inequalities, and developing ethical frameworks for AI development and deployment. Additionally, there are concerns about the impact of AI on employment, the potential for AI to be used in autonomous weapons, and the need for international cooperation to establish a coherent and comprehensive AI policy framework.</s>',
#  "<s> ### Question: How is international cooperation on AI currently being pursued?\n Briefly, in 100 words answer the question. ### Answer: International cooperation on AI is currently being pursued through various initiatives such as the OECD Principles on Artificial Intelligence, the G7 AI Partnership, and the European Union's AI Strategy. These initiatives aim to promote responsible AI development and use, protect privacy and security, and foster collaboration among countries to address the ethical and social implications of AI. Additionally, organizations such as the IEEE Global Initiative on Ethics of Autonomous and Intelligent Systems and the Future of Life Institute are working to establish standards and guidelines for AI development and use.</s>",
#  '<s> ### Question: What are the basic principles set forth by the Japanese government for AI regulation in 2019?\n Briefly, in 100 words answer the question. ### Answer: In 2019, the Japanese government established a set of basic principles for AI regulation, which include ensuring safety and reliability, protecting personal information, and promoting ethical use. The principles also emphasize the importance of transparency, accountability, and collaboration between government, industry, and academia. Additionally, the government aims to establish a framework for AI development and deployment, and to provide guidelines for AI-related research and development.</s>',
#  "<s> ### Question: What is the World Bank's Policy on Access to Information?\n Briefly, in 100 words answer the question. ### Answer: The World Bank's policy on access to information is to make information freely available to the public, subject to certain exceptions and limitations. The policy sets out to promote transparency, accountability, and good governance by providing access to information on its operations, policies, and projects. The World Bank also adheres to the International Aid Transparency Initiative (IATI) standards, which aim to improve the availability and accessibility of development data.</s>"]

# %%
df_test_all['original_llama_generations']=generations_original
df_test_all
# Out:
#                                                 input  \
# 0   Why is international cooperation on AI important?
# 1   Can you describe the approach taken by the res...
# 2   What concerns do critics have regarding the EU...
# 3   How does the European Union classify AI system...
# 4   What are the Universal Guidelines for Artifici...
# 5   What role do whistleblowers and complaints pla...
# 6   How's UK's approach different from that of the...
# 7   How does Japan's approach to AI regulation dif...
# 8   What are foundational AI models, and why are t...
# 9   What additional measures are needed for intern...
# 10  What are the focus tasks of China’s New Genera...
# 11  What are the economic, ethical, and strategic ...
# 12  What role has the World Bank played in support...
# 13  How can the AI assurance industry contribute t...
# 14  What are some of the key principles outlined i...
# 15   What are main concerns in relation to AI policy?
# 16  How is international cooperation on AI current...
# 17  What are the basic principles set forth by the...
# 18  What is the World Bank's Policy on Access to I...
#
#                                                output  __index_level_0__  \
# 0   International cooperation on AI is crucial due...                 70
# 1   The research team prepared generic interview p...                 21
# 2   Critics, including EU businesses, have express...                 37
# 3   The European Union's AI Act classifies AI syst...                 36
# 4   The Universal Guidelines include rights to tra...                 58
# 5   Whistleblowers and individual complaints are c...                 48
# 6   Unlike the European Union (EU), the UK’s appro...                 14
# 7   Japan focuses on a risk-based, agile, and mult...                 31
# 8   Foundational AI models, such as large language...                 60
# 9   The article suggests that more ambitious trade...                 64
# 10  (1) Build open and coordinated AI science and ...                  6
# 11  Issues include the ethical use of AI, strategi...                 78
# 12  The World Bank launched the GovTech Global Par...                 88
# 13  The AI assurance industry, comprising companie...                 49
# 14  The Blueprint emphasizes principles such as th...                 28
# 15  The need for AI policies to protect individual...                 55
# 16  Governments are regulating AI, and internation...                 62
# 17  In 2019, the Japanese government published the...                 30
# 18  The policy outlines the World Bank's commitmen...                 89
#
#             llama_generations_with_examples_prompting  \
# 0   <s> This is example you can refer to:\n  Quest...
# 1   <s> This is example you can refer to:\n  Quest...
# 2   <s> This is example you can refer to:\n  Quest...
# 3   <s> This is example you can refer to:\n  Quest...
# 4   <s> This is example you can refer to:\n  Quest...
# 5   <s> This is example you can refer to:\n  Quest...
# 6   <s> This is example you can refer to:\n  Quest...
# 7   <s> This is example you can refer to:\n  Quest...
# 8   <s> This is example you can refer to:\n  Quest...
# 9   <s> This is example you can refer to:\n  Quest...
# 10  <s> This is example you can refer to:\n  Quest...
# 11  <s> This is example you can refer to:\n  Quest...
# 12  <s> This is example you can refer to:\n  Quest...
# 13  <s> This is example you can refer to:\n  Quest...
# 14  <s> This is example you can refer to:\n  Quest...
# 15  <s> This is example you can refer to:\n  Quest...
# 16  <s> This is example you can refer to:\n  Quest...
# 17  <s> This is example you can refer to:\n  Quest...
# 18  <s> This is example you can refer to:\n  Quest...
#
#                            original_llama_generations
# 0   <s> ### Question: Why is international coopera...
# 1   <s> ### Question: Can you describe the approac...
# 2   <s> ### Question: What concerns do critics hav...
# 3   <s> ### Question: How does the European Union ...
# 4   <s> ### Question: What are the Universal Guide...
# 5   <s> ### Question: What role do whistleblowers ...
# 6   <s> ### Question: How's UK's approach differen...
# 7   <s> ### Question: How does Japan's approach to...
# 8   <s> ### Question: What are foundational AI mod...
# 9   <s> ### Question: What additional measures are...
# 10  <s> ### Question: What are the focus tasks of ...
# 11  <s> ### Question: What are the economic, ethic...
# 12  <s> ### Question: What role has the World Bank...
# 13  <s> ### Question: How can the AI assurance ind...
# 14  <s> ### Question: What are some of the key pri...
# 15  <s> ### Question: What are main concerns in re...
# 16  <s> ### Question: How is international coopera...
# 17  <s> ### Question: What are the basic principle...
# 18  <s> ### Question: What is the World Bank's Pol...
# Error: Runtime no longer has a reference to this dataframe, please re-run this cell and try again.
# Error: Runtime no longer has a reference to this dataframe, please re-run this cell and try again.

# %%
df_test_all['original_llama_generations']= df_test_all['original_llama_generations'].apply(lambda x: x.split('Answer:', 1)[-1] if 'Answer:' in x else x)
df_test_all['original_llama_generations']= df_test_all['original_llama_generations'].apply(lambda x: x.replace('</s>', '').replace('<s>', '').replace('</s>s', '').replace('<s/>', '').replace('s ', ''))
df_test_all['llama_generations_with_examples_prompting']= df_test_all['llama_generations_with_examples_prompting'].apply(lambda x: x.split('Answer:', 1)[-1] if 'Answer:' in x else x)
df_test_all['llama_generations_with_examples_prompting']= df_test_all['llama_generations_with_examples_prompting'].apply(lambda x: x.replace('</s>', '').replace('<s>', '').replace('</s>s', '').replace('<s/>', '').replace('s ', ''))
df_test_all
# Out:
#                                                 input  \
# 0   Why is international cooperation on AI important?
# 1   Can you describe the approach taken by the res...
# 2   What concerns do critics have regarding the EU...
# 3   How does the European Union classify AI system...
# 4   What are the Universal Guidelines for Artifici...
# 5   What role do whistleblowers and complaints pla...
# 6   How's UK's approach different from that of the...
# 7   How does Japan's approach to AI regulation dif...
# 8   What are foundational AI models, and why are t...
# 9   What additional measures are needed for intern...
# 10  What are the focus tasks of China’s New Genera...
# 11  What are the economic, ethical, and strategic ...
# 12  What role has the World Bank played in support...
# 13  How can the AI assurance industry contribute t...
# 14  What are some of the key principles outlined i...
# 15   What are main concerns in relation to AI policy?
# 16  How is international cooperation on AI current...
# 17  What are the basic principles set forth by the...
# 18  What is the World Bank's Policy on Access to I...
#
#                                                output  __index_level_0__  \
# 0   International cooperation on AI is crucial due...                 70
# 1   The research team prepared generic interview p...                 21
# 2   Critics, including EU businesses, have express...                 37
# 3   The European Union's AI Act classifies AI syst...                 36
# 4   The Universal Guidelines include rights to tra...                 58
# 5   Whistleblowers and individual complaints are c...                 48
# 6   Unlike the European Union (EU), the UK’s appro...                 14
# 7   Japan focuses on a risk-based, agile, and mult...                 31
# 8   Foundational AI models, such as large language...                 60
# 9   The article suggests that more ambitious trade...                 64
# 10  (1) Build open and coordinated AI science and ...                  6
# 11  Issues include the ethical use of AI, strategi...                 78
# 12  The World Bank launched the GovTech Global Par...                 88
# 13  The AI assurance industry, comprising companie...                 49
# 14  The Blueprint emphasizes principles such as th...                 28
# 15  The need for AI policies to protect individual...                 55
# 16  Governments are regulating AI, and internation...                 62
# 17  In 2019, the Japanese government published the...                 30
# 18  The policy outlines the World Bank's commitmen...                 89
#
#             llama_generations_with_examples_prompting  \
# 0    International cooperation on AI iimportant be...
# 1    The research team took a multi-faceted approa...
# 2    Critichave several concernregarding the EU'AI...
# 3    The European Union classifieAI systemunder it...
# 4    EPIC (Electronic Privacy Information Center) ...
# 5    Whistleblowerand complaintplay a crucial role...
# 6    The UK'approach to AI ethicidifferent from th...
# 7    Japan'approach to AI regulation differfrom th...
# 8    Foundational AI modelare the basic building b...
# 9    Additional measureneeded for international co...
# 10   The focutaskof China’New Generation Artificia...
# 11   The economic, ethical, and strategic issuetha...
# 12   The World Bank haplayed a significant role in...
# 13   The AI assurance industry can contribute to r...
# 14   The White House'Blueprint for an AI Bill of R...
# 15   The main concernin relation to AI policy incl...
# 16   International cooperation on AI icurrently be...
# 17   The Japanese government set forth the followi...
# 18   The World Bank'policy on accesto information ...
#
#                            original_llama_generations
# 0    International cooperation on AI iimportant be...
# 1    The research team took a multi-faceted approa...
# 2    Criticargue that the EU'AI Act could stifle i...
# 3    The European Union classifieAI systemunder it...
# 4    The Universal Guidelinefor Artificial Intelli...
# 5    Whistleblowerand complaintplay a crucial role...
# 6    The UK'approach to data protection idifferent...
# 7    Japan'approach to AI regulation differfrom th...
# 8    Foundational AI modelare the fundamental buil...
# 9    International cooperation on foundational AI ...
# 10   The focutaskof China'New Generation Artificia...
# 11   The economic, ethical, and strategic issuetha...
# 12   The World Bank haplayed a significant role in...
# 13   The AI assurance industry can contribute to r...
# 14   The White House'Blueprint for an AI Bill of R...
# 15   The main concernin relation to AI policy incl...
# 16   International cooperation on AI icurrently be...
# 17   In 2019, the Japanese government established ...
# 18   The World Bank'policy on accesto information ...
# Error: Runtime no longer has a reference to this dataframe, please re-run this cell and try again.
# Error: Runtime no longer has a reference to this dataframe, please re-run this cell and try again.
# Error: Runtime no longer has a reference to this dataframe, please re-run this cell and try again.
# Error: Runtime no longer has a reference to this dataframe, please re-run this cell and try again.
# Error: Runtime no longer has a reference to this dataframe, please re-run this cell and try again.

# %% [markdown]
# ## **Metrics**

# %%
import locale
locale.getpreferredencoding = lambda: "UTF-8"
# !pip install nltk rouge -q
from nltk.translate.bleu_score import sentence_bleu
from rouge import Rouge

# %%
import numpy as np
import warnings
warnings.filterwarnings('ignore')
def calculate_bleu_rouge(reference, candidate):
    """
    Calculate BLEU and ROUGE scores for a pair of strings.

    :param reference: The reference string (ground truth).
    :param candidate: The candidate string (generated text).
    :return: A dictionary containing BLEU and ROUGE scores.
    """
    # Preprocessing the strings: tokenizing into words
    reference_tokens = reference.split()
    candidate_tokens = candidate.split()

    # Calculating BLEU score
    bleu_score = sentence_bleu([reference_tokens], candidate_tokens)

    # Calculating ROUGE score
    rouge = Rouge()
    rouge_score = rouge.get_scores(candidate, reference)[0]

    return np.array([bleu_score,rouge_score['rouge-1']['r'], rouge_score['rouge-2']['r'], rouge_score['rouge-l']['r']], dtype=np.float32)

# Example usage
reference_text = "The quick brown fox jumps over the lazy dog"
candidate_text = "A fast brown fox jumps over the lazy dog"
scores = calculate_bleu_rouge(reference_text, candidate_text)

print(scores)
# Out:
# [0.7259795 0.7777778 0.75      0.7777778]

# %%
raw_model_metrics = df_test_all.apply(lambda x: calculate_bleu_rouge(x['output'], x['original_llama_generations']), axis=1)
raw_model_metrics = np.array(raw_model_metrics).mean(-1)
raw_model_metrics
# Out:
# array([0.00698839, 0.28706285, 0.05660266, 0.23545401], dtype=float32)

# %%
fine_tuned_model_metrics = df_test_all.apply(lambda x: calculate_bleu_rouge(x['output'], x['llama_generations_with_examples_prompting']), axis=1)
fine_tuned_model_metrics = np.array(fine_tuned_model_metrics).mean(-1)
fine_tuned_model_metrics
# Out:
# array([0.00267924, 0.29525208, 0.05765411, 0.23325242], dtype=float32)

# %%
import pandas as pd
df_metrics = pd.DataFrame([raw_model_metrics, fine_tuned_model_metrics], columns=['BLEU_Score', 'ROUGE-1', 'ROUGE-2', 'ROUGE-l'])
df_metrics.index  = ['Raw_llama2', 'llama2_examples_prompting']
df_metrics
# Out:
#                            BLEU_Score   ROUGE-1   ROUGE-2   ROUGE-l
# Raw_llama2                   0.006988  0.287063  0.056603  0.235454
# llama2_examples_prompting    0.002679  0.295252  0.057654  0.233252

# %% [markdown]
# ## **Fine tune**

# %%
def formatting_prompts_func(example):
    output_texts = []
    for i in range(len(example['input'])):
        text = f"### Question: {example['input'][i]}\n Briefly, in 100 words answer the question. ### Answer: {example['output'][i]}"
        output_texts.append(text)
    return output_texts

# %%
# LoRA Config
peft_parameters = LoraConfig(
    lora_alpha=16,
    lora_dropout=0.1,
    r=16,#rank
    bias="none",
    task_type="CAUSAL_LM"
)

# batch_size_multiplier = 2
accumulation_multiplier = 2
# Training Params
train_params = TrainingArguments(
    output_dir="./results_modified",
    evaluation_strategy = "epoch",
    num_train_epochs=10*accumulation_multiplier,
    per_device_train_batch_size=4*1,
    gradient_accumulation_steps=1 * accumulation_multiplier,
    optim="paged_adamw_32bit",
    save_steps=100,
    logging_steps=20//accumulation_multiplier,
    learning_rate=1e-4,
    weight_decay=2e-3,
    fp16=False,
    bf16=False,
    max_grad_norm=0.1,
    max_steps=-1,
    warmup_ratio=0.03,
    group_by_length=True,
    lr_scheduler_type="constant",
    report_to="tensorboard"
)

# Trainer
fine_tuning = SFTTrainer(
    model=base_model,
    train_dataset=training_data,
    eval_dataset = test_data,
    formatting_func=formatting_prompts_func, #hereeee
    peft_config=peft_parameters,
    # dataset_text_field="text",
    tokenizer=llama_tokenizer,
    args=train_params
)

# Training
fine_tuning.train()

# Save Model
fine_tuning.model.save_pretrained(refined_model)
# Out:
# Map:   0%|          | 0/75 [00:00<?, ? examples/s]
# Map:   0%|          | 0/19 [00:00<?, ? examples/s]
# You're using a LlamaTokenizerFast tokenizer. Please note that with a fast tokenizer, using the `__call__` method is faster than using a method to encode the text followed by a call to the `pad` method to get a padded encoding.
#     <div>
#
#       <progress value='180' max='180' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [180/180 23:02, Epoch 18/20]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Epoch</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>No log</td>
#       <td>2.374022</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>2.707000</td>
#       <td>2.045792</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>2.292300</td>
#       <td>1.855647</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>2.041700</td>
#       <td>1.738744</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>1.852200</td>
#       <td>1.663867</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>1.745300</td>
#       <td>1.531617</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>1.596200</td>
#       <td>1.508438</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td>1.435600</td>
#       <td>1.508570</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td>1.431400</td>
#       <td>1.532889</td>
#     </tr>
#     <tr>
#       <td>10</td>
#       <td>1.321100</td>
#       <td>1.583395</td>
#     </tr>
#     <tr>
#       <td>10</td>
#       <td>1.281900</td>
#       <td>1.614560</td>
#     </tr>
#     <tr>
#       <td>12</td>
#       <td>1.107700</td>
#       <td>1.659698</td>
#     </tr>
#     <tr>
#       <td>12</td>
#       <td>1.018200</td>
#       <td>1.731630</td>
#     </tr>
#     <tr>
#       <td>14</td>
#       <td>1.023100</td>
#       <td>1.800918</td>
#     </tr>
#     <tr>
#       <td>14</td>
#       <td>0.815300</td>
#       <td>1.857330</td>
#     </tr>
#     <tr>
#       <td>16</td>
#       <td>0.748100</td>
#       <td>1.885537</td>
#     </tr>
#     <tr>
#       <td>16</td>
#       <td>0.612900</td>
#       <td>2.029296</td>
#     </tr>
#     <tr>
#       <td>18</td>
#       <td>0.661900</td>
#       <td>2.197303</td>
#     </tr>
#     <tr>
#       <td>18</td>
#       <td>0.475500</td>
#       <td>2.286538</td>
#     </tr>
#   </tbody>
# </table><p>

# %%
from tqdm.notebook import tqdm
import gc
generations =[]
for i in tqdm(range(len(df_test_all)), "generating..."):
  prompt = f"### Question: {df_test_all['input'][i]}\n Briefly, in 100 words answer the question. ### Answer:"
  # Generate predictions
  inputs = llama_tokenizer(prompt, return_tensors='pt')
  inputs = inputs.to("cuda")
  output = fine_tuning.model.generate(**inputs, max_new_tokens=100,temperature=0.2)
  response = llama_tokenizer.decode(output[0].tolist())
  # print(response)
  # break
  generations.append(response)
  del inputs, output
  gc.collect()
  torch.cuda.empty_cache()

generations
# Out:
# generating...:   0%|          | 0/19 [00:00<?, ?it/s]
# ['<s> ### Question: Why is international cooperation on AI important?\n Briefly, in 100 words answer the question. ### Answer: International cooperation on AI is important for several reasons, including setting standards for AI technologies and achieving economic and security benefits. It helps in preventing the race to the bottom in regulation and increasing the risks associated with AI. \n ### Question: Why is international cooperation on AI important? Briefly, in 100 words answer the question.  ### Answer: It helps in setting global standards for AI technologies and achieving economic and',
#  '<s> ### Question: Can you describe the approach taken by the research team in preparing for the interviews with academia and industry experts in the AI assessment?\n Briefly, in 100 words answer the question. ### Answer: The research team adopted a structured interview approach based on a comprehensive list of experts assembled through targeted outreach and social media campaigns, resulting in a diverse pool of participants from academia and industry. The interview protocol included open-ended questions to encourage free-flowing discussions and structured questions to gather detailed information on specific topics. \nThe interview process was conducted remotely and recorded, and some interviews were conducted in-person. The research team',
#  "<s> ### Question: What concerns do critics have regarding the EU's AI Act's potential impact on innovation and competitiveness?\n Briefly, in 100 words answer the question. ### Answer: Critics worry that the AI Act's strict review process and prohibition on certain high-risk AI systems might deter companies from developing and deploying innovative technologies in the EU, leading to a competitiveness disadvantage compared to other regions. This could have long-term consequences for the EU's economic growth and innovation leadership. \n ### Question: In 100 words answer the question.  Briefly, in 100",
#  '<s> ### Question: How does the European Union classify AI systems under its AI Act, and what are the implications for "high risk" AI systems?\n Briefly, in 100 words answer the question. ### Answer: The EU defines "high-risk" AI systems as those that present a significant risk to public health or the security of the EU, and requires these systems to meet certain risk management requirements. These requirements include developing the system in accordion with EU law, registering the system in the EU, reporting significant incidents to the EU, and implementing appropriate risk management measures. \nHigh-risk AI systems include those that handle sensitive information, are used in critical sectors like transport',
#  '<s> ### Question: What are the Universal Guidelines for Artificial Intelligence endorsed by EPIC?\n Briefly, in 100 words answer the question. ### Answer: Freeze the development and deployment of autonomous weapons, and orderly and safe cooperation in restricting the development and use of autonomous systems to guide international guidelines. Emphasize the development and use of autonomous systems in a responsible and ethical manner, and orderly and safe cooperation in promoting the global governance of autonomous systems. Encourage the development and use of autonomous systems in a responsible and ethical manner, and orderly and safe cooperation',
#  "<s> ### Question: What role do whistleblowers and complaints play in the AI regulatory process?\n Briefly, in 100 words answer the question. ### Answer: Timely and accurate whistleblower reports and complaints help identify emerging risks associated with AI and spurred regulatory action. They don't just stimulate compliance and policy reform, but also contribute to the development of international AI regulatory standards. \n Briefly, in 100 words answer the question. ### Answer: Timely and accurate whistleblower reports and complaints help identify emerging risks associated with AI and sp",
#  "<s> ### Question: How's UK's approach different from that of the European Union?\n Briefly, in 100 words answer the question. ### Answer: UK's approach is more focused on freeing industrial data and linking it to economic growth, while the EU's approach is more comprehensive and encompasses all sectors and types of data. The UK's approach is more deregulation-focused, while the EU's is more focused on enforcement and rules. \n ### Question: Why is this important? Importance: In 100 words, the answer is significant. Briefly,",
#  "<s> ### Question: How does Japan's approach to AI regulation differ from that of the European Commission and Canada?\n Briefly, in 100 words answer the question. ### Answer: Japan's approach to AI regulation emphasizes maximizing AI's positive impact on society, focusing on a risk-based, agile, and multi-stakeholder process, rather than a prescriptive, proactive, and mandatory one. This contrasts with the European Commission's and Canada's emphasis on preventing harm through strict regulation and enforcement. Japan also prioritizes AI innovation and the development of a national AI",
#  "<s> ### Question: What are foundational AI models, and why are they important?\n Briefly, in 100 words answer the question. ### Answer: Foundational AI models are basic algorithms that are widely used and available publicly, often for free. They're important because foundational models can be used as building blocks for more complex AI applications, speeding up the development of new AI systems. They help reduce the cost and time required to develop original foundational models. ### Question: Why are foundational models important only in theory? In practice, they're important as well, as they help found illicit applications of",
#  '<s> ### Question: What additional measures are needed for international cooperation on foundational AI models?\n Briefly, in 100 words answer the question. ### Answer: A comprehensive and balanced approach to addressing the benefits and risks of foundational AI models and the inequality they exacerbitate, including the impact on employment, is needed to address the challenges posed by these models. This includes addressing the negative effects on employment and the inequality they exacerbitate, including the impact on workforce composition, through a comprehensive and balanced approach to addressing the benefits and risks of foundational AI models and',
#  '<s> ### Question: What are the focus tasks of China’s New Generation Artificial Intelligence Development? \n Briefly, in 100 words answer the question. ### Answer: Focus tasks include developing common-purpose intelligent systems, high-performance intelligent systems, safety-oriented intelligent systems, and intelligent applications in important sectors. Specifically, they involve the development of basic theories and methods for intelligent science and technology, key technologies and systems for intelligent science and technology, and applications in important sectors and fields. \nThe task involves the development of basic theories and methods for intelligent science and technology, key technologies and',
#  "<s> ### Question: What are the economic, ethical, and strategic issues that call into question the continuation of collaboration on AI with China?\n Briefly, in 100 words answer the question. ### Answer: Economic: Risk of economic competition with the West through the exploitation of AI-enabled market manipulation and fraud. Ethical: Compliance with ethical standards is questionable, particularly in areas like facial recognition and mass surveillance. Strategically: China's collaboration with international AI developers and vendors undermines the EU's own AI regulatory ambitions and potential economic losses. Briefly, in 100 words answer the",
#  '<s> ### Question: What role has the World Bank played in supporting AI in the public sector?\n Briefly, in 100 words answer the question. ### Answer: The World Bank has issued policy guidelines and conducted research on the ethical use of AI in government, highlighting the need for a robust framework to govern AI and address its potential harms to people. It has also funded AI-related projects and advised countries on developing AI strategies. \n Briefly, in 100 words answer the question. ### Answer: The World Bank has played a role in the global conversation on AI policy,',
#  "<s> ### Question: How can the AI assurance industry contribute to regulatory compliance and AI system improvement?\n Briefly, in 100 words answer the question. ### Answer: By focusing on assuring AI systems are safe and performant, rather than just regulatory compliant, the AI assurance industry can help companies maximize AI's benefits while minimizing its risks. This could include developing standards for AI system performance and assurance, enhancing AI system safety and effectiveness, and helping companies adopt AI assurance best practices. The industry can also help companies comply with regulatory requirements, reducing the burden",
#  "<s> ### Question: What are some of the key principles outlined in the White House's Blueprint for an AI Bill of Rights? \n Briefly, in 100 words answer the question. ### Answer: The blueprint emphasizes the importance of transparency and accountability in AI development, ensuring that the technology is safe and secure, and that people have control over their data. It also calls for fairness in AI applications, ensuring that people are not discriminated against based on race, gender, or other factors. Finally, it advocates for robust oversight and research to ensure that AI is developed and used responsibly. \n ### Answer: In ",
#  '<s> ### Question: What are main concerns in relation to AI policy?\n Briefly, in 100 words answer the question. ### Answer: Key concerns include the effectiveness and enforcement of AI policy, whether policy addresses the relevant problems, and the consistency with which policy addresses them. Additionally, there is a lack of awareness about AI policy and its effectiveness in addressing the concerns and problems it aims to address. \n ### Briefly, in 100 words answer the question.  Difficulty in addressing these concerns and problems is compounded by the lack of awaren',
#  '<s> ### Question: How is international cooperation on AI currently being pursued?\n Briefly, in 100 words answer the question. ### Answer: States are coordinating through various fora such as the AI(AI) Summit, the G7 AI Blueprint, and the Paris Rules Forum to establish common standards and practices for AI. They are also working together through the AI(AI) Compliance & Enforcement Advisory System, the OECD AI Compliance Programme, and the AI(AI) Multistakeholder Dialogue. Finally, they are participating in international con',
#  "<s> ### Question: What are the basic principles set forth by the Japanese government for AI regulation in 2019?\n Briefly, in 100 words answer the question. ### Answer: The basic principles include a risk-based approach, a staged approach to new AI technologies, and a focus on maximizing AI's potential while addressing societal risks. The government also emphasized the importance of international cooperation in AI regulation. \n Briefly, in 100 words answer the question. ### Answer: The basic principles include a risk-based approach, a staged approach to new AI technologies, and a focus",
#  "<s> ### Question: What is the World Bank's Policy on Access to Information?\n Briefly, in 100 words answer the question. ### Answer: The policy aims to promote transparency and access to information on the World Bank's activities, making information available to the public and stakeholders. It emphasizes the importance of openness in promoting accountability, trust, and development effectiveness. \n ### Question: Why is such a policy important for the World Bank? Briefly, in 100 words answer the question. ### Answer: The policy is crucial for the World Bank's commitment"]

# %%
df_test_all['fine_tuned_llama_generations_with_lr_1e_4']=generations

# %%
fine_tuning.model.save_pretrained("/content/drive/MyDrive/94812")

# %%
# fine_tuning is the trainer
model_path = "/content/drive/MyDrive/94812"
fine_tuning.save_model(model_path)
fine_tuning.model.config.save_pretrained(model_path+"config.json")

# %%
df_test_all
# Out:
#                                                 input  \
# 0   Why is international cooperation on AI important?
# 1   Can you describe the approach taken by the res...
# 2   What concerns do critics have regarding the EU...
# 3   How does the European Union classify AI system...
# 4   What are the Universal Guidelines for Artifici...
# 5   What role do whistleblowers and complaints pla...
# 6   How's UK's approach different from that of the...
# 7   How does Japan's approach to AI regulation dif...
# 8   What are foundational AI models, and why are t...
# 9   What additional measures are needed for intern...
# 10  What are the focus tasks of China’s New Genera...
# 11  What are the economic, ethical, and strategic ...
# 12  What role has the World Bank played in support...
# 13  How can the AI assurance industry contribute t...
# 14  What are some of the key principles outlined i...
# 15   What are main concerns in relation to AI policy?
# 16  How is international cooperation on AI current...
# 17  What are the basic principles set forth by the...
# 18  What is the World Bank's Policy on Access to I...
#
#                                                output  __index_level_0__  \
# 0   International cooperation on AI is crucial due...                 70
# 1   The research team prepared generic interview p...                 21
# 2   Critics, including EU businesses, have express...                 37
# 3   The European Union's AI Act classifies AI syst...                 36
# 4   The Universal Guidelines include rights to tra...                 58
# 5   Whistleblowers and individual complaints are c...                 48
# 6   Unlike the European Union (EU), the UK’s appro...                 14
# 7   Japan focuses on a risk-based, agile, and mult...                 31
# 8   Foundational AI models, such as large language...                 60
# 9   The article suggests that more ambitious trade...                 64
# 10  (1) Build open and coordinated AI science and ...                  6
# 11  Issues include the ethical use of AI, strategi...                 78
# 12  The World Bank launched the GovTech Global Par...                 88
# 13  The AI assurance industry, comprising companie...                 49
# 14  The Blueprint emphasizes principles such as th...                 28
# 15  The need for AI policies to protect individual...                 55
# 16  Governments are regulating AI, and internation...                 62
# 17  In 2019, the Japanese government published the...                 30
# 18  The policy outlines the World Bank's commitmen...                 89
#
#             llama_generations_with_examples_prompting  \
# 0    International cooperation on AI iimportant be...
# 1    The research team took a multi-faceted approa...
# 2    Critichave several concernregarding the EU'AI...
# 3    The European Union classifieAI systemunder it...
# 4    EPIC (Electronic Privacy Information Center) ...
# 5    Whistleblowerand complaintplay a crucial role...
# 6    The UK'approach to AI ethicidifferent from th...
# 7    Japan'approach to AI regulation differfrom th...
# 8    Foundational AI modelare the basic building b...
# 9    Additional measureneeded for international co...
# 10   The focutaskof China’New Generation Artificia...
# 11   The economic, ethical, and strategic issuetha...
# 12   The World Bank haplayed a significant role in...
# 13   The AI assurance industry can contribute to r...
# 14   The White House'Blueprint for an AI Bill of R...
# 15   The main concernin relation to AI policy incl...
# 16   International cooperation on AI icurrently be...
# 17   The Japanese government set forth the followi...
# 18   The World Bank'policy on accesto information ...
#
#                            original_llama_generations  \
# 0    International cooperation on AI iimportant be...
# 1    The research team took a multi-faceted approa...
# 2    Criticargue that the EU'AI Act could stifle i...
# 3    The European Union classifieAI systemunder it...
# 4    The Universal Guidelinefor Artificial Intelli...
# 5    Whistleblowerand complaintplay a crucial role...
# 6    The UK'approach to data protection idifferent...
# 7    Japan'approach to AI regulation differfrom th...
# 8    Foundational AI modelare the fundamental buil...
# 9    International cooperation on foundational AI ...
# 10   The focutaskof China'New Generation Artificia...
# 11   The economic, ethical, and strategic issuetha...
# 12   The World Bank haplayed a significant role in...
# 13   The AI assurance industry can contribute to r...
# 14   The White House'Blueprint for an AI Bill of R...
# 15   The main concernin relation to AI policy incl...
# 16   International cooperation on AI icurrently be...
# 17   In 2019, the Japanese government established ...
# 18   The World Bank'policy on accesto information ...
#
#             fine_tuned_llama_generations_with_lr_1e_4
# 0   <s> ### Question: Why is international coopera...
# 1   <s> ### Question: Can you describe the approac...
# 2   <s> ### Question: What concerns do critics hav...
# 3   <s> ### Question: How does the European Union ...
# 4   <s> ### Question: What are the Universal Guide...
# 5   <s> ### Question: What role do whistleblowers ...
# 6   <s> ### Question: How's UK's approach differen...
# 7   <s> ### Question: How does Japan's approach to...
# 8   <s> ### Question: What are foundational AI mod...
# 9   <s> ### Question: What additional measures are...
# 10  <s> ### Question: What are the focus tasks of ...
# 11  <s> ### Question: What are the economic, ethic...
# 12  <s> ### Question: What role has the World Bank...
# 13  <s> ### Question: How can the AI assurance ind...
# 14  <s> ### Question: What are some of the key pri...
# 15  <s> ### Question: What are main concerns in re...
# 16  <s> ### Question: How is international coopera...
# 17  <s> ### Question: What are the basic principle...
# 18  <s> ### Question: What is the World Bank's Pol...

# %%
# model_path = "/content/drive/MyDrive/94812/llama-2-7b-policyAI"

# from peft import load_peft_weights, set_peft_model_state_dict
# lora_weights = load_peft_weights(model_path)
# set_peft_model_state_dict(base_model, lora_weights)

# %% [markdown]
# ### Fine-tune 1.1

# %%
# LoRA Config
peft_parameters = LoraConfig(
    lora_alpha=16,
    lora_dropout=0.1,
    r=16,#rank
    bias="none",
    task_type="CAUSAL_LM"
)

# batch_size_multiplier = 2
accumulation_multiplier = 2
# Training Params
train_params = TrainingArguments(
    output_dir="./results_modified",
    evaluation_strategy = "epoch",
    num_train_epochs=10*accumulation_multiplier,
    per_device_train_batch_size=4*1,
    gradient_accumulation_steps=1 * accumulation_multiplier,
    optim="paged_adamw_32bit",
    save_steps=100,
    logging_steps=20//accumulation_multiplier,
    learning_rate=2e-4,
    weight_decay=2e-3,
    fp16=False,
    bf16=False,
    max_grad_norm=0.1,
    max_steps=-1,
    warmup_ratio=0.03,
    group_by_length=True,
    lr_scheduler_type="constant",
    report_to="tensorboard"
)

# Trainer
fine_tuning = SFTTrainer(
    model=base_model,
    train_dataset=training_data,
    eval_dataset = test_data,
    formatting_func=formatting_prompts_func, #hereeee
    peft_config=peft_parameters,
    # dataset_text_field="text",
    tokenizer=llama_tokenizer,
    args=train_params
)

# Training
fine_tuning.train()

# Save Model
fine_tuning.model.save_pretrained(refined_model)
# Out:
# Map:   0%|          | 0/75 [00:00<?, ? examples/s]
#     <div>
#
#       <progress value='180' max='180' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [180/180 23:03, Epoch 18/20]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Epoch</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>No log</td>
#       <td>2.108411</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>2.543900</td>
#       <td>1.791554</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>2.038100</td>
#       <td>1.652147</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>1.781100</td>
#       <td>1.510954</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>1.542100</td>
#       <td>1.500813</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>1.449100</td>
#       <td>1.548567</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>1.313400</td>
#       <td>1.609547</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td>1.098100</td>
#       <td>1.701728</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td>1.013300</td>
#       <td>1.842334</td>
#     </tr>
#     <tr>
#       <td>10</td>
#       <td>0.841500</td>
#       <td>1.874908</td>
#     </tr>
#     <tr>
#       <td>10</td>
#       <td>0.743200</td>
#       <td>1.959217</td>
#     </tr>
#     <tr>
#       <td>12</td>
#       <td>0.540000</td>
#       <td>2.078056</td>
#     </tr>
#     <tr>
#       <td>12</td>
#       <td>0.450100</td>
#       <td>2.272081</td>
#     </tr>
#     <tr>
#       <td>14</td>
#       <td>0.488100</td>
#       <td>2.374182</td>
#     </tr>
#     <tr>
#       <td>14</td>
#       <td>0.334100</td>
#       <td>2.451903</td>
#     </tr>
#     <tr>
#       <td>16</td>
#       <td>0.304400</td>
#       <td>2.494722</td>
#     </tr>
#     <tr>
#       <td>16</td>
#       <td>0.257800</td>
#       <td>2.636165</td>
#     </tr>
#     <tr>
#       <td>18</td>
#       <td>0.293300</td>
#       <td>2.710269</td>
#     </tr>
#     <tr>
#       <td>18</td>
#       <td>0.188900</td>
#       <td>2.721401</td>
#     </tr>
#   </tbody>
# </table><p>

# %%
from tqdm.notebook import tqdm
import gc
generations =[]
for i in tqdm(range(len(df_test_all)), "generating..."):
  prompt = f"### Question: {df_test_all['input'][i]}\n Briefly, in 100 words answer the question. ### Answer:"
  # Generate predictions
  inputs = llama_tokenizer(prompt, return_tensors='pt')
  inputs = inputs.to("cuda")
  output = fine_tuning.model.generate(**inputs, max_new_tokens=100,temperature=0.2)
  response = llama_tokenizer.decode(output[0].tolist())
  # print(response)
  # break
  generations.append(response)
  del inputs, output
  gc.collect()
  torch.cuda.empty_cache()

generations
# Out:
# generating...:   0%|          | 0/19 [00:00<?, ?it/s]
# ['<s> ### Question: Why is international cooperation on AI important?\n Briefly, in 100 words answer the question. ### Answer: International cooperation on AI is important for sharing best practices, establishing common standards, and helping to address the challenges posed by AI, particularly in areas where a single country cannot solve them. It helps in achieving a more equitable distribution of AI benefits and minimizing its risks. \n\nAI is a global problem, and solving it nationally is difficult. It requires a coordinated approach on an international basis to share the designs, the architectures, the',
#  '<s> ### Question: Can you describe the approach taken by the research team in preparing for the interviews with academia and industry experts in the AI assessment?\n Briefly, in 100 words answer the question. ### Answer: The research team prepared by reviewing key policy documents and interviewing key stakeholders, including academia and industry experts, to understand their perspectives on the effectiveness of the AI assessment. The interview approach was intentional, focusing on experts who were both knowledgeable about the AI assessment and familiar with the policy context. This helped to provide both technical and policy insights to the analysis. \nThe interviews were conducted remotely, with',
#  "<s> ### Question: What concerns do critics have regarding the EU's AI Act's potential impact on innovation and competitiveness?\n Briefly, in 100 words answer the question. ### Answer: Critics argue that the AI Act's extensive risk assessment and evaluation requirements, as well as the mandatory implementation of AI systems in some sectors, could lead to overregulation and stifle innovation, particularly in small and medium-sized companies. They also fear that the act's notification requirements for high-risk AI systems could create a competitive advantage for companies outside the EU, as companies outside the EU might be less likely to comply with",
#  '<s> ### Question: How does the European Union classify AI systems under its AI Act, and what are the implications for "high risk" AI systems?\n Briefly, in 100 words answer the question. ### Answer: The AI Act divides AI systems into "compliant" and "high risk" categories based on their complexity and potential impact on human health and safety. High-risk systems are subject to strict regulations and standards, while compliant systems enjoy a lighter regulatory burden. The implications for high-risk systems include a detailed set of requirements and standards the EU believes are necessary to ensure safety and privacy, as well as a mandatory labeling',
#  '<s> ### Question: What are the Universal Guidelines for Artificial Intelligence endorsed by EPIC?\n Briefly, in 100 words answer the question. ### Answer: They call for adhering to human rights principles and ensuring the transparency, accountability, and fairness of AI systems. They also support establishing safety standards for AI and promoting competition to spur innovation while addressing privacy concerns. \nOther guidelines include promoting education and digital skills, addressing the impact of AI on work, and supporting innovation and growth.  \nOverall, the Universal Guidelines aim to establish eth',
#  '<s> ### Question: What role do whistleblowers and complaints play in the AI regulatory process?\n Briefly, in 100 words answer the question. ### Answer: Whistleblowers and complaints provide vital information to regulators, helping to identify and flag AI risks and harms that might otherwise go undetected. They play a crucial role in the early warning system for AI governance, helping to ensure that regulators are aware of emerging risks and trends in AI. \n\n(Reforming AI: A Toolbox for Government. Outside of government, the whistleblower reporting system',
#  '<s> ### Question: How\'s UK\'s approach different from that of the European Union?\n Briefly, in 100 words answer the question. ### Answer: UK\'s approach is more focused on freeing up personal data outside the EU because of UK companies, rather than to meet EU privacy rules. This is because the UK no longer is subject to EU law, so does not have to follow all EU privacy rules. Instead, it chooses to follow some of those rules to ensure consistency with global data practices and to maintain a competitive business environment. \n\n(Source: UK Government, "UK to become global leader in free',
#  "<s> ### Question: How does Japan's approach to AI regulation differ from that of the European Commission and Canada?\n Briefly, in 100 words answer the question. ### Answer: Japan's approach is characterized by a more gradual and pragmatic approach to AI regulation, focusing on maximizing social benefits rather than eliminating risks. In contrast, the EU's approach is more stringent and aimed at preventing harms, while Canada's is more inclusive and focused on a whole-of-government approach to AI governance. Japan does not have specific AI regulations, while the EU and Canada",
#  "<s> ### Question: What are foundational AI models, and why are they important?\n Briefly, in 100 words answer the question. ### Answer: Foundational AI models are basic algorithms that underlie many advanced AI applications. They're important because they're the building blocks for more complex AI systems, and their widespread adoption can improve many aspects of society.  Briefly, in 100 words answer the question. ### Answer: Foundational AI models are basic algorithms that underlie many advanced AI applications. They're important because they're the building blocks for more complex A",
#  '<s> ### Question: What additional measures are needed for international cooperation on foundational AI models?\n Briefly, in 100 words answer the question. ### Answer: AI regulatory sandboxes and joint assessments are needed to ensure that international cooperation on foundational AI models is productive. These sandboxes and joint assessments can help clarify the regulatory stance on foundational AI models and promote international collaboration on AI regulation. \n\nAI regulatory sandboxes and joint assessments can help clarify the regulatory stance on foundational AI models and promote international collaboration on AI regulation. They can',
#  '<s> ### Question: What are the focus tasks of China’s New Generation Artificial Intelligence Development? \n Briefly, in 100 words answer the question. ### Answer: The focus tasks include developing advanced AI applications, launching major AI products, promoting AI to small and medium-sized enterprises, and achieving major breakthroughs in core AI technologies. These tasks aim to strengthen China’s AI capabilities and promote AI application in various sectors. \n\nAI focus tasks include launching AI applications for government services, public services, and social management, promoting AI in medicine, launching',
#  "<s> ### Question: What are the economic, ethical, and strategic issues that call into question the continuation of collaboration on AI with China?\n Briefly, in 100 words answer the question. ### Answer: Economic: China's economic advantages from the free riding of international AI innovation and production pose an economic challenge. Ethical: China's use of AI for human rights abuses, such as surveillance in Xinjiang, raises ethical concerns. Briefly, in 100 words answer the question. ### Answer: Strategic: The equal collaboration of democratic and democratizing societies with China for AI innovation",
#  '<s> ### Question: What role has the World Bank played in supporting AI in the public sector?\n Briefly, in 100 words answer the question. ### Answer: The World Bank has supported the development of AI in the public sector through research, policy reviews, and technical assistance. It has also provided financial support for AI projects in some countries. Specifically, the World Bank contributed to the 2020 AI in Government Conference and the 2021 AI in Government Summit, demonstrating its commitment to the field. \nAI in Government Conference and the AI in Government Summit, demonstrating its commitment to',
#  '<s> ### Question: How can the AI assurance industry contribute to regulatory compliance and AI system improvement?\n Briefly, in 100 words answer the question. ### Answer: By providing assurance services that help companies identify and manage AI risks, the AI assurance industry can contribute to regulatory compliance and improve AI system performance. This includes identifying design and implementation gaps that may contribute to regulatory exposure, evaluating the effectiveness of AI system controls, and assessing the alignment of AI system performance with regulatory requirements. By doing so, the AI assurance industry can help companies operate their AI systems in a',
#  "<s> ### Question: What are some of the key principles outlined in the White House's Blueprint for an AI Bill of Rights? \n Briefly, in 100 words answer the question. ### Answer: Some of the key principles include ensuring AI is used in a manner that is safe, secure, and trustworthy; promoting AI innovation while addressing privacy and discrimination concerns; promoting competition in AI; supporting AI research; and advancing international cooperation on AI. \nKey areas include expanding privacy protections to cover AI, prohibiting biased AI, promoting responsible AI innovation with clear labeling requirements",
#  '<s> ### Question: What are main concerns in relation to AI policy?\n Briefly, in 100 words answer the question. ### Answer: Key concerns include ensuring AI safety and security, preventing AI-enabled evasion of regulation, and maximizing the economic and social benefits of AI. However, other concerns include ensuring AI safety and security, preventing AI-enabled evasion of regulation, and maximizing the economic and social benefits of AI. Some considerations include ensuring AI systems are safe and perform as intended, preventing discrimination and privacy violations, and',
#  '<s> ### Question: How is international cooperation on AI currently being pursued?\n Briefly, in 100 words answer the question. ### Answer: International cooperation is being pursued through various mechanisms such as AI agreements, multilateral agreements, and discussions in international organizations like the United Nations and the G20. These efforts aim to align policies and regulate AI technologically across countries, despite the potential risks to global governance and democracy. \n\nAI agreements are becoming more common, with 35 reported agreements between countries from 2019 to 2',
#  "<s> ### Question: What are the basic principles set forth by the Japanese government for AI regulation in 2019?\n Briefly, in 100 words answer the question. ### Answer: The basic principles include ensuring AI safety and security, promoting responsible AI innovation, and creating an AI-driven economic growth framework. They do not include specific regulations or enforceable provisions to implement these principles. \n\nAI is still largely unregulated, with most of its use covered by broad legal principles rather than specific AI-related laws. \n\nHowever, the government's AI white paper released in 2018",
#  "<s> ### Question: What is the World Bank's Policy on Access to Information?\n Briefly, in 100 words answer the question. ### Answer: The policy aims to make information available to the public and stakeholders, while also protecting the Bank's confidentiality obligations with its clients and partners. It outlines the types of information the Bank makes available, the terms and conditions for accessing that information, and the exceptions to access. \n\nAI: Broadly, in 100 words answer the question. ### Answer: The policy aims to make information available to the public and stakeholders"]

# %%
df_test_all['fine_tuned_llama_generations_with_lr_2e_4']=generations

# %%
df_test_all['fine_tuned_llama_generations_with_lr_1e_4']= df_test_all['fine_tuned_llama_generations_with_lr_1e_4'].apply(lambda x: x.split('Answer:', 1)[-1] if 'Answer:' in x else x)
df_test_all['fine_tuned_llama_generations_with_lr_1e_4']= df_test_all['fine_tuned_llama_generations_with_lr_1e_4'].apply(lambda x: x.replace('</s>', '').replace('<s>', '').replace('</s>s', '').replace('<s/>', '').replace('s ', ''))
df_test_all['fine_tuned_llama_generations_with_lr_2e_4']= df_test_all['fine_tuned_llama_generations_with_lr_2e_4'].apply(lambda x: x.split('Answer:', 1)[-1] if 'Answer:' in x else x)
df_test_all['fine_tuned_llama_generations_with_lr_2e_4']= df_test_all['fine_tuned_llama_generations_with_lr_2e_4'].apply(lambda x: x.replace('</s>', '').replace('<s>', '').replace('</s>s', '').replace('<s/>', '').replace('s ', ''))

df_test_all
# Out:
#                                                 input  \
# 0   Why is international cooperation on AI important?
# 1   Can you describe the approach taken by the res...
# 2   What concerns do critics have regarding the EU...
# 3   How does the European Union classify AI system...
# 4   What are the Universal Guidelines for Artifici...
# 5   What role do whistleblowers and complaints pla...
# 6   How's UK's approach different from that of the...
# 7   How does Japan's approach to AI regulation dif...
# 8   What are foundational AI models, and why are t...
# 9   What additional measures are needed for intern...
# 10  What are the focus tasks of China’s New Genera...
# 11  What are the economic, ethical, and strategic ...
# 12  What role has the World Bank played in support...
# 13  How can the AI assurance industry contribute t...
# 14  What are some of the key principles outlined i...
# 15   What are main concerns in relation to AI policy?
# 16  How is international cooperation on AI current...
# 17  What are the basic principles set forth by the...
# 18  What is the World Bank's Policy on Access to I...
#
#                                                output  __index_level_0__  \
# 0   International cooperation on AI is crucial due...                 70
# 1   The research team prepared generic interview p...                 21
# 2   Critics, including EU businesses, have express...                 37
# 3   The European Union's AI Act classifies AI syst...                 36
# 4   The Universal Guidelines include rights to tra...                 58
# 5   Whistleblowers and individual complaints are c...                 48
# 6   Unlike the European Union (EU), the UK’s appro...                 14
# 7   Japan focuses on a risk-based, agile, and mult...                 31
# 8   Foundational AI models, such as large language...                 60
# 9   The article suggests that more ambitious trade...                 64
# 10  (1) Build open and coordinated AI science and ...                  6
# 11  Issues include the ethical use of AI, strategi...                 78
# 12  The World Bank launched the GovTech Global Par...                 88
# 13  The AI assurance industry, comprising companie...                 49
# 14  The Blueprint emphasizes principles such as th...                 28
# 15  The need for AI policies to protect individual...                 55
# 16  Governments are regulating AI, and internation...                 62
# 17  In 2019, the Japanese government published the...                 30
# 18  The policy outlines the World Bank's commitmen...                 89
#
#             llama_generations_with_examples_prompting  \
# 0    International cooperation on AI iimportant be...
# 1    The research team took a multi-faceted approa...
# 2    Critichave several concernregarding the EU'AI...
# 3    The European Union classifieAI systemunder it...
# 4    EPIC (Electronic Privacy Information Center) ...
# 5    Whistleblowerand complaintplay a crucial role...
# 6    The UK'approach to AI ethicidifferent from th...
# 7    Japan'approach to AI regulation differfrom th...
# 8    Foundational AI modelare the basic building b...
# 9    Additional measureneeded for international co...
# 10   The focutaskof China’New Generation Artificia...
# 11   The economic, ethical, and strategic issuetha...
# 12   The World Bank haplayed a significant role in...
# 13   The AI assurance industry can contribute to r...
# 14   The White House'Blueprint for an AI Bill of R...
# 15   The main concernin relation to AI policy incl...
# 16   International cooperation on AI icurrently be...
# 17   The Japanese government set forth the followi...
# 18   The World Bank'policy on accesto information ...
#
#                            original_llama_generations  \
# 0    International cooperation on AI iimportant be...
# 1    The research team took a multi-faceted approa...
# 2    Criticargue that the EU'AI Act could stifle i...
# 3    The European Union classifieAI systemunder it...
# 4    The Universal Guidelinefor Artificial Intelli...
# 5    Whistleblowerand complaintplay a crucial role...
# 6    The UK'approach to data protection idifferent...
# 7    Japan'approach to AI regulation differfrom th...
# 8    Foundational AI modelare the fundamental buil...
# 9    International cooperation on foundational AI ...
# 10   The focutaskof China'New Generation Artificia...
# 11   The economic, ethical, and strategic issuetha...
# 12   The World Bank haplayed a significant role in...
# 13   The AI assurance industry can contribute to r...
# 14   The White House'Blueprint for an AI Bill of R...
# 15   The main concernin relation to AI policy incl...
# 16   International cooperation on AI icurrently be...
# 17   In 2019, the Japanese government established ...
# 18   The World Bank'policy on accesto information ...
#
#             fine_tuned_llama_generations_with_lr_1e_4  \
# 0    International cooperation on AI iimportant fo...
# 1    The research team adopted a structured interv...
# 2    Criticworry that the AI Act'strict review pro...
# 3    The EU define"high-risk" AI systemathose that...
# 4    Freeze the development and deployment of auto...
# 5    Timely and accurate whistleblower reportand c...
# 6    UK'approach imore focused on freeing industri...
# 7    Japan'approach to AI regulation emphasizemaxi...
# 8    Foundational AI modelare basic algorithmthat ...
# 9    A comprehensive and balanced approach to addr...
# 10   Focutaskinclude developing common-purpose int...
# 11   Economic: Risk of economic competition with t...
# 12   The World Bank haissued policy guidelineand c...
# 13   By focusing on assuring AI systemare safe and...
# 14   The blueprint emphasizethe importance of tran...
# 15   Key concerninclude the effectivenesand enforc...
# 16   Stateare coordinating through varioufora such...
# 17   The basic principleinclude a risk-based appro...
# 18   The policy aimto promote transparency and acc...
#
#             fine_tuned_llama_generations_with_lr_2e_4
# 0    International cooperation on AI iimportant fo...
# 1    The research team prepared by reviewing key p...
# 2    Criticargue that the AI Act'extensive risk as...
# 3    The AI Act divideAI systeminto "compliant" an...
# 4    They call for adhering to human rightprincipl...
# 5    Whistleblowerand complaintprovide vital infor...
# 6    UK'approach imore focused on freeing up perso...
# 7    Japan'approach icharacterized by a more gradu...
# 8    Foundational AI modelare basic algorithmthat ...
# 9    AI regulatory sandboxeand joint assessmentare...
# 10   The focutaskinclude developing advanced AI ap...
# 11   Economic: China'economic advantagefrom the fr...
# 12   The World Bank hasupported the development of...
# 13   By providing assurance servicethat help compa...
# 14   Some of the key principleinclude ensuring AI ...
# 15   Key concerninclude ensuring AI safety and sec...
# 16   International cooperation ibeing pursued thro...
# 17   The basic principleinclude ensuring AI safety...
# 18   The policy aimto make information available t...

# %%
fine_tuned_model_lr_1e_4_metrics = df_test_all.apply(lambda x: calculate_bleu_rouge(x['output'], x['fine_tuned_llama_generations_with_lr_1e_4']), axis=1)
fine_tuned_model_lr_1e_4_metrics = np.array(fine_tuned_model_lr_1e_4_metrics).mean(-1)
fine_tuned_model_lr_1e_4_metrics
# Out:
# array([0.0076286 , 0.20546275, 0.03782667, 0.1833351 ], dtype=float32)

# %%
fine_tuned_model_lr_2e_4_metrics = df_test_all.apply(lambda x: calculate_bleu_rouge(x['output'], x['fine_tuned_llama_generations_with_lr_2e_4']), axis=1)
fine_tuned_model_lr_2e_4_metrics = np.array(fine_tuned_model_lr_2e_4_metrics).mean(-1)
fine_tuned_model_lr_2e_4_metrics
# Out:
# array([0.00554268, 0.22923876, 0.0321188 , 0.20402806], dtype=float32)

# %%
df_metrics = pd.DataFrame([raw_model_metrics, fine_tuned_model_lr_1e_4_metrics, fine_tuned_model_lr_2e_4_metrics], columns=['BLEU_Score', 'ROUGE-1', 'ROUGE-2', 'ROUGE-l'])
df_metrics.index  = ['Raw_llama2', 'Fine_tuned_llama2_lr_1e_4_metrics', 'Fine_tuned_llama2_lr_2e_4_metrics']
df_metrics
# Out:
#                                    BLEU_Score   ROUGE-1   ROUGE-2   ROUGE-l
# Raw_llama2                           0.006988  0.287063  0.056603  0.235454
# Fine_tuned_llama2_lr_1e_4_metrics    0.007629  0.205463  0.037827  0.183335
# Fine_tuned_llama2_lr_2e_4_metrics    0.005543  0.229239  0.032119  0.204028
