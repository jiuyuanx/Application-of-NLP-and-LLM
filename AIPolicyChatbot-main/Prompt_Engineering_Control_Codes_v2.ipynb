# %% [markdown]
# <a href="https://colab.research.google.com/github/VaLeRiEe37/AIPolicyChatbot/blob/main/Prompt_Engineering_Control_Codes_v2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install -q  torch peft==0.4.0 bitsandbytes==0.40.2 transformers==4.31.0 trl==0.4.7 accelerate datasets
import torch
import datasets
from datasets import load_dataset
from transformers import (
    AutoModelForCausalLM,
    AutoTokenizer,
    BitsAndBytesConfig,
    TrainingArguments,
    pipeline
)
from peft import LoraConfig
from trl import SFTTrainer
from datasets import Dataset, DatasetDict, load_dataset
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 72.9/72.9 kB 1.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 92.5/92.5 MB 10.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.4/7.4 MB 47.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 77.4/77.4 kB 4.8 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 280.0/280.0 kB 29.3 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 536.7/536.7 kB 29.3 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.8/7.8 MB 50.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 116.3/116.3 kB 14.0 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 134.8/134.8 kB 16.9 MB/s eta 0:00:00

# %% [markdown]
# ## **Load dataset from HuggingFace**

# %%
# Dataset
data_name = "jiuyuan/policy_AI"
training_data = load_dataset(data_name, split="train")
test_data = load_dataset(data_name, split="test")
# Out:
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_token.py:88: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# Downloading readme:   0%|          | 0.00/461 [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/32.8k [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/9.46k [00:00<?, ?B/s]
# Generating train split:   0%|          | 0/75 [00:00<?, ? examples/s]
# Generating test split:   0%|          | 0/19 [00:00<?, ? examples/s]

# %%
df_test = test_data.to_pandas()
df_test
# Out:
#                                                 input  \
# 0   Why is international cooperation on AI important?
# 1   Can you describe the approach taken by the res...
# 2   What concerns do critics have regarding the EU...
# 3   How does the European Union classify AI system...
# 4   What are the Universal Guidelines for Artifici...
# 5   What role do whistleblowers and complaints pla...
# 6   How's UK's approach different from that of the...
# 7   How does Japan's approach to AI regulation dif...
# 8   What are foundational AI models, and why are t...
# 9   What additional measures are needed for intern...
# 10  What are the focus tasks of China’s New Genera...
# 11  What are the economic, ethical, and strategic ...
# 12  What role has the World Bank played in support...
# 13  How can the AI assurance industry contribute t...
# 14  What are some of the key principles outlined i...
# 15   What are main concerns in relation to AI policy?
# 16  How is international cooperation on AI current...
# 17  What are the basic principles set forth by the...
# 18  What is the World Bank's Policy on Access to I...
#
#                                                output  __index_level_0__
# 0   International cooperation on AI is crucial due...                 70
# 1   The research team prepared generic interview p...                 21
# 2   Critics, including EU businesses, have express...                 37
# 3   The European Union's AI Act classifies AI syst...                 36
# 4   The Universal Guidelines include rights to tra...                 58
# 5   Whistleblowers and individual complaints are c...                 48
# 6   Unlike the European Union (EU), the UK’s appro...                 14
# 7   Japan focuses on a risk-based, agile, and mult...                 31
# 8   Foundational AI models, such as large language...                 60
# 9   The article suggests that more ambitious trade...                 64
# 10  (1) Build open and coordinated AI science and ...                  6
# 11  Issues include the ethical use of AI, strategi...                 78
# 12  The World Bank launched the GovTech Global Par...                 88
# 13  The AI assurance industry, comprising companie...                 49
# 14  The Blueprint emphasizes principles such as th...                 28
# 15  The need for AI policies to protect individual...                 55
# 16  Governments are regulating AI, and internation...                 62
# 17  In 2019, the Japanese government published the...                 30
# 18  The policy outlines the World Bank's commitmen...                 89

# %%
df_test[['input']].to_csv('prompts.csv', )

# %%
import pandas as pd
df_prompt = pd.read_csv("control_codes_prompts.csv", encoding='ISO-8859-1')
df_prompt['prompt_engineering'] = df_prompt['prompt_engineering']
df_prompt
# Out:
#                                                 input  \
# 0   Why is international cooperation on AI important?
# 1   Can you describe the approach taken by the res...
# 2   What concerns do critics have regarding the EU...
# 3   How does the European Union classify AI system...
# 4   What are the Universal Guidelines for Artifici...
# 5   What role do whistleblowers and complaints pla...
# 6   How's UK's approach different from that of the...
# 7   How does Japan's approach to AI regulation dif...
# 8   What are foundational AI models, and why are t...
# 9   What additional measures are needed for intern...
# 10  What are the focus tasks of Chinaâs New Gene...
# 11  What are the economic, ethical, and strategic ...
# 12  What role has the World Bank played in support...
# 13  How can the AI assurance industry contribute t...
# 14  What are some of the key principles outlined i...
# 15   What are main concerns in relation to AI policy?
# 16  How is international cooperation on AI current...
# 17  What are the basic principles set forth by the...
# 18  What is the World Bank's Policy on Access to I...
#
#                                    prompt_engineering
# 0   [International Cooperation] Why is internation...
# 1   [Research Approach] Can you describe the appro...
# 2   [EU AI Act Criticism] What concerns do critics...
# 3   [EU AI Classification] How does the European U...
# 4   [AI Ethics Guidelines] What are the Universal ...
# 5   [Regulatory Process] What role do whistleblowe...
# 6   [UK AI Strategy] How's UK's approach different...
# 7   [Japan AI Regulation] How does Japan's approac...
# 8   [Foundational AI Models] What are foundational...
# 9   [AI Cooperation Measures] What additional meas...
# 10  [China AI Focus] What are the focus tasks of C...
# 11  [AI Collaboration Ethics] What are the economi...
# 12  [World Bank AI Support] What role has the Worl...
# 13  [AI Assurance Industry] How can the AI assuran...
# 14  [AI Bill of Rights] What are some of the key p...
# 15  [AI Policy Concerns] What are main concerns in...
# 16  [AI Cooperation Pursuit] How is international ...
# 17  [Japan AI Regulation 2019] What are the basic ...
# 18  [World Bank Information Access] What is the Wo...

# %%
def prompt_engineering(df):
    output_texts = []

    for i in range(len(df['input'])):
        row = df.iloc[i]
        text = f"### Question: {row['input']}\n Briefly, in 100 words answer the question: {row['prompt_engineering']} \n ### Answer: </s>"
        output_texts.append(text)
    return output_texts

df_prompt['prompt']= prompt_engineering(df_prompt)
print(df_prompt.iloc[0]['prompt'])
df_prompt
# Out:
# ### Question: Why is international cooperation on AI important?
#  Briefly, in 100 words answer the question: [International Cooperation] Why is international cooperation on AI important?
#  ### Answer: </s>
#                                                 input  \
# 0   Why is international cooperation on AI important?
# 1   Can you describe the approach taken by the res...
# 2   What concerns do critics have regarding the EU...
# 3   How does the European Union classify AI system...
# 4   What are the Universal Guidelines for Artifici...
# 5   What role do whistleblowers and complaints pla...
# 6   How's UK's approach different from that of the...
# 7   How does Japan's approach to AI regulation dif...
# 8   What are foundational AI models, and why are t...
# 9   What additional measures are needed for intern...
# 10  What are the focus tasks of Chinaâs New Gene...
# 11  What are the economic, ethical, and strategic ...
# 12  What role has the World Bank played in support...
# 13  How can the AI assurance industry contribute t...
# 14  What are some of the key principles outlined i...
# 15   What are main concerns in relation to AI policy?
# 16  How is international cooperation on AI current...
# 17  What are the basic principles set forth by the...
# 18  What is the World Bank's Policy on Access to I...
#
#                                    prompt_engineering  \
# 0   [International Cooperation] Why is internation...
# 1   [Research Approach] Can you describe the appro...
# 2   [EU AI Act Criticism] What concerns do critics...
# 3   [EU AI Classification] How does the European U...
# 4   [AI Ethics Guidelines] What are the Universal ...
# 5   [Regulatory Process] What role do whistleblowe...
# 6   [UK AI Strategy] How's UK's approach different...
# 7   [Japan AI Regulation] How does Japan's approac...
# 8   [Foundational AI Models] What are foundational...
# 9   [AI Cooperation Measures] What additional meas...
# 10  [China AI Focus] What are the focus tasks of C...
# 11  [AI Collaboration Ethics] What are the economi...
# 12  [World Bank AI Support] What role has the Worl...
# 13  [AI Assurance Industry] How can the AI assuran...
# 14  [AI Bill of Rights] What are some of the key p...
# 15  [AI Policy Concerns] What are main concerns in...
# 16  [AI Cooperation Pursuit] How is international ...
# 17  [Japan AI Regulation 2019] What are the basic ...
# 18  [World Bank Information Access] What is the Wo...
#
#                                                prompt
# 0   ### Question: Why is international cooperation...
# 1   ### Question: Can you describe the approach ta...
# 2   ### Question: What concerns do critics have re...
# 3   ### Question: How does the European Union clas...
# 4   ### Question: What are the Universal Guideline...
# 5   ### Question: What role do whistleblowers and ...
# 6   ### Question: How's UK's approach different fr...
# 7   ### Question: How does Japan's approach to AI ...
# 8   ### Question: What are foundational AI models,...
# 9   ### Question: What additional measures are nee...
# 10  ### Question: What are the focus tasks of Chin...
# 11  ### Question: What are the economic, ethical, ...
# 12  ### Question: What role has the World Bank pla...
# 13  ### Question: How can the AI assurance industr...
# 14  ### Question: What are some of the key princip...
# 15  ### Question: What are main concerns in relati...
# 16  ### Question: How is international cooperation...
# 17  ### Question: What are the basic principles se...
# 18  ### Question: What is the World Bank's Policy ...

# %%
# from google.colab import drive
# drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# Model and tokenizer names
base_model_name = "NousResearch/Llama-2-7b-chat-hf"
refined_model = "llama-2-7b-mlabonne-enhanced"

# Tokenizer
llama_tokenizer = AutoTokenizer.from_pretrained(base_model_name, trust_remote_code=True)
llama_tokenizer.pad_token = llama_tokenizer.eos_token
llama_tokenizer.padding_side = "right"  # Fix for fp16

# Quantization Config
quant_config = BitsAndBytesConfig(
    load_in_4bit=True,
    bnb_4bit_quant_type="nf4",
    bnb_4bit_compute_dtype=torch.float16,
    bnb_4bit_use_double_quant=False
)

# Model
base_model = AutoModelForCausalLM.from_pretrained(
    base_model_name,
    quantization_config=quant_config,
    device_map={"": 0}
)
base_model.config.use_cache = False
base_model.config.pretraining_tp = 1
# Out:
# tokenizer_config.json:   0%|          | 0.00/746 [00:00<?, ?B/s]
# tokenizer.model:   0%|          | 0.00/500k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/1.84M [00:00<?, ?B/s]
# added_tokens.json:   0%|          | 0.00/21.0 [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/435 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/583 [00:00<?, ?B/s]
# model.safetensors.index.json:   0%|          | 0.00/26.8k [00:00<?, ?B/s]
# Downloading shards:   0%|          | 0/2 [00:00<?, ?it/s]
# model-00001-of-00002.safetensors:   0%|          | 0.00/9.98G [00:00<?, ?B/s]
# model-00002-of-00002.safetensors:   0%|          | 0.00/3.50G [00:00<?, ?B/s]
# Loading checkpoint shards:   0%|          | 0/2 [00:00<?, ?it/s]
# generation_config.json:   0%|          | 0.00/179 [00:00<?, ?B/s]

# %% [markdown]
# ## **Generations & Evaluation**

# %%
df_test_all=test_data.to_pandas()
df_train=training_data.to_pandas()
df_test_all
# Out:
#                                                 input  \
# 0   Why is international cooperation on AI important?
# 1   Can you describe the approach taken by the res...
# 2   What concerns do critics have regarding the EU...
# 3   How does the European Union classify AI system...
# 4   What are the Universal Guidelines for Artifici...
# 5   What role do whistleblowers and complaints pla...
# 6   How's UK's approach different from that of the...
# 7   How does Japan's approach to AI regulation dif...
# 8   What are foundational AI models, and why are t...
# 9   What additional measures are needed for intern...
# 10  What are the focus tasks of China’s New Genera...
# 11  What are the economic, ethical, and strategic ...
# 12  What role has the World Bank played in support...
# 13  How can the AI assurance industry contribute t...
# 14  What are some of the key principles outlined i...
# 15   What are main concerns in relation to AI policy?
# 16  How is international cooperation on AI current...
# 17  What are the basic principles set forth by the...
# 18  What is the World Bank's Policy on Access to I...
#
#                                                output  __index_level_0__
# 0   International cooperation on AI is crucial due...                 70
# 1   The research team prepared generic interview p...                 21
# 2   Critics, including EU businesses, have express...                 37
# 3   The European Union's AI Act classifies AI syst...                 36
# 4   The Universal Guidelines include rights to tra...                 58
# 5   Whistleblowers and individual complaints are c...                 48
# 6   Unlike the European Union (EU), the UK’s appro...                 14
# 7   Japan focuses on a risk-based, agile, and mult...                 31
# 8   Foundational AI models, such as large language...                 60
# 9   The article suggests that more ambitious trade...                 64
# 10  (1) Build open and coordinated AI science and ...                  6
# 11  Issues include the ethical use of AI, strategi...                 78
# 12  The World Bank launched the GovTech Global Par...                 88
# 13  The AI assurance industry, comprising companie...                 49
# 14  The Blueprint emphasizes principles such as th...                 28
# 15  The need for AI policies to protect individual...                 55
# 16  Governments are regulating AI, and internation...                 62
# 17  In 2019, the Japanese government published the...                 30
# 18  The policy outlines the World Bank's commitmen...                 89

# %%
df_test_all['output'].apply(lambda x:len(x.split())).describe(), df_train['output'].apply(lambda x:len(x.split())).describe()
# Out:
# (count    19.000000
#  mean     40.631579
#  std      11.591235
#  min      17.000000
#  25%      33.000000
#  50%      41.000000
#  75%      48.500000
#  max      61.000000
#  Name: output, dtype: float64,
#  count      75.000000
#  mean       73.893333
#  std       136.433092
#  min        21.000000
#  25%        31.000000
#  50%        38.000000
#  75%        52.500000
#  max      1020.000000
#  Name: output, dtype: float64)

# %%
from tqdm.notebook import tqdm
import gc
generations_prompt_engineer_controlcodes =[]
for i in tqdm(range(len(df_prompt)), "generating..."):
  prompt = df_prompt.iloc[i]['prompt']
  # Generate predictions
  inputs = llama_tokenizer(prompt, return_tensors='pt')
  inputs = inputs.to("cuda")
  output = base_model.generate(**inputs, max_new_tokens=200,temperature=0.2)
  response = llama_tokenizer.decode(output[0].tolist())
  print(response)
  # break
  generations_prompt_engineer_controlcodes.append(response)
  del inputs, output
  gc.collect()
  torch.cuda.empty_cache()
# Out:
# generating...:   0%|          | 0/19 [00:00<?, ?it/s]
# /usr/local/lib/python3.10/dist-packages/transformers/generation/utils.py:1270: UserWarning: You have modified the pretrained model configuration to control generation. This is a deprecated strategy to control generation and will be removed soon, in a future version. Please use a generation configuration file (see https://huggingface.co/docs/transformers/main_classes/text_generation )
#   warnings.warn(
# <s> ### Question: Why is international cooperation on AI important?
#  Briefly, in 100 words answer the question: [International Cooperation] Why is international cooperation on AI important?
#  ### Answer:</s>
# International cooperation on AI is important for several reasons:
#
# 1. Sharing knowledge and expertise: By working together, countries can pool their resources and expertise to advance the field of AI.
# 2. Setting global standards: International cooperation can help establish common standards and guidelines for the development and use of AI, ensuring consistency and fairness across different countries.
# 3. Addressing ethical and social implications: AI raises a range of ethical and social concerns, such as privacy, bias, and job displacement. International cooperation can help address these issues through joint research and policy development.
# 4. Promoting innovation and economic growth: International cooperation can foster innovation and economic growth by encouraging the exchange of ideas and collaboration on AI-related research and development projects.
# 5. Enhancing global security: AI can be used for malicious purposes, such as cyber
# <s> ### Question: Can you describe the approach taken by the research team in preparing for the interviews with academia and industry experts in the AI assessment?
#  Briefly, in 100 words answer the question: [Research Approach] Can you describe the approach taken by the research team in preparing for the interviews with academia and industry experts in the AI assessment?
#  ### Answer:</s>: The research team took a multi-faceted approach in preparing for the interviews with academia and industry experts in the AI assessment. First, they conducted a comprehensive literature review to identify key themes and trends in AI research and applications. They also analyzed industry reports and white papers to gain insights into the current state of AI in various sectors. Next, they developed a set of interview questions that covered a range of topics, including AI applications, challenges, and future directions. Finally, they reached out to potential interviewees and secured commitments from a diverse group of experts, including researchers, entrepreneurs, and industry leaders. By taking a thorough and strategic approach, the research team was able to gather valuable insights and perspectives from a range of experts in the field.</s>
# <s> ### Question: What concerns do critics have regarding the EU's AI Act's potential impact on innovation and competitiveness?
#  Briefly, in 100 words answer the question: [EU AI Act Criticism] What concerns do critics have regarding the EU's AI Act's potential impact on innovation and competitiveness?
#  ### Answer:</s>s
# Critics argue that the EU's AI Act could stifle innovation and competitiveness by imposing overly restrictive regulations on AI development and deployment. They fear that the Act's requirements for transparency, accountability, and ethical use could lead to increased costs, complexity, and bureaucracy, making it harder for European companies to compete with their global peers. Additionally, some critics argue that the Act could hinder the development of cutting-edge AI technologies, such as those based on machine learning, by creating uncertainty and regulatory hurdles that could slow down the pace of innovation.</s>
# <s> ### Question: How does the European Union classify AI systems under its AI Act, and what are the implications for "high risk" AI systems?
#  Briefly, in 100 words answer the question: [EU AI Classification] How does the European Union classify AI systems under its AI Act, and what are the implications for "high risk" AI systems?
#  ### Answer:</s>
# The European Union (EU) classifies AI systems under its AI Act into three categories: (1) low-risk AI systems, (2) high-risk AI systems, and (3) unacceptable AI systems. High-risk AI systems are those that can pose a significant risk to individuals, society, or the environment, such as those that are used for critical applications like healthcare or transportation. The EU's AI Act requires that high-risk AI systems be subject to a rigorous assessment and oversight process, including a risk assessment, testing, and validation, before they can be placed on the market. The implications for high-risk AI systems are stricter regulations and oversight, which can include requirements for transparency, accountability, and liability.</s>
# <s> ### Question: What are the Universal Guidelines for Artificial Intelligence endorsed by EPIC?
#  Briefly, in 100 words answer the question: [AI Ethics Guidelines] What are the Universal Guidelines for Artificial Intelligence endorsed by EPIC?
#  ### Answer:</s>...
#
# The Universal Guidelines for Artificial Intelligence (AI) endorsed by the Electronic Privacy Information Center (EPIC) are a set of principles and recommendations for the ethical development and use of AI. The guidelines cover areas such as transparency, accountability, fairness, and privacy, and are intended to promote responsible and ethical AI development and deployment. The guidelines also emphasize the importance of human oversight and review, and provide recommendations for ensuring that AI systems are aligned with human values and ethical principles.</s>
# <s> ### Question: What role do whistleblowers and complaints play in the AI regulatory process?
#  Briefly, in 100 words answer the question: [Regulatory Process] What role do whistleblowers and complaints play in the AI regulatory process?
#  ### Answer:</s><s> nobody
# Whistleblowers and complaints play a crucial role in the AI regulatory process by serving as early warning systems for potential misuses or abuses of AI. They provide valuable information that can help regulators identify and address emerging risks and issues, such as biased algorithms, privacy violations, or autonomous weapons. By reporting concerns or suspected violations, whistleblowers and complainants can help ensure that AI is developed and used in ways that are ethical, responsible, and transparent.</s>
# <s> ### Question: How's UK's approach different from that of the European Union?
#  Briefly, in 100 words answer the question: [UK AI Strategy] How's UK's approach different from that of the European Union?
#  ### Answer:</s>...the UK's approach is more focused on the development of AI technologies and their application in specific sectors, such as healthcare and transport, whereas the EU's approach is more focused on ensuring ethical and responsible use of AI and protecting individual rights and freedoms.</s>
# <s> ### Question: How does Japan's approach to AI regulation differ from that of the European Commission and Canada?
#  Briefly, in 100 words answer the question: [Japan AI Regulation] How does Japan's approach to AI regulation differ from that of the European Commission and Canada?
#  ### Answer:</s>
# Japan's approach to AI regulation differs from that of the European Commission and Canada in several ways. While the European Commission has adopted a comprehensive framework for AI regulation, including the establishment of a new agency to oversee AI development and deployment, Japan has taken a more incremental approach, focusing on specific sectors such as autonomous vehicles and medical AI. Additionally, Japan has placed a greater emphasis on collaboration between industry and government, while the European Commission has taken a more prescriptive approach. Canada has also taken a more incremental approach, focusing on specific areas such as data privacy and security.</s>
# <s> ### Question: What are foundational AI models, and why are they important?
#  Briefly, in 100 words answer the question: [Foundational AI Models] What are foundational AI models, and why are they important?
#  ### Answer:</s>... foundational AI models are the basic building blocks of AI systems, such as decision trees, neural networks, and support vector machines. These models are important because they provide a framework for understanding how AI systems work and how they can be applied to different problems. By understanding the foundational models, researchers and practitioners can develop more advanced AI systems and improve the performance of existing ones. Additionally, foundational models can serve as a basis for evaluating the performance of AI systems and for developing new models that can solve complex problems.</s>
# <s> ### Question: What additional measures are needed for international cooperation on foundational AI models?
#  Briefly, in 100 words answer the question: [AI Cooperation Measures] What additional measures are needed for international cooperation on foundational AI models?
#  ### Answer:</s>
# To facilitate international cooperation on foundational AI models, additional measures can be taken, such as:
#
# 1. Establishing common standards and frameworks for AI model development and deployment.
# 2. Encouraging collaboration and knowledge-sharing among researchers and developers through workshops, conferences, and other events.
# 3. Developing and implementing ethical guidelines for AI model development and use, such as those related to privacy, fairness, and accountability.
# 4. Providing training and capacity-building programs for researchers and developers in developing countries to enhance their capabilities in AI model development.
# 5. Encouraging the development of AI models that are transparent, explainable, and interpretable, to increase trust and understanding among stakeholders.
# 6. Fostering dialogue and cooperation among governments, industry leaders, and civil society organizations to ensure that AI
# <s> ### Question: What are the focus tasks of Chinaâs New Generation Artificial Intelligence Development?
#  Briefly, in 100 words answer the question: [China AI Focus] What are the focus tasks of ChinaÕs New Generation Artificial Intelligence Development?
#  ### Answer:</s>s
# China's New Generation Artificial Intelligence Development focuses on several key tasks, including:
#
# 1. Natural Language Processing (NLP): Developing AI systems that can understand and generate human-like language, with applications in areas like chatbots, language translation, and text summarization.
# 2. Computer Vision: Developing AI systems that can interpret and analyze visual data from images and videos, with applications in areas like facial recognition, object detection, and autonomous driving.
# 3. Robotics: Developing AI-powered robots that can perform tasks that typically require human intelligence, such as assembly, maintenance, and logistics.
# 4. Healthcare: Developing AI systems that can diagnose diseases, develop personalized treatment plans, and improve patient outcomes.
# 5. Education: Developing AI-powered educational tools that can personalize learning experiences for students, improve educational out
# <s> ### Question: What are the economic, ethical, and strategic issues that call into question the continuation of collaboration on AI with China?
#  Briefly, in 100 words answer the question: [AI Collaboration Ethics] What are the economic, ethical, and strategic issues that call into question the continuation of collaboration on AI with China?
#  ### Answer:</s><s> nobody likes a tattle-tale, but sometimes it's necessary to speak up when something is amiss. the same goes for ai collaboration. while it can be tempting to overlook ethical concerns for the sake of economic gain, doing so can lead to unintended consequences that ultimately harm everyone involved. here are some of the economic, ethical, and strategic issues that call into question the continuation of collaboration on ai with china:
#
# economic issues:
#
# 1. intellectual property theft: china has a history of stealing intellectual property from foreign companies, including those in the ai field. this can lead to the loss of competitive advantage and potential financial losses for companies that collaborate with china.
#
# 2. forced technology transfer: china has been accused of forcing foreign companies to transfer their technology to local partners in exchange for access to the chinese market. this can be particularly problematic in the ai
# <s> ### Question: What role has the World Bank played in supporting AI in the public sector?
#  Briefly, in 100 words answer the question: [World Bank AI Support] What role has the World Bank played in supporting AI in the public sector?
#  ### Answer:</s>
# The World Bank has played a significant role in supporting AI in the public sector through its various initiatives and programs. For instance, the World Bank's Artificial Intelligence for Development (AI4D) program aims to promote the ethical and responsible use of AI in developing countries, while its Digital Development Finance (DDF) program provides financing for digital infrastructure and innovation projects, including AI-related initiatives. Additionally, the World Bank has launched the AI for Good initiative, which brings together governments, private sector companies, and civil society organizations to develop and deploy AI solutions that address pressing social and environmental challenges. Through these and other initiatives, the World Bank has demonstrated its commitment to supporting the responsible and impactful use of AI in the public sector.</s>
# <s> ### Question: How can the AI assurance industry contribute to regulatory compliance and AI system improvement?
#  Briefly, in 100 words answer the question: [AI Assurance Industry] How can the AI assurance industry contribute to regulatory compliance and AI system improvement?
#  ### Answer:</s><s> nobody
# The AI assurance industry can contribute to regulatory compliance and AI system improvement by providing independent, third-party assessments of AI systems to ensure they are operating within legal and ethical boundaries. These assessments can help identify potential risks and vulnerabilities, and provide recommendations for improvement. Additionally, the AI assurance industry can work with regulators and standards bodies to develop and implement industry-wide standards and guidelines for AI system development and deployment, ensuring that AI systems are designed and deployed in a way that is transparent, accountable, and trustworthy. By doing so, the AI assurance industry can help build trust in AI systems and promote their widespread adoption.</s>
# <s> ### Question: What are some of the key principles outlined in the White House's Blueprint for an AI Bill of Rights?
#  Briefly, in 100 words answer the question: [AI Bill of Rights] What are some of the key principles outlined in the White House's Blueprint for an AI Bill of Rights?
#  ### Answer:</s>...the White House's Blueprint for an AI Bill of Rights outlines several key principles for the ethical development and use of artificial intelligence (AI). These principles include:
#
# 1. Transparency: AI systems should be transparent about their performance and decision-making processes.
# 2. Accountability: Developers and users of AI systems should be held accountable for any harm caused by their systems.
# 3. Fairness: AI systems should not discriminate against any individual or group based on their race, gender, religion, or other personal characteristic.
# 4. Privacy: AI systems should protect the privacy and security of personal data.
# 5. Safety: AI systems should be designed and deployed with safety in mind, to minimize the risk of harm to individuals or communities.
# 6. Inclusivity: AI systems should be accessible and beneficial to all individuals and communities, regardless of their background or socio
# <s> ### Question: What are main concerns in relation to AI policy?
#  Briefly, in 100 words answer the question: [AI Policy Concerns] What are main concerns in relation to AI policy?
#  ### Answer:</s>
# There are several concerns related to AI policy, including:
#
# 1. Bias and discrimination: Ensuring that AI systems do not perpetuate or exacerbate existing biases and discrimination.
# 2. Privacy: Protecting individuals' personal information and ensuring that AI systems do not infringe on their privacy rights.
# 3. Job displacement: Addressing the potential impact of AI on employment and ensuring that workers are not displaced by automation.
# 4. Safety and reliability: Ensuring that AI systems are safe and reliable, and do not pose a risk to individuals or society.
# 5. Transparency and explainability: Ensuring that AI systems are transparent and understandable, so that individuals can trust their decisions and actions.
# 6. Security: Protecting AI systems and their data from cyber threats and ensuring that they are secure
# <s> ### Question: How is international cooperation on AI currently being pursued?
#  Briefly, in 100 words answer the question: [AI Cooperation Pursuit] How is international cooperation on AI currently being pursued?
#  ### Answer:</s>t is currently being pursued through various initiatives such as the G7 AI Roundtable, the OECD Principles on Artificial Intelligence, and the AI for Good Global Summit. These initiatives aim to promote collaboration and coordination among countries to ensure that AI is developed and used in a responsible and ethical manner, and to address issues such as data privacy, security, and inclusivity. Additionally, many countries are establishing national AI strategies and setting up AI-related research and development centers to further advance the field.</s>
# <s> ### Question: What are the basic principles set forth by the Japanese government for AI regulation in 2019?
#  Briefly, in 100 words answer the question: [Japan AI Regulation 2019] What are the basic principles set forth by the Japanese government for AI regulation in 2019?
#  ### Answer:</s>...the Japanese government set forth the following basic principles for AI regulation in 2019:
#
# 1. Safety and Reliability: Ensuring AI systems are safe and reliable, and do not pose a threat to people's lives or property.
# 2. Respect for Human Rights: Ensuring AI systems do not infringe on human rights, such as privacy, non-discrimination, and freedom of expression.
# 3. Transparency and Explainability: Ensuring AI systems are transparent and understandable, and that their decision-making processes can be explained to users.
# 4. Accountability and Responsibility: Ensuring those responsible for developing and using AI systems are held accountable for any adverse consequences.
# 5. Continuous Monitoring and Improvement: Continuously monitoring and improving AI systems to ensure they remain safe, reliable, and ethical.
# <s> ### Question: What is the World Bank's Policy on Access to Information?
#  Briefly, in 100 words answer the question: [World Bank Information Access] What is the World Bank's Policy on Access to Information?
#  ### Answer:</s>
# The World Bank's Policy on Access to Information (ATI) aims to promote transparency and accountability by providing the public with access to information on its activities, operations, and decision-making processes. The policy sets out the rights of requesters, the types of information that are available, and the procedures for requesting and disclosing information. The World Bank also has a dedicated website for accessing and sharing information, called the World Bank Open Data.</s>

# %%
df_test['prompt_engineering_control_codes_generations']=generations_prompt_engineer_controlcodes
df_test
# Out:
#                                                 input  \
# 0   Why is international cooperation on AI important?
# 1   Can you describe the approach taken by the res...
# 2   What concerns do critics have regarding the EU...
# 3   How does the European Union classify AI system...
# 4   What are the Universal Guidelines for Artifici...
# 5   What role do whistleblowers and complaints pla...
# 6   How's UK's approach different from that of the...
# 7   How does Japan's approach to AI regulation dif...
# 8   What are foundational AI models, and why are t...
# 9   What additional measures are needed for intern...
# 10  What are the focus tasks of China’s New Genera...
# 11  What are the economic, ethical, and strategic ...
# 12  What role has the World Bank played in support...
# 13  How can the AI assurance industry contribute t...
# 14  What are some of the key principles outlined i...
# 15   What are main concerns in relation to AI policy?
# 16  How is international cooperation on AI current...
# 17  What are the basic principles set forth by the...
# 18  What is the World Bank's Policy on Access to I...
#
#                                                output  __index_level_0__  \
# 0   International cooperation on AI is crucial due...                 70
# 1   The research team prepared generic interview p...                 21
# 2   Critics, including EU businesses, have express...                 37
# 3   The European Union's AI Act classifies AI syst...                 36
# 4   The Universal Guidelines include rights to tra...                 58
# 5   Whistleblowers and individual complaints are c...                 48
# 6   Unlike the European Union (EU), the UK’s appro...                 14
# 7   Japan focuses on a risk-based, agile, and mult...                 31
# 8   Foundational AI models, such as large language...                 60
# 9   The article suggests that more ambitious trade...                 64
# 10  (1) Build open and coordinated AI science and ...                  6
# 11  Issues include the ethical use of AI, strategi...                 78
# 12  The World Bank launched the GovTech Global Par...                 88
# 13  The AI assurance industry, comprising companie...                 49
# 14  The Blueprint emphasizes principles such as th...                 28
# 15  The need for AI policies to protect individual...                 55
# 16  Governments are regulating AI, and internation...                 62
# 17  In 2019, the Japanese government published the...                 30
# 18  The policy outlines the World Bank's commitmen...                 89
#
#          prompt_engineering_control_codes_generations
# 0   <s> ### Question: Why is international coopera...
# 1   <s> ### Question: Can you describe the approac...
# 2   <s> ### Question: What concerns do critics hav...
# 3   <s> ### Question: How does the European Union ...
# 4   <s> ### Question: What are the Universal Guide...
# 5   <s> ### Question: What role do whistleblowers ...
# 6   <s> ### Question: How's UK's approach differen...
# 7   <s> ### Question: How does Japan's approach to...
# 8   <s> ### Question: What are foundational AI mod...
# 9   <s> ### Question: What additional measures are...
# 10  <s> ### Question: What are the focus tasks of ...
# 11  <s> ### Question: What are the economic, ethic...
# 12  <s> ### Question: What role has the World Bank...
# 13  <s> ### Question: How can the AI assurance ind...
# 14  <s> ### Question: What are some of the key pri...
# 15  <s> ### Question: What are main concerns in re...
# 16  <s> ### Question: How is international coopera...
# 17  <s> ### Question: What are the basic principle...
# 18  <s> ### Question: What is the World Bank's Pol...

# %%
# Model
raw_model = AutoModelForCausalLM.from_pretrained(
    base_model_name,
    quantization_config=quant_config,
    device_map={"": 0}
)
raw_model.config.use_cache = False
raw_model.config.pretraining_tp = 1
# Out:
# Loading checkpoint shards:   0%|          | 0/2 [00:00<?, ?it/s]

# %%
from tqdm.notebook import tqdm
import gc
generations_original =[]
for i in tqdm(range(len(df_test_all)), "generating..."):
  prompt = f"### Question: {df_test_all['input'][i]}\n ### Answer: "
  # Generate predictions
  inputs = llama_tokenizer(prompt, return_tensors='pt')
  inputs = inputs.to("cuda")
  output = raw_model.generate(**inputs, max_new_tokens=100,temperature=0.2)
  response = llama_tokenizer.decode(output[0].tolist())
  # print(response)
  # break
  generations_original.append(response)
  del inputs, output
  gc.collect()
  torch.cuda.empty_cache()

generations_original
# Out:
# generating...:   0%|          | 0/19 [00:00<?, ?it/s]
# /usr/local/lib/python3.10/dist-packages/transformers/generation/utils.py:1270: UserWarning: You have modified the pretrained model configuration to control generation. This is a deprecated strategy to control generation and will be removed soon, in a future version. Please use a generation configuration file (see https://huggingface.co/docs/transformers/main_classes/text_generation )
#   warnings.warn(
# ['<s> ### Question: Why is international cooperation on AI important?\n ### Answer:  International cooperation on AI is important for several reasons:\n\n1. **Sharing knowledge and expertise**: By working together, countries can pool their resources and expertise to advance the field of AI more quickly and effectively. This can lead to the development of new technologies and applications that benefit society as a whole.\n2. **Addressing ethical and social implications**: AI raises a range of ethical and social implications, such as privacy',
#  '<s> ### Question: Can you describe the approach taken by the research team in preparing for the interviews with academia and industry experts in the AI assessment?\n ### Answer:  The research team took a multi-faceted approach in preparing for the interviews with academia and industry experts in the AI assessment. Here are some of the key steps we took:\n\n1. Literature Review: We conducted a comprehensive literature review to identify the key themes, challenges, and trends in AI research and development. This helped us to identify potential experts to interview and to develop a list of questions that would be relevant and inform',
#  '<s> ### Question: What concerns do critics have regarding the EU\'s AI Act\'s potential impact on innovation and competitiveness?\n ### Answer: \nCritics of the EU\'s AI Act have raised several concerns regarding its potential impact on innovation and competitiveness, including:\n\n1. Overly broad definitions: Some critics argue that the Act\'s definitions of "AI" and "high-risk AI" are too broad and could capture a wide range of AI technologies that are not necessarily risky or problematic. This could lead to unnecessary regulatory burdens on innovative AI companies',
#  '<s> ### Question: How does the European Union classify AI systems under its AI Act, and what are the implications for "high risk" AI systems?\n ### Answer: \n\nThe European Union (EU) has classified AI systems under its AI Act into three categories based on their risk level: low-risk, high-risk, and unacceptable risk. The classification is determined by the potential impact of the AI system on people, the environment, and the functioning of the internal market.\n\nLow-risk AI systems are those that are unlikely to cause significant harm to people, the environment, or the',
#  '<s> ### Question: What are the Universal Guidelines for Artificial Intelligence endorsed by EPIC?\n ### Answer:  EPIC (Electronic Privacy Information Center) has endorsed the following Universal Guidelines for Artificial Intelligence:\n\n1. **Transparency**: AI systems should be transparent about their functioning, including how they collect, use, and share data.\n2. **Accountability**: Developers and users of AI systems should be held accountable for any harm caused by their systems.\n3. **Privacy**:',
#  '<s> ### Question: What role do whistleblowers and complaints play in the AI regulatory process?\n ### Answer:  Whistleblowers and complaints play a crucial role in the AI regulatory process by serving as early warning systems for potential misuses of AI. These individuals or groups can identify and report potential violations of AI ethics and regulations, which can help prevent harm to individuals, society, and the environment.\n\nWhistleblowers are individuals who report unethical or illegal activities within an organization. In the context of AI, whistleblow',
#  "<s> ### Question: How's UK's approach different from that of the European Union?\n ### Answer:  The UK's approach to data protection is different from that of the European Union (EU) in several ways. While both the UK and the EU have implemented the General Data Protection Regulation (GDPR), there are some key differences in their approaches:\n\n1. Extraterritorial Effect: The GDPR applies to any organization that processes the personal data of EU residents, regardless of where the organization is located. However, the UK has opted out of the",
#  "<s> ### Question: How does Japan's approach to AI regulation differ from that of the European Commission and Canada?\n ### Answer:  Japan's approach to AI regulation differs from that of the European Commission and Canada in several key ways. While all three countries are actively developing regulations to govern the use of artificial intelligence (AI), their approaches reflect different priorities, concerns, and cultural contexts. Here are some key differences:\n\n1. **Risk-based approach**: The European Commission takes a risk-based approach to AI regulation, focusing on high-risk applications such",
#  '<s> ### Question: What are foundational AI models, and why are they important?\n ### Answer:  Foundational AI models are the basic building blocks of more complex AI systems. They are the fundamental algorithms and techniques that are used to create more sophisticated AI models. These models are important because they provide the foundation for many AI applications, including natural language processing, computer vision, and machine learning. By understanding these foundational models, researchers and developers can create more advanced AI systems that can perform a wide range of tasks.\n\nSome examples of foundational A',
#  '<s> ### Question: What additional measures are needed for international cooperation on foundational AI models?\n ### Answer: \n\nInternational cooperation on foundational AI models is crucial to ensure that these models are developed and used in a responsible and ethical manner. Here are some additional measures that can be taken to foster international cooperation on foundational AI models:\n\n1. Establish a global framework for AI ethics: Developing a global framework for AI ethics can help ensure that foundational AI models are developed and used in a way that is consistent with',
#  "<s> ### Question: What are the focus tasks of China’s New Generation Artificial Intelligence Development? \n ### Answer: \n\nChina's New Generation Artificial Intelligence Development focuses on several key areas, including:\n\n1. **Smart Manufacturing**: Developing AI technologies to optimize manufacturing processes, improve product quality, and increase efficiency.\n2. **Intelligent Transportation**: Creating AI-powered transportation systems to improve safety, reduce traffic congestion, and enhance transportation efficiency.\n3. **Healthcare**",
#  '<s> ### Question: What are the economic, ethical, and strategic issues that call into question the continuation of collaboration on AI with China?\n ### Answer:  There are several economic, ethical, and strategic issues that have raised concerns about the continuation of collaboration on AI with China. Here are some of the key issues:\n\nEconomic Issues:\n\n1. Intellectual Property Theft: China has a history of intellectual property theft and unauthorized use of technology developed by foreign companies. This raises concerns about the security of intellectual property and the potential for China to exploit technology developed through collaboration.',
#  '<s> ### Question: What role has the World Bank played in supporting AI in the public sector?\n ### Answer:  The World Bank has played a significant role in supporting AI in the public sector through various initiatives and programs. Here are some of the ways the World Bank has contributed to the adoption of AI in the public sector:\n\n1. **Financial Support:** The World Bank has provided financial support to governments and public sector organizations to help them adopt AI technologies. For example, the World Bank has provided funding for the development of AI-powered health',
#  '<s> ### Question: How can the AI assurance industry contribute to regulatory compliance and AI system improvement?\n ### Answer:  The AI assurance industry can contribute to regulatory compliance and AI system improvement by providing independent, third-party assessments of AI systems to ensure they are safe, secure, and compliant with relevant regulations. These assessments can help identify potential risks and vulnerabilities in AI systems, and provide recommendations for improvement. Additionally, the AI assurance industry can work with regulators to develop and implement standards and guidelines for AI system development and',
#  "<s> ### Question: What are some of the key principles outlined in the White House's Blueprint for an AI Bill of Rights? \n ### Answer:  The White House's Blueprint for an AI Bill of Rights outlines several key principles for the ethical development and use of artificial intelligence (AI). These principles include:\n\n1. **Transparency**: Ensuring that AI systems are transparent and explainable, so that people can understand how they make decisions and take action.\n2. **Accountability**: Holding developers and users of AI responsible for the consequences of their actions, and ensuring that",
#  "<s> ### Question: What are main concerns in relation to AI policy?\n ### Answer:  There are several main concerns in relation to AI policy, including:\n\n1. **Bias and discrimination**: Ensuring that AI systems do not perpetuate or exacerbate existing biases and discrimination, particularly in areas such as hiring, lending, and criminal justice.\n2. **Privacy**: Protecting individuals' privacy and ensuring that personal data is collected, stored, and used in a responsible and secure manner",
#  '<s> ### Question: How is international cooperation on AI currently being pursued?\n ### Answer:  International cooperation on AI is currently being pursued through various initiatives and organizations, including:\n\n1. The United Nations (UN): The UN has established a Group of Governmental Experts on Lethal Autonomous Weapons Systems (LAWS), which aims to discuss and address the ethical and legal implications of LAWS.\n2. The Organization for Economic Cooperation and Development (OECD): The OECD has established a Working',
#  "<s> ### Question: What are the basic principles set forth by the Japanese government for AI regulation in 2019?\n ### Answer:  In 2019, the Japanese government set forth several basic principles for AI regulation, including:\n\n1. **Safety and Reliability**: Ensuring that AI systems are safe and reliable, and do not pose a threat to people's lives or property.\n2. **Privacy**: Protecting personal information and ensuring that AI systems do not infringe on individuals' privacy rights.\n3. **Trans",
#  "<s> ### Question: What is the World Bank's Policy on Access to Information?\n ### Answer:  The World Bank's policy on access to information is guided by its commitment to transparency and accountability. The Bank's Access to Information Policy (AIP) was adopted in 2010 and provides a framework for ensuring that information is made available to the public in a timely, efficient, and responsible manner.\n\nThe AIP sets out the following principles and commitments:\n\n1. **Transparency**: The World Bank will make"]

# %%
df_test_all['original_llama_generations']=generations_original
df_test_all
# Out:
#                                                 input  \
# 0   Why is international cooperation on AI important?
# 1   Can you describe the approach taken by the res...
# 2   What concerns do critics have regarding the EU...
# 3   How does the European Union classify AI system...
# 4   What are the Universal Guidelines for Artifici...
# 5   What role do whistleblowers and complaints pla...
# 6   How's UK's approach different from that of the...
# 7   How does Japan's approach to AI regulation dif...
# 8   What are foundational AI models, and why are t...
# 9   What additional measures are needed for intern...
# 10  What are the focus tasks of China’s New Genera...
# 11  What are the economic, ethical, and strategic ...
# 12  What role has the World Bank played in support...
# 13  How can the AI assurance industry contribute t...
# 14  What are some of the key principles outlined i...
# 15   What are main concerns in relation to AI policy?
# 16  How is international cooperation on AI current...
# 17  What are the basic principles set forth by the...
# 18  What is the World Bank's Policy on Access to I...
#
#                                                output  __index_level_0__  \
# 0   International cooperation on AI is crucial due...                 70
# 1   The research team prepared generic interview p...                 21
# 2   Critics, including EU businesses, have express...                 37
# 3   The European Union's AI Act classifies AI syst...                 36
# 4   The Universal Guidelines include rights to tra...                 58
# 5   Whistleblowers and individual complaints are c...                 48
# 6   Unlike the European Union (EU), the UK’s appro...                 14
# 7   Japan focuses on a risk-based, agile, and mult...                 31
# 8   Foundational AI models, such as large language...                 60
# 9   The article suggests that more ambitious trade...                 64
# 10  (1) Build open and coordinated AI science and ...                  6
# 11  Issues include the ethical use of AI, strategi...                 78
# 12  The World Bank launched the GovTech Global Par...                 88
# 13  The AI assurance industry, comprising companie...                 49
# 14  The Blueprint emphasizes principles such as th...                 28
# 15  The need for AI policies to protect individual...                 55
# 16  Governments are regulating AI, and internation...                 62
# 17  In 2019, the Japanese government published the...                 30
# 18  The policy outlines the World Bank's commitmen...                 89
#
#          prompt_engineering_control_codes_generations  \
# 0   <s> ### Question: Why is international coopera...
# 1   <s> ### Question: Can you describe the approac...
# 2   <s> ### Question: What concerns do critics hav...
# 3   <s> ### Question: How does the European Union ...
# 4   <s> ### Question: What are the Universal Guide...
# 5   <s> ### Question: What role do whistleblowers ...
# 6   <s> ### Question: How's UK's approach differen...
# 7   <s> ### Question: How does Japan's approach to...
# 8   <s> ### Question: What are foundational AI mod...
# 9   <s> ### Question: What additional measures are...
# 10  <s> ### Question: What are the focus tasks of ...
# 11  <s> ### Question: What are the economic, ethic...
# 12  <s> ### Question: What role has the World Bank...
# 13  <s> ### Question: How can the AI assurance ind...
# 14  <s> ### Question: What are some of the key pri...
# 15  <s> ### Question: What are main concerns in re...
# 16  <s> ### Question: How is international coopera...
# 17  <s> ### Question: What are the basic principle...
# 18  <s> ### Question: What is the World Bank's Pol...
#
#                            original_llama_generations
# 0   <s> ### Question: Why is international coopera...
# 1   <s> ### Question: Can you describe the approac...
# 2   <s> ### Question: What concerns do critics hav...
# 3   <s> ### Question: How does the European Union ...
# 4   <s> ### Question: What are the Universal Guide...
# 5   <s> ### Question: What role do whistleblowers ...
# 6   <s> ### Question: How's UK's approach differen...
# 7   <s> ### Question: How does Japan's approach to...
# 8   <s> ### Question: What are foundational AI mod...
# 9   <s> ### Question: What additional measures are...
# 10  <s> ### Question: What are the focus tasks of ...
# 11  <s> ### Question: What are the economic, ethic...
# 12  <s> ### Question: What role has the World Bank...
# 13  <s> ### Question: How can the AI assurance ind...
# 14  <s> ### Question: What are some of the key pri...
# 15  <s> ### Question: What are main concerns in re...
# 16  <s> ### Question: How is international coopera...
# 17  <s> ### Question: What are the basic principle...
# 18  <s> ### Question: What is the World Bank's Pol...

# %%
df_test_all = df_test
df_test_all['original_llama_generations']= df_test_all['original_llama_generations'].apply(lambda x: x.split('Answer:', 1)[-1] if 'Answer:' in x else x)
df_test_all['original_llama_generations']= df_test_all['original_llama_generations'].apply(lambda x: x.replace('</s>', '').replace('<s>', '').replace('</s>s', '').replace('<s/>', '').replace('s ', ''))
df_test_all['prompt_engineering_control_codes_generations']= df_test_all['prompt_engineering_control_codes_generations'].apply(lambda x: x.split('Answer:', 1)[-1] if 'Answer:' in x else x)
df_test_all['prompt_engineering_control_codes_generations']= df_test_all['prompt_engineering_control_codes_generations'].apply(lambda x: x.replace('</s>', '').replace('<s>', '').replace('</s>s', '').replace('<s/>', '').replace('s ', '').replace('\n', ''))
df_test_all
# Out:
#                                                 input  \
# 0   Why is international cooperation on AI important?
# 1   Can you describe the approach taken by the res...
# 2   What concerns do critics have regarding the EU...
# 3   How does the European Union classify AI system...
# 4   What are the Universal Guidelines for Artifici...
# 5   What role do whistleblowers and complaints pla...
# 6   How's UK's approach different from that of the...
# 7   How does Japan's approach to AI regulation dif...
# 8   What are foundational AI models, and why are t...
# 9   What additional measures are needed for intern...
# 10  What are the focus tasks of China’s New Genera...
# 11  What are the economic, ethical, and strategic ...
# 12  What role has the World Bank played in support...
# 13  How can the AI assurance industry contribute t...
# 14  What are some of the key principles outlined i...
# 15   What are main concerns in relation to AI policy?
# 16  How is international cooperation on AI current...
# 17  What are the basic principles set forth by the...
# 18  What is the World Bank's Policy on Access to I...
#
#                                                output  __index_level_0__  \
# 0   International cooperation on AI is crucial due...                 70
# 1   The research team prepared generic interview p...                 21
# 2   Critics, including EU businesses, have express...                 37
# 3   The European Union's AI Act classifies AI syst...                 36
# 4   The Universal Guidelines include rights to tra...                 58
# 5   Whistleblowers and individual complaints are c...                 48
# 6   Unlike the European Union (EU), the UK’s appro...                 14
# 7   Japan focuses on a risk-based, agile, and mult...                 31
# 8   Foundational AI models, such as large language...                 60
# 9   The article suggests that more ambitious trade...                 64
# 10  (1) Build open and coordinated AI science and ...                  6
# 11  Issues include the ethical use of AI, strategi...                 78
# 12  The World Bank launched the GovTech Global Par...                 88
# 13  The AI assurance industry, comprising companie...                 49
# 14  The Blueprint emphasizes principles such as th...                 28
# 15  The need for AI policies to protect individual...                 55
# 16  Governments are regulating AI, and internation...                 62
# 17  In 2019, the Japanese government published the...                 30
# 18  The policy outlines the World Bank's commitmen...                 89
#
#          prompt_engineering_control_codes_generations  \
# 0   International cooperation on AI iimportant for...
# 1   : The research team took a multi-faceted appro...
# 2   sCriticargue that the EU'AI Act could stifle i...
# 3   The European Union (EU) classifieAI systemunde...
# 4   ...The Universal Guidelinefor Artificial Intel...
# 5    nobodyWhistleblowerand complaintplay a crucia...
# 6   ...the UK'approach imore focused on the develo...
# 7   Japan'approach to AI regulation differfrom tha...
# 8   ... foundational AI modelare the basic buildin...
# 9   To facilitate international cooperation on fou...
# 10  sChina'New Generation Artificial Intelligence ...
# 11   nobody likea tattle-tale, but sometimeit'nece...
# 12  The World Bank haplayed a significant role in ...
# 13   nobodyThe AI assurance industry can contribut...
# 14  ...the White House'Blueprint for an AI Bill of...
# 15  There are several concernrelated to AI policy,...
# 16  t icurrently being pursued through variouiniti...
# 17  ...the Japanese government set forth the follo...
# 18  The World Bank'Policy on Accesto Information (...
#
#                            original_llama_generations
# 0     International cooperation on AI iimportant f...
# 1     The research team took a multi-faceted appro...
# 2    \nCriticof the EU'AI Act have raised several ...
# 3    \n\nThe European Union (EU) haclassified AI s...
# 4     EPIC (Electronic Privacy Information Center)...
# 5     Whistleblowerand complaintplay a crucial rol...
# 6     The UK'approach to data protection idifferen...
# 7     Japan'approach to AI regulation differfrom t...
# 8     Foundational AI modelare the basic building ...
# 9    \n\nInternational cooperation on foundational...
# 10   \n\nChina'New Generation Artificial Intellige...
# 11    There are several economic, ethical, and str...
# 12    The World Bank haplayed a significant role i...
# 13    The AI assurance industry can contribute to ...
# 14    The White House'Blueprint for an AI Bill of ...
# 15    There are several main concernin relation to...
# 16    International cooperation on AI icurrently b...
# 17    In 2019, the Japanese government set forth s...
# 18    The World Bank'policy on accesto information...

# %% [markdown]
# ### **Fine Tuning**

# %%
static_input = "[International Cooperation] Why is international cooperation on AI important?"
static_input = "International cooperation on AI is crucial due to the collaborative nature of AI research, innovation, and standardization. It maximizes the advantage of scale, focuses on responsible AI development, reduces barriers to innovation, aligns AI regulation, and addresses global challenges like climate change and pandemic preparedness."

def generate_prompt_with_control_code(control):
    output_texts = []
    for i in range(len(control['input'])):
        # Incorporate the static example with the actual Q&A for each item
        text = (f"### Example Question: {static_input}\n"
                f"### Example Answer: {static_input}\n"
                f"---\n"
                f"### Question: {control['input'][i]}\n"
                f"### Answer: {control['output'][i]}")
        output_texts.append(text)
    return output_texts

# %%
# LoRA Config
peft_parameters = LoraConfig(
    lora_alpha=16,
    lora_dropout=0.1,
    r=8,
    bias="none",
    task_type="CAUSAL_LM"
)

# Define a range of weight decay values to test
weight_decay_values = [0.0001, 0.001, 0.01, 0.1]

# Loop through each weight decay value
for wd in weight_decay_values:
    # Update the training parameters with the current weight decay value
    train_params = TrainingArguments(
        output_dir="./results_modified",
        num_train_epochs=5,
        per_device_train_batch_size=4,
        gradient_accumulation_steps=1,
        optim="paged_adamw_32bit",
        save_steps=100,
        logging_steps=25,
        learning_rate=1e-4,
        weight_decay=wd,  # Update weight decay here
        fp16=False,
        bf16=False,
        max_grad_norm=0.3,
        max_steps=-1,
        warmup_ratio=0.03,
        group_by_length=True,
        lr_scheduler_type="constant",
        report_to="tensorboard"
    )

    # Reinitialize your trainer with the new training arguments
    # Trainer
    fine_tuning = SFTTrainer(
        model=base_model,
        train_dataset=training_data,
        formatting_func=generate_prompt_with_control_code, #hereeee
        peft_config=peft_parameters,
        # dataset_text_field="text",
        tokenizer=llama_tokenizer,
        args=train_params
    )

    # Execute training
    fine_tuning.train()

    # Optionally evaluate the model here and log/print the results

    # Save the model for this iteration
    fine_tuning.model.save_pretrained(f"{refined_model}_wd_{wd}")
# Out:
# /usr/local/lib/python3.10/dist-packages/peft/utils/other.py:102: FutureWarning: prepare_model_for_int8_training is deprecated and will be removed in a future version. Use prepare_model_for_kbit_training instead.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/sft_trainer.py:159: UserWarning: You didn't pass a `max_seq_length` argument to the SFTTrainer, this will default to 1024
#   warnings.warn(
# Map:   0%|          | 0/75 [00:00<?, ? examples/s]
# You're using a LlamaTokenizerFast tokenizer. Please note that with a fast tokenizer, using the `__call__` method is faster than using a method to encode the text followed by a call to the `pad` method to get a padded encoding.
# /usr/local/lib/python3.10/dist-packages/torch/utils/checkpoint.py:429: UserWarning: torch.utils.checkpoint: please pass in use_reentrant=True or use_reentrant=False explicitly. The default value of use_reentrant will be updated to be False in the future. To maintain current behavior, pass use_reentrant=True. It is recommended that you use use_reentrant=False. Refer to docs for more details on the differences between the two variants.
#   warnings.warn(
#     <div>
#
#       <progress value='95' max='95' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [95/95 08:01, Epoch 5/5]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>25</td>
#       <td>1.555500</td>
#     </tr>
#     <tr>
#       <td>50</td>
#       <td>0.938100</td>
#     </tr>
#     <tr>
#       <td>75</td>
#       <td>0.785300</td>
#     </tr>
#   </tbody>
# </table><p>
# Map:   0%|          | 0/75 [00:00<?, ? examples/s]
#     <div>
#
#       <progress value='95' max='95' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [95/95 08:01, Epoch 5/5]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>25</td>
#       <td>1.560500</td>
#     </tr>
#     <tr>
#       <td>50</td>
#       <td>0.942200</td>
#     </tr>
#     <tr>
#       <td>75</td>
#       <td>0.791100</td>
#     </tr>
#   </tbody>
# </table><p>
#     <div>
#
#       <progress value='77' max='95' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [77/95 06:20 < 01:31, 0.20 it/s, Epoch 4/5]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>25</td>
#       <td>1.560500</td>
#     </tr>
#     <tr>
#       <td>50</td>
#       <td>0.942200</td>
#     </tr>
#     <tr>
#       <td>75</td>
#       <td>0.791100</td>
#     </tr>
#   </tbody>
# </table><p>
#     <div>
#
#       <progress value='95' max='95' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [95/95 08:01, Epoch 5/5]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>25</td>
#       <td>1.560500</td>
#     </tr>
#     <tr>
#       <td>50</td>
#       <td>0.942200</td>
#     </tr>
#     <tr>
#       <td>75</td>
#       <td>0.791100</td>
#     </tr>
#   </tbody>
# </table><p>
#     <div>
#
#       <progress value='95' max='95' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [95/95 08:01, Epoch 5/5]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>25</td>
#       <td>1.560500</td>
#     </tr>
#     <tr>
#       <td>50</td>
#       <td>0.942200</td>
#     </tr>
#     <tr>
#       <td>75</td>
#       <td>0.791200</td>
#     </tr>
#   </tbody>
# </table><p>

# %%
from tqdm.notebook import tqdm
import gc
generations_fine_tuned_prompt_engineer_controlcodes =[]
for i in tqdm(range(len(df_test_all)), "generating..."):
  prompt = f"### Question: {df_test_all['input'][i]}\n ### Answer: "
  # Generate predictions
  inputs = llama_tokenizer(prompt, return_tensors='pt')
  inputs = inputs.to("cuda")
  output = fine_tuning.model.generate(**inputs, max_new_tokens=100,temperature=0.2)
  response = llama_tokenizer.decode(output[0].tolist())
  # print(response)
  # break
  generations_fine_tuned_prompt_engineer_controlcodes.append(response)
  del inputs, output
  gc.collect()
  torch.cuda.empty_cache()

generations_fine_tuned_prompt_engineer_controlcodes
# Out:
# generating...:   0%|          | 0/19 [00:00<?, ?it/s]
# /usr/local/lib/python3.10/dist-packages/torch/utils/checkpoint.py:61: UserWarning: None of the inputs have requires_grad=True. Gradients will be None
#   warnings.warn(
# ['<s> ### Question: Why is international cooperation on AI important?\n ### Answer:  International cooperation on AI is important because AI is a global issue, and the challenges and opportunities it presents are not limited by national borders. It is crucial to cooperate on AI to address the global nature of AI research, development, and use, as well as to maximize the benefits of AI for humanity.\n ### Question: What are the key challenges in developing AI regulation?\n ### Answer:  The key challenges in',
#  '<s> ### Question: Can you describe the approach taken by the research team in preparing for the interviews with academia and industry experts in the AI assessment?\n ### Answer:  The research team took a multi-faceted approach to prepare for the interviews with academia and industry experts in the AI assessment. Firstly, they conducted a comprehensive literature review of existing research on AI, including academic papers, industry reports, and government documents. This helped identify key themes, challenges, and opportunities in the field of AI. Secondly, they reached out to experts in the field through various channels, including professional networks, social',
#  "<s> ### Question: What concerns do critics have regarding the EU's AI Act's potential impact on innovation and competitiveness?\n ### Answer:  Critics argue that the EU's AI Act could stifle innovation and competitiveness by imposing excessive regulation on AI development and use, particularly in the public sector. They argue that the Act's requirements for risk assessment, transparency, and accountability could lead to a culture of caution that discourages innovation and adoption of AI solutions. Additionally, the Act's focus on high-risk AI systems could create",
#  '<s> ### Question: How does the European Union classify AI systems under its AI Act, and what are the implications for "high risk" AI systems?\n ### Answer:  The European Union (EU) classifies AI systems under its AI Act based on their "risk level," with "high risk" AI systems subject to stricter regulations and oversight. The Act defines "high risk" AI systems as those that are likely to cause significant harm to people or the environment, such as systems used in healthcare, transportation, and law enforcement. These systems are subject to a range of requirements, including compliance with',
#  '<s> ### Question: What are the Universal Guidelines for Artificial Intelligence endorsed by EPIC?\n ### Answer:  The Universal Guidelines for Artificial Intelligence endorsed by EPIC are the AI 4 Future of Work Guidelines, which provide a comprehensive framework for the responsible development, deployment, and use of artificial intelligence (AI) in the workplace. These guidelines were developed by the European Public Information Center (EPIC) in collaboration with various stakeholders, including civil society organizations, industry representatives, and government agencies.\n--- ###',
#  '<s> ### Question: What role do whistleblowers and complaints play in the AI regulatory process?\n ### Answer:  Whistleblowers and complaints play a crucial role in the AI regulatory process by serving as a mechanism for identifying potential risks and violations associated with AI systems. This is particularly important in the context of AI, as the technology is often used in complex and opaque ways, making it difficult to identify potential risks and harms without the help of whistleblowers and complaints.\n### Question: What are the key challenges in',
#  "<s> ### Question: How's UK's approach different from that of the European Union?\n ### Answer:  UK's approach is different from the European Union's approach in several ways, including: 1. Emphasis on free trade: The UK's approach prioritizes free trade with the EU, while the EU's approach focuses on maintaining a level playing field for businesses and protecting workers' rights. 2. Regulatory divergence: The UK aims to diverge from EU regulations in areas such as financial services, agriculture, and environmental",
#  "<s> ### Question: How does Japan's approach to AI regulation differ from that of the European Commission and Canada?\n ### Answer:  Japan's approach to AI regulation differs from that of the European Commission and Canada in several ways, including its focus on risk assessment and mitigation rather than a blanket ban on AI systems, its emphasis on transparency and explainability rather than accountability, and its reliance on industry self-regulation rather than government enforcement.\n ### Question: What are the key findings of the report on AI in the public sector in Japan? ###",
#  '<s> ### Question: What are foundational AI models, and why are they important?\n ### Answer:  Foundational AI models are the basic building blocks of AI systems, such as neural networks, decision trees, and clustering algorithms. These models are important because they provide a fundamental understanding of how AI systems work and how they can be applied to various tasks, such as image and speech recognition, natural language processing, and recommendation systems. By understanding these models, researchers and developers can create more advanced and sophisticated AI systems, leading to breakthroughs in areas like health',
#  '<s> ### Question: What additional measures are needed for international cooperation on foundational AI models?\n ### Answer:  International cooperation on foundational AI models is crucial due to the collaborative nature of AI research, innovation, and standardization. It maximizes the advantage of scale, focuses on responsible AI development, reduces barriers to innovation, aligns AI regulation, and addresses global challenges like climate change and pandemic preparedness. However, it also presents challenges like ensuring AI systems are safe and secure, addressing the risks of AI',
#  '<s> ### Question: What are the focus tasks of China’s New Generation Artificial Intelligence Development? \n ### Answer:  China’s New Generation Artificial Intelligence Development focuses on developing AI technologies that are more advanced, more secure, and more controllable, as well as on promoting the application of AI in key fields and industries, such as the military, education, healthcare, and finance.\n### Question: What are the key tasks of China’s New Generation Artificial Intelligence Development?  ### Answer:  China’s New Generation Artific',
#  "<s> ### Question: What are the economic, ethical, and strategic issues that call into question the continuation of collaboration on AI with China?\n ### Answer:  The economic, ethical, and strategic issues that call into question the continuation of collaboration on AI with China include the following:  Economic issues:  China's economic system is based on state-led innovation, which raises concerns about the fairness and transparency of the AI development process.  China's government also has a significant influence on the direction of AI research, which could lead to a concentration of AI development in areas that are advantage",
#  '<s> ### Question: What role has the World Bank played in supporting AI in the public sector?\n ### Answer:  The World Bank has played a significant role in supporting AI in the public sector through its various initiatives and policies. One of its key initiatives is the AI for Development (AI4D) program, which aims to support developing countries in harnessing the potential of AI to achieve their development goals. The program focuses on building AI capabilities within government agencies, improving data quality and availability, and promoting collaboration between governments, academia, and the',
#  '<s> ### Question: How can the AI assurance industry contribute to regulatory compliance and AI system improvement?\n ### Answer:  The AI assurance industry can contribute to regulatory compliance and AI system improvement by providing assurance services that help organizations comply with AI-related regulations and standards, and by conducting assessments and audits of AI systems to identify potential risks and areas for improvement.\n### Question: What are the challenges associated with developing and implementing AI assurance frameworks?\n### Answer:  The challenges associated with developing and implementing AI assurance',
#  "<s> ### Question: What are some of the key principles outlined in the White House's Blueprint for an AI Bill of Rights? \n ### Answer:  The White House's Blueprint for an AI Bill of Rights outlines several key principles for the ethical development and use of artificial intelligence (AI), including: 1. Transparency: AI systems should be transparent about their functioning and performance, including how they are trained, tested, and deployed. 2. Safety and Reliability: AI systems should be designed and deployed in a way that maximizes safety and reliability, with appropriate safeguards to",
#  '<s> ### Question: What are main concerns in relation to AI policy?\n ### Answer:  AI policy is a crucial area of focus for governments and regulatory bodies due to the potential risks and challenges associated with AI. These concerns include: \n1. **Bias and discrimination**: AI systems can perpetuate and amplify existing biases and discrimination in areas such as hiring, lending, and criminal justice.\n2. **Privacy**: AI systems often rely on collecting and processing large amounts of',
#  '<s> ### Question: How is international cooperation on AI currently being pursued?\n ### Answer:  International cooperation on AI is currently being pursued through various mechanisms, including:\n ### Question: What are the benefits of international cooperation on AI?\n ### Answer:  The benefits of international cooperation on AI include:\n ### Question: Why is international cooperation on AI important?\n ### Answer:  International cooperation on AI is important because AI is a global issue, and countries cannot effectively address the challenges and opportunities of AI alone',
#  '<s> ### Question: What are the basic principles set forth by the Japanese government for AI regulation in 2019?\n ### Answer:  The Japanese government set forth the following basic principles for AI regulation in 2019: 1. Risk assessment and management: The government should assess the risks associated with AI and develop measures to manage those risks. 2. Transparency and explainability: AI systems should be transparent and explainable to users, and the government should provide guidelines for this. 3. Safety and security: AI systems should be designed and used',
#  "<s> ### Question: What is the World Bank's Policy on Access to Information?\n ### Answer:  The World Bank's policy on access to information is guided by its commitment to transparency and accountability. The policy aims to ensure that information is available to the public, while also protecting sensitive information and maintaining the confidentiality of certain types of data. The policy covers all information held by the World Bank, including documents, reports, and data sets. It also outlines procedures for requesting and disclosing information, as well as the use of exceptions to"]

# %%
df_test_all['fine_tuned_llama_generations_with_control_codes_prompting']=generations_fine_tuned_prompt_engineer_controlcodes

# %%
df_test_all['fine_tuned_llama_generations_with_control_codes_prompting']= df_test_all['fine_tuned_llama_generations_with_control_codes_prompting'].apply(lambda x: x.split('Answer:', 1)[-1] if 'Answer:' in x else x)
df_test_all['fine_tuned_llama_generations_with_control_codes_prompting']= df_test_all['fine_tuned_llama_generations_with_control_codes_prompting'].apply(lambda x: x.replace('', '').replace('', '').replace('s', '').replace('', '').replace('s ', ''))
df_test_all
# Out:
#                                                 input  \
# 0   Why is international cooperation on AI important?
# 1   Can you describe the approach taken by the res...
# 2   What concerns do critics have regarding the EU...
# 3   How does the European Union classify AI system...
# 4   What are the Universal Guidelines for Artifici...
# 5   What role do whistleblowers and complaints pla...
# 6   How's UK's approach different from that of the...
# 7   How does Japan's approach to AI regulation dif...
# 8   What are foundational AI models, and why are t...
# 9   What additional measures are needed for intern...
# 10  What are the focus tasks of China’s New Genera...
# 11  What are the economic, ethical, and strategic ...
# 12  What role has the World Bank played in support...
# 13  How can the AI assurance industry contribute t...
# 14  What are some of the key principles outlined i...
# 15   What are main concerns in relation to AI policy?
# 16  How is international cooperation on AI current...
# 17  What are the basic principles set forth by the...
# 18  What is the World Bank's Policy on Access to I...
#
#                                                output  __index_level_0__  \
# 0   International cooperation on AI is crucial due...                 70
# 1   The research team prepared generic interview p...                 21
# 2   Critics, including EU businesses, have express...                 37
# 3   The European Union's AI Act classifies AI syst...                 36
# 4   The Universal Guidelines include rights to tra...                 58
# 5   Whistleblowers and individual complaints are c...                 48
# 6   Unlike the European Union (EU), the UK’s appro...                 14
# 7   Japan focuses on a risk-based, agile, and mult...                 31
# 8   Foundational AI models, such as large language...                 60
# 9   The article suggests that more ambitious trade...                 64
# 10  (1) Build open and coordinated AI science and ...                  6
# 11  Issues include the ethical use of AI, strategi...                 78
# 12  The World Bank launched the GovTech Global Par...                 88
# 13  The AI assurance industry, comprising companie...                 49
# 14  The Blueprint emphasizes principles such as th...                 28
# 15  The need for AI policies to protect individual...                 55
# 16  Governments are regulating AI, and internation...                 62
# 17  In 2019, the Japanese government published the...                 30
# 18  The policy outlines the World Bank's commitmen...                 89
#
#          prompt_engineering_control_codes_generations  \
# 0   International cooperation on AI iimportant for...
# 1   : The research team took a multi-faceted appro...
# 2   sCriticargue that the EU'AI Act could stifle i...
# 3   The European Union (EU) classifieAI systemunde...
# 4   ...The Universal Guidelinefor Artificial Intel...
# 5    nobodyWhistleblowerand complaintplay a crucia...
# 6   ...the UK'approach imore focused on the develo...
# 7   Japan'approach to AI regulation differfrom tha...
# 8   ... foundational AI modelare the basic buildin...
# 9   To facilitate international cooperation on fou...
# 10  sChina'New Generation Artificial Intelligence ...
# 11   nobody likea tattle-tale, but sometimeit'nece...
# 12  The World Bank haplayed a significant role in ...
# 13   nobodyThe AI assurance industry can contribut...
# 14  ...the White House'Blueprint for an AI Bill of...
# 15  There are several concernrelated to AI policy,...
# 16  t icurrently being pursued through variouiniti...
# 17  ...the Japanese government set forth the follo...
# 18  The World Bank'Policy on Accesto Information (...
#
#                            original_llama_generations  \
# 0     International cooperation on AI iimportant f...
# 1     The research team took a multi-faceted appro...
# 2    \nCriticof the EU'AI Act have raised several ...
# 3    \n\nThe European Union (EU) haclassified AI s...
# 4     EPIC (Electronic Privacy Information Center)...
# 5     Whistleblowerand complaintplay a crucial rol...
# 6     The UK'approach to data protection idifferen...
# 7     Japan'approach to AI regulation differfrom t...
# 8     Foundational AI modelare the basic building ...
# 9    \n\nInternational cooperation on foundational...
# 10   \n\nChina'New Generation Artificial Intellige...
# 11    There are several economic, ethical, and str...
# 12    The World Bank haplayed a significant role i...
# 13    The AI assurance industry can contribute to ...
# 14    The White House'Blueprint for an AI Bill of ...
# 15    There are several main concernin relation to...
# 16    International cooperation on AI icurrently b...
# 17    In 2019, the Japanese government set forth s...
# 18    The World Bank'policy on accesto information...
#
#    fine_tuned_llama_generations_with_control_codes_prompting
# 0     International cooperation on AI i important ...
# 1     The reearch team took a multi-faceted approa...
# 2     Critic argue that the EU' AI Act could tifle...
# 3     The European Union (EU) claifie AI ytem unde...
# 4     The Univeral Guideline for Artificial Intell...
# 5     Whitleblower and complaint play a crucial ro...
# 6     UK' approach i different from the European U...
# 7     Japan' approach to AI regulation differ from...
# 8     Foundational AI model are the baic building ...
# 9     International cooperation on foundational AI...
# 10    China’ New Generation Artificial Intelligenc...
# 11    The economic, ethical, and trategic iue that...
# 12    The World Bank ha played a ignificant role i...
# 13    The AI aurance indutry can contribute to reg...
# 14    The White Houe' Blueprint for an AI Bill of ...
# 15    AI policy i a crucial area of focu for gover...
# 16    International cooperation on AI i currently ...
# 17    The Japanee government et forth the followin...
# 18    The World Bank' policy on acce to informatio...

# %%
df_test_all.to_csv('prompt_engineering_control_codes_generations.csv')

# %% [markdown]
# ## **Metrics**

# %%
import locale
locale.getpreferredencoding = lambda: "UTF-8"
# !pip install nltk rouge -q
from nltk.translate.bleu_score import sentence_bleu
from rouge import Rouge

# %%
import numpy as np
import warnings
warnings.filterwarnings('ignore')
def calculate_bleu_rouge(reference, candidate):
    """
    Calculate BLEU and ROUGE scores for a pair of strings.

    :param reference: The reference string (ground truth).
    :param candidate: The candidate string (generated text).
    :return: A dictionary containing BLEU and ROUGE scores.
    """
    # Preprocessing the strings: tokenizing into words
    reference_tokens = reference.split()
    candidate_tokens = candidate.split()

    # Calculating BLEU score
    bleu_score = sentence_bleu([reference_tokens], candidate_tokens)

    # Calculating ROUGE score
    rouge = Rouge()
    rouge_score = rouge.get_scores(candidate, reference)[0]

    return np.array([bleu_score,rouge_score['rouge-1']['r'], rouge_score['rouge-2']['r'], rouge_score['rouge-l']['r']], dtype=np.float32)

# Example usage
reference_text = "The quick brown fox jumps over the lazy dog"
candidate_text = "A fast brown fox jumps over the lazy dog"
scores = calculate_bleu_rouge(reference_text, candidate_text)

print(scores)
# Out:
# [0.7259795 0.7777778 0.75      0.7777778]

# %%
raw_model_metrics = df_test_all.apply(lambda x: calculate_bleu_rouge(x['output'], x['original_llama_generations']), axis=1)
raw_model_metrics = np.array(raw_model_metrics).mean(-1)
raw_model_metrics
# Out:
# array([0.00753218, 0.22768214, 0.04304937, 0.19757742], dtype=float32)

# %%
fine_tuned_model_metrics = df_test_all.apply(lambda x: calculate_bleu_rouge(x['output'], x['fine_tuned_llama_generations_with_control_codes_prompting']), axis=1)
fine_tuned_model_metrics = np.array(fine_tuned_model_metrics).mean(-1)
fine_tuned_model_metrics
# Out:
# array([0.00650947, 0.24681257, 0.03952901, 0.19356087], dtype=float32)

# %%
df_metrics = pd.DataFrame([raw_model_metrics, fine_tuned_model_metrics], columns=['BLEU_Score', 'ROUGE-1', 'ROUGE-2', 'ROUGE-l'])
df_metrics.index  = ['Raw_llama2', 'Fine_tuned_llama2']
df_metrics
# Out:
#                    BLEU_Score   ROUGE-1   ROUGE-2   ROUGE-l
# Raw_llama2           0.007532  0.227682  0.043049  0.197577
# Fine_tuned_llama2    0.006509  0.246813  0.039529  0.193561

# %%
prompt_engineering_templating_metrics = df_test_all.apply(lambda x: calculate_bleu_rouge(x['output'], x['prompt_engineering_control_codes_generations']), axis=1)
prompt_engineering_templating_metrics = np.array(prompt_engineering_templating_metrics).mean(-1)
prompt_engineering_templating_metrics
# Out:
# array([0.00463858, 0.26936254, 0.04948557, 0.22331083], dtype=float32)

# %%
df_metrics = pd.DataFrame([prompt_engineering_templating_metrics], columns=['BLEU_Score', 'ROUGE-1', 'ROUGE-2', 'ROUGE-l'])
df_metrics.index  = ['prompt_engineering_control_codes_metrics']
df_metrics
# Out:
#                                           BLEU_Score   ROUGE-1   ROUGE-2  \
# prompt_engineering_control_codes_metrics    0.004639  0.269363  0.049486
#
#                                            ROUGE-l
# prompt_engineering_control_codes_metrics  0.223311

# %%
df_metrics = pd.DataFrame([raw_model_metrics, fine_tuned_model_metrics, prompt_engineering_templating_metrics], columns=['BLEU_Score', 'ROUGE-1', 'ROUGE-2', 'ROUGE-l'])
df_metrics.index  = ['Raw_llama2', 'Fine_tuned_llama2_examples_prompting', 'prompt_engineering_control_codes_metrics']
df_metrics
# Out:
#                                           BLEU_Score   ROUGE-1   ROUGE-2  \
# Raw_llama2                                  0.007532  0.227682  0.043049
# Fine_tuned_llama2_examples_prompting        0.006509  0.246813  0.039529
# prompt_engineering_control_codes_metrics    0.004639  0.269363  0.049486
#
#                                            ROUGE-l
# Raw_llama2                                0.197577
# Fine_tuned_llama2_examples_prompting      0.193561
# prompt_engineering_control_codes_metrics  0.223311
