# %%
# !pip install -q  torch peft==0.4.0 bitsandbytes==0.40.2 transformers==4.31.0 trl==0.4.7 accelerate datasets
# import torch
import datasets
from datasets import load_dataset
from transformers import (
    AutoModelForCausalLM,
    AutoTokenizer,
    BitsAndBytesConfig,
    TrainingArguments,
    pipeline
)
# from peft import LoraConfig
# from trl import SFTTrainer
from datasets import Dataset, DatasetDict, load_dataset
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 72.9/72.9 kB 2.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 92.5/92.5 MB 8.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.4/7.4 MB 65.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 77.4/77.4 kB 6.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 280.0/280.0 kB 25.4 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 536.7/536.7 kB 20.3 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.8/7.8 MB 42.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 116.3/116.3 kB 13.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 134.8/134.8 kB 17.2 MB/s eta 0:00:00

# %% [markdown]
# ## **Load dataset from HuggingFace**

# %%
# Dataset
data_name = "jiuyuan/policy_AI"
# training_data = load_dataset(data_name, split="train")
test_data = load_dataset(data_name, split="test")
# Out:
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_token.py:88: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# Downloading readme:   0%|          | 0.00/445 [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/31.2k [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/8.78k [00:00<?, ?B/s]
# Generating train split:   0%|          | 0/75 [00:00<?, ? examples/s]
# Generating test split:   0%|          | 0/19 [00:00<?, ? examples/s]

# %%
df_test = test_data.to_pandas()
df_test
# Out:
#                                                 input  \
# 0   Why is international cooperation on AI important?
# 1   Can you describe the approach taken by the res...
# 2   What concerns do critics have regarding the EU...
# 3   How does the European Union classify AI system...
# 4   What are the Universal Guidelines for Artifici...
# 5   What role do whistleblowers and complaints pla...
# 6   How's UK's approach different from that of the...
# 7   How does Japan's approach to AI regulation dif...
# 8   What are foundational AI models, and why are t...
# 9   What additional measures are needed for intern...
# 10  What are the focus tasks of China’s New Genera...
# 11  What are the economic, ethical, and strategic ...
# 12  What role has the World Bank played in support...
# 13  How can the AI assurance industry contribute t...
# 14  What are some of the key principles outlined i...
# 15   What are main concerns in relation to AI policy?
# 16  How is international cooperation on AI current...
# 17  What are the basic principles set forth by the...
# 18  What is the World Bank's Policy on Access to I...
#
#                                                output
# 0   International cooperation on AI is crucial due...
# 1   The research team prepared generic interview p...
# 2   Critics, including EU businesses, have express...
# 3   The European Union's AI Act classifies AI syst...
# 4   The Universal Guidelines include rights to tra...
# 5   Whistleblowers and individual complaints are c...
# 6   Unlike the European Union (EU), the UK’s appro...
# 7   Japan focuses on a risk-based, agile, and mult...
# 8   Foundational AI models, such as large language...
# 9   The article suggests that more ambitious trade...
# 10  (1) Build open and coordinated AI science and ...
# 11  Issues include the ethical use of AI, strategi...
# 12  The World Bank launched the GovTech Global Par...
# 13  The AI assurance industry, comprising companie...
# 14  The Blueprint emphasizes principles such as th...
# 15  The need for AI policies to protect individual...
# 16  Governments are regulating AI, and internation...
# 17  In 2019, the Japanese government published the...
# 18  The policy outlines the World Bank's commitmen...

# %%
# df_test[['input']].to_csv('prompts.csv')

# %%
import pandas as pd
df_prompt = pd.read_csv("prompt_engineering.csv" )
df_prompt['prompt_engineering'] = df_prompt['prompt_engineering'].apply(lambda x:x[1:-1])
df_prompt
# Out:
#        0                                              input  \
# 0    1.0  Why is international cooperation on AI important?
# 1    2.0  Can you describe the approach taken by the res...
# 2    3.0  What concerns do critics have regarding the EU...
# 3    4.0  How does the European Union classify AI system...
# 4    5.0  What are the Universal Guidelines for Artifici...
# 5    6.0  What role do whistleblowers and complaints pla...
# 6    7.0  How's UK's approach different from that of the...
# 7    8.0  How does Japan's approach to AI regulation dif...
# 8    9.0  What are foundational AI models, and why are t...
# 9   10.0  What additional measures are needed for intern...
# 10  11.0  What are the focus tasks of China’s New Genera...
# 11  12.0  What are the economic, ethical, and strategic ...
# 12  13.0  What role has the World Bank played in support...
# 13  14.0  How can the AI assurance industry contribute t...
# 14  15.0  What are some of the key principles outlined i...
# 15  16.0   What are main concerns in relation to AI policy?
# 16  17.0  How is international cooperation on AI current...
# 17  18.0  What are the basic principles set forth by the...
# 18   NaN  What is the World Bank's Policy on Access to I...
#
#                                    prompt_engineering
# 0   Explain the significance of international coll...
# 1   Outline the methodology adopted by the researc...
# 2   Discuss the main concerns raised by critics re...
# 3   Describe how the European Union's AI Act class...
# 4   Summarize the Universal Guidelines for Artific...
# 5   Analyze the role of whistleblowers and the com...
# 6   Detail the key differences between the United ...
# 7   Examine how Japan's approach to AI regulation ...
# 8   Define what foundational AI models are and dis...
# 9   Identify and elaborate on the additional measu...
# 10  Summarize the focus tasks outlined in China's ...
# 11  Discuss the economic, ethical, and strategic i...
# 12  Describe the role that the World Bank has play...
# 13  Examine how the AI assurance industry can play...
# 14  Summarize the key principles outlined in the W...
# 15  Identify and elaborate on the main concerns cu...
# 16  Describe the various methods through which int...
# 17  Outline the basic principles set forth by the ...
# 18  Explain the World Bank's Policy on Access to I...

# %%
def prompt_engineering(df):
    output_texts = []

    for i in range(len(df['input'])):
        row = df.iloc[i]
        text = f"### Question: {row['input']}\n Briefly, in 100 words use this template to answer the questions {row['prompt_engineering']} ### Answer: "
        output_texts.append(text)
    return output_texts

df_prompt['prompt']= prompt_engineering(df_prompt)
print(df_prompt.iloc[0]['prompt'])
df_prompt
# Out:
# ### Question: Why is international cooperation on AI important?
#  Briefly, in 100 words use this template to answer the questions Explain the significance of international collaboration in the development and regulation of artificial intelligence technologies. Specifically, detail the benefits such cooperation brings in harmonizing standards, preventing a regulatory race to the bottom, and addressing global challenges like AI safety and ethical use. ### Answer:
#        0                                              input  \
# 0    1.0  Why is international cooperation on AI important?
# 1    2.0  Can you describe the approach taken by the res...
# 2    3.0  What concerns do critics have regarding the EU...
# 3    4.0  How does the European Union classify AI system...
# 4    5.0  What are the Universal Guidelines for Artifici...
# 5    6.0  What role do whistleblowers and complaints pla...
# 6    7.0  How's UK's approach different from that of the...
# 7    8.0  How does Japan's approach to AI regulation dif...
# 8    9.0  What are foundational AI models, and why are t...
# 9   10.0  What additional measures are needed for intern...
# 10  11.0  What are the focus tasks of China’s New Genera...
# 11  12.0  What are the economic, ethical, and strategic ...
# 12  13.0  What role has the World Bank played in support...
# 13  14.0  How can the AI assurance industry contribute t...
# 14  15.0  What are some of the key principles outlined i...
# 15  16.0   What are main concerns in relation to AI policy?
# 16  17.0  How is international cooperation on AI current...
# 17  18.0  What are the basic principles set forth by the...
# 18   NaN  What is the World Bank's Policy on Access to I...
#
#                                    prompt_engineering  \
# 0   Explain the significance of international coll...
# 1   Outline the methodology adopted by the researc...
# 2   Discuss the main concerns raised by critics re...
# 3   Describe how the European Union's AI Act class...
# 4   Summarize the Universal Guidelines for Artific...
# 5   Analyze the role of whistleblowers and the com...
# 6   Detail the key differences between the United ...
# 7   Examine how Japan's approach to AI regulation ...
# 8   Define what foundational AI models are and dis...
# 9   Identify and elaborate on the additional measu...
# 10  Summarize the focus tasks outlined in China's ...
# 11  Discuss the economic, ethical, and strategic i...
# 12  Describe the role that the World Bank has play...
# 13  Examine how the AI assurance industry can play...
# 14  Summarize the key principles outlined in the W...
# 15  Identify and elaborate on the main concerns cu...
# 16  Describe the various methods through which int...
# 17  Outline the basic principles set forth by the ...
# 18  Explain the World Bank's Policy on Access to I...
#
#                                                prompt
# 0   ### Question: Why is international cooperation...
# 1   ### Question: Can you describe the approach ta...
# 2   ### Question: What concerns do critics have re...
# 3   ### Question: How does the European Union clas...
# 4   ### Question: What are the Universal Guideline...
# 5   ### Question: What role do whistleblowers and ...
# 6   ### Question: How's UK's approach different fr...
# 7   ### Question: How does Japan's approach to AI ...
# 8   ### Question: What are foundational AI models,...
# 9   ### Question: What additional measures are nee...
# 10  ### Question: What are the focus tasks of Chin...
# 11  ### Question: What are the economic, ethical, ...
# 12  ### Question: What role has the World Bank pla...
# 13  ### Question: How can the AI assurance industr...
# 14  ### Question: What are some of the key princip...
# 15  ### Question: What are main concerns in relati...
# 16  ### Question: How is international cooperation...
# 17  ### Question: What are the basic principles se...
# 18  ### Question: What is the World Bank's Policy ...

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# Model and tokenizer names
import torch
base_model_name = "NousResearch/Llama-2-7b-chat-hf"
# refined_model = "llama-2-7b-mlabonne-enhanced"

# Tokenizer
llama_tokenizer = AutoTokenizer.from_pretrained(base_model_name, trust_remote_code=True)
llama_tokenizer.pad_token = llama_tokenizer.eos_token
llama_tokenizer.padding_side = "right"  # Fix for fp16

# Quantization Config
quant_config = BitsAndBytesConfig(
    load_in_4bit=True,
    bnb_4bit_quant_type="nf4",
    bnb_4bit_compute_dtype=torch.float16,
    bnb_4bit_use_double_quant=False
)

# Model
base_model = AutoModelForCausalLM.from_pretrained(
    base_model_name,
    quantization_config=quant_config,
    device_map={"": 0}
)
base_model.config.use_cache = False
base_model.config.pretraining_tp = 1
# Out:
# tokenizer_config.json:   0%|          | 0.00/746 [00:00<?, ?B/s]
# tokenizer.model:   0%|          | 0.00/500k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/1.84M [00:00<?, ?B/s]
# added_tokens.json:   0%|          | 0.00/21.0 [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/435 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/583 [00:00<?, ?B/s]
# model.safetensors.index.json:   0%|          | 0.00/26.8k [00:00<?, ?B/s]
# Downloading shards:   0%|          | 0/2 [00:00<?, ?it/s]
# model-00001-of-00002.safetensors:   0%|          | 0.00/9.98G [00:00<?, ?B/s]
# model-00002-of-00002.safetensors:   0%|          | 0.00/3.50G [00:00<?, ?B/s]
# Loading checkpoint shards:   0%|          | 0/2 [00:00<?, ?it/s]
# generation_config.json:   0%|          | 0.00/179 [00:00<?, ?B/s]

# %% [markdown]
# ## **Generations & Evaluation**

# %%
from tqdm.notebook import tqdm
import gc
generations_prompt_engineer_templating =[]
for i in tqdm(range(len(df_prompt)), "generating..."):
  prompt = df_prompt.iloc[i]['prompt']
  # Generate predictions
  inputs = llama_tokenizer(prompt, return_tensors='pt')
  inputs = inputs.to("cuda")
  output = base_model.generate(**inputs, max_new_tokens=200,temperature=0.2)
  response = llama_tokenizer.decode(output[0].tolist())
  print(response)
  # break
  generations_prompt_engineer_templating.append(response)
  del inputs, output
  gc.collect()
  torch.cuda.empty_cache()

# generations_original
# Out:
# generating...:   0%|          | 0/19 [00:00<?, ?it/s]
# <s> ### Question: Why is international cooperation on AI important?
#  Briefly, in 100 words use this template to answer the questions Explain the significance of international collaboration in the development and regulation of artificial intelligence technologies. Specifically, detail the benefits such cooperation brings in harmonizing standards, preventing a regulatory race to the bottom, and addressing global challenges like AI safety and ethical use. ### Answer:  International cooperation on AI is crucial for several reasons. Firstly, it helps harmonize standards and regulations, ensuring a consistent approach across different countries and avoiding a regulatory race to the bottom. This promotes trust and confidence in AI technologies, as well as fair competition among companies. Secondly, international cooperation enables the sharing of knowledge, expertise, and resources, accelerating AI research and development. This can lead to more innovative and effective AI solutions, addressing global challenges like AI safety and ethical use. Finally, international cooperation fosters a collective understanding of AI's potential impact, enabling countries to work together to address emerging challenges and ensure AI's responsible use. By working together, countries can develop and implement AI technologies that benefit humanity as a whole.</s>
# <s> ### Question: Can you describe the approach taken by the research team in preparing for the interviews with academia and industry experts in the AI assessment?
#  Briefly, in 100 words use this template to answer the questions Outline the methodology adopted by the research team in preparing for and conducting interviews with experts from academia and the industry in the context of AI assessment. Highlight the criteria for selecting interviewees, the types of questions asked to gather diverse perspectives, and how the information was synthesized to inform policy recommendations. ### Answer:  The research team adopted a multi-stage approach in preparing for and conducting interviews with experts in academia and industry for the AI assessment. First, a comprehensive literature review was conducted to identify key themes and challenges in AI assessment. Second, a diverse pool of interviewees was selected based on their expertise and experience in AI assessment, including academics, policymakers, and industry leaders. Third, a set of open-ended questions was developed to gather diverse perspectives on AI assessment, including questions on the effectiveness of current approaches, challenges and limitations, and potential future directions. Finally, the information gathered from the interviews was synthesized and analyzed to inform policy recommendations for improving AI assessment.</s>
# <s> ### Question: What concerns do critics have regarding the EU's AI Act's potential impact on innovation and competitiveness?
#  Briefly, in 100 words use this template to answer the questions Discuss the main concerns raised by critics regarding the European Union's AI Act, particularly focusing on its potential impact on innovation and competitiveness within the EU. Analyze how the regulation might hinder or foster technological advancement and the competitiveness of European AI industries on a global scale. ### Answer:  Critics argue that the EU's AI Act may stifle innovation and competitiveness within the EU by imposing overly restrictive regulations on AI development and deployment. They fear that the Act's requirements for transparency, accountability, and ethical use of AI may lead to increased costs, longer development times, and reduced access to funding and talent. Additionally, the Act's focus on "high-risk" AI applications may inadvertently limit the development of promising AI technologies, such as those in the fields of healthcare and transportation. Furthermore, the Act's extraterritorial reach may create difficulties for EU-based companies seeking to operate in other jurisdictions with less stringent AI regulations, potentially hindering their global competitiveness.</s>
# <s> ### Question: How does the European Union classify AI systems under its AI Act, and what are the implications for "high risk" AI systems?
#  Briefly, in 100 words use this template to answer the questions Describe how the European Union's AI Act classifies AI systems, with a special focus on the criteria used to identify 'high-risk' AI systems. Expand on the regulatory implications for these high-risk categories, including the compliance requirements and the potential effects on their development and deployment within the EU market. ### Answer:  The European Union's AI Act classifies AI systems into three categories: low-risk, high-risk, and unacceptable risk. Low-risk AI systems are those that do not pose a significant risk to individuals, society, or the environment, such as AI-powered calculators or language translation tools. High-risk AI systems are those that have the potential to cause significant harm, such as autonomous weapons or AI systems used for mass surveillance. Unacceptable risk AI systems are those that are prohibited within the EU, such as AI systems that are inherently discriminatory or that undermine human dignity. For high-risk AI systems, the EU has established compliance requirements, including rigorous testing and validation, robust cybersecurity measures, and transparent and explainable AI. Non-compliance with these requirements can result in fines and other penalties.
# <s> ### Question: What are the Universal Guidelines for Artificial Intelligence endorsed by EPIC?
#  Briefly, in 100 words use this template to answer the questions Summarize the Universal Guidelines for Artificial Intelligence as endorsed by the Electronic Privacy Information Center (EPIC). Focus on the key principles outlined in the guidelines, how they propose to safeguard individual rights, and the role these guidelines play in shaping ethical and responsible AI development practices globally. ### Answer:  The Universal Guidelines for Artificial Intelligence endorsed by EPIC are a set of principles aimed at safeguarding individual rights and promoting ethical and responsible AI development practices globally. The guidelines focus on key principles such as transparency, accountability, and fairness, and propose to ensure that AI systems are designed and developed with respect for human rights, privacy, and dignity. These guidelines play a crucial role in shaping ethical and responsible AI development practices by providing a framework for developers, policymakers, and other stakeholders to follow, and by promoting a culture of accountability and transparency in the AI industry. By endorsing these guidelines, EPIC is contributing to the development of a more ethical and responsible AI ecosystem that prioritizes individual rights and promotes trustworthy AI systems.</s>
# <s> ### Question: What role do whistleblowers and complaints play in the AI regulatory process?
#  Briefly, in 100 words use this template to answer the questions Analyze the role of whistleblowers and the complaints process in the regulatory oversight of artificial intelligence. Discuss how these elements contribute to transparency, accountability, and enforcement of AI regulations, and the mechanisms in place to protect and encourage individuals to report unethical or illegal AI practices. ### Answer:  Whistleblowers and complaints play a crucial role in the AI regulatory process by serving as early warning systems for unethical or illegal AI practices. Whistleblowers can report potential violations of AI regulations, while complaints can provide valuable information on the effectiveness of existing regulations and identify areas for improvement. Both mechanisms contribute to transparency and accountability by providing a means for individuals to report concerns without fear of retribution. To encourage reporting, regulatory bodies must establish robust protections for whistleblowers and complaints, including confidentiality and immunity from legal action. Additionally, regulatory bodies must ensure that complaints are handled promptly and fairly, with appropriate consequences for non-compliance. By fostering a culture of transparency and accountability, these mechanisms can help ensure that AI regulations are enforced effectively and ethically.</s>
# <s> ### Question: How's UK's approach different from that of the European Union?
#  Briefly, in 100 words use this template to answer the questions Detail the key differences between the United Kingdom's approach to regulating artificial intelligence and that of the European Union. Focus on the regulatory frameworks, objectives, and any specific areas where the UK's strategy diverges significantly from the EU's, including the impact on innovation, privacy, and international collaboration. ### Answer:  The UK's approach to regulating AI differs from the EU's in several key areas. The UK's AI Regulatory Framework focuses on ensuring AI is used ethically and responsibly, with a focus on transparency, accountability, and fairness. The EU's General Data Protection Regulation (GDPR) provides a broader framework for data protection and privacy, including specific provisions for AI. The UK's approach prioritizes innovation and international collaboration, while the EU's approach emphasizes data protection and privacy. The UK's AI Strategy also includes provisions for AI standards and a new AI governance body, while the EU's approach relies on existing data protection and privacy laws. Overall, the UK's approach is more flexible and tailored to the specific needs of the UK, while the EU's approach is more comprehensive and
# <s> ### Question: How does Japan's approach to AI regulation differ from that of the European Commission and Canada?
#  Briefly, in 100 words use this template to answer the questions Examine how Japan's approach to AI regulation contrasts with those of the European Commission and Canada. Highlight the unique aspects of Japan's strategy, particularly in terms of policy objectives, regulatory measures, stakeholder engagement, and how these differences reflect Japan's cultural, economic, and technological priorities. ### Answer:  Japan's approach to AI regulation differs significantly from that of the European Commission and Canada. While the European Commission focuses on ethical considerations and data privacy, Japan prioritizes the development of AI talent and innovation. Japan's policy objectives are more focused on promoting AI adoption and maximizing economic benefits, whereas the European Commission and Canada prioritize ensuring AI is used responsibly and ethically. Japan's regulatory measures are more light-touch, with a focus on guidelines and industry self-regulation, whereas the European Commission and Canada have more prescriptive regulations. Japan engages more closely with industry stakeholders, particularly large tech companies, whereas the European Commission and Canada prioritize engagement with civil society and smaller start-ups. Japan's approach reflects its cultural priorities, such as a strong emphasis on consensus-building and harmony, as well
# <s> ### Question: What are foundational AI models, and why are they important?
#  Briefly, in 100 words use this template to answer the questions Define what foundational AI models are and discuss their significance in the broader landscape of artificial intelligence development. Elaborate on their potential impacts on innovation, ethical considerations, and the challenges they pose for regulation and governance. ### Answer:  Foundational AI models are the fundamental building blocks of artificial intelligence, including machine learning algorithms, neural networks, and deep learning techniques. These models are essential for developing more complex AI systems and have significant implications for innovation, ethical considerations, and regulatory challenges. For instance, the development of foundational models has enabled the creation of applications such as image and speech recognition, natural language processing, and autonomous vehicles. However, these models also raise ethical concerns, such as privacy and bias, which must be addressed through careful governance and regulation. Overall, foundational AI models are crucial for advancing AI research and development, but their widespread adoption also poses significant challenges for ensuring responsible and ethical AI use.</s>
# <s> ### Question: What additional measures are needed for international cooperation on foundational AI models?
#  Briefly, in 100 words use this template to answer the questions Identify and elaborate on the additional measures needed to foster effective international cooperation on the development, regulation, and ethical use of foundational AI models. Discuss how these measures can address challenges such as intellectual property rights, data privacy, and ensuring equitable access to AI benefits across countries. ### Answer:  To foster effective international cooperation on foundational AI models, additional measures are needed to address challenges such as intellectual property rights, data privacy, and ensuring equitable access to AI benefits across countries. These measures include: 1. Establishing international norms and standards for AI development and use, such as guidelines for data privacy and security, and standards for explainability and transparency. 2. Creating multilateral agreements or treaties that address intellectual property rights and data sharing, while also promoting collaboration and knowledge sharing among countries. 3. Supporting capacity building and training programs for researchers and policymakers in developing countries, to ensure equitable access to AI benefits and promote inclusive AI development. 4. Encouraging the development of AI governance frameworks that prioritize ethical considerations and promote responsible AI use, and that are adaptable to different cultural and
# <s> ### Question: What are the focus tasks of China’s New Generation Artificial Intelligence Development?
#  Briefly, in 100 words use this template to answer the questions Summarize the focus tasks outlined in China's New Generation Artificial Intelligence Development Plan. Analyze how these tasks are designed to advance China's AI capabilities, their implications for global AI competitiveness, and the role of these tasks in achieving China's strategic objectives in technology and economy. ### Answer:  China's New Generation Artificial Intelligence Development Plan outlines several focus tasks to advance the country's AI capabilities, including: 1. Developing core AI technologies, such as machine learning, natural language processing, and computer vision. 2. Building AI-powered industrial chains, including AI-enabled manufacturing, logistics, and supply chain management. 3. Promoting AI application in key industries, such as healthcare, finance, and education. 4. Enhancing AI security and privacy, including developing secure AI algorithms and protecting personal data. These tasks are designed to advance China's AI capabilities by investing in research and development, fostering innovation, and promoting collaboration between academia, industry, and government. The implications for global AI competitiveness are significant, as China aims to become a leader in AI development and application. The plan'
# <s> ### Question: What are the economic, ethical, and strategic issues that call into question the continuation of collaboration on AI with China?
#  Briefly, in 100 words use this template to answer the questions Discuss the economic, ethical, and strategic issues that have emerged, calling into question the sustainability and desirability of continued AI collaboration with China. Consider aspects such as intellectual property rights, data privacy, human rights, and geopolitical tensions in your analysis. ### Answer:  Economic issues: China's aggressive pursuit of AI technology and talent has led to concerns about intellectual property theft and unequal access to global markets. Ethical issues: China's human rights record and lack of transparency in AI development raise concerns about the ethical implications of collaborating with a government that may be using AI for nefarious purposes. Strategic issues: Geopolitical tensions between China and Western countries have led to questions about the long-term viability of collaboration with a country that may pose a threat to global security.</s>
# <s> ### Question: What role has the World Bank played in supporting AI in the public sector?
#  Briefly, in 100 words use this template to answer the questions Describe the role that the World Bank has played in supporting the integration and development of artificial intelligence technologies within the public sector. Focus on the initiatives, programs, and partnerships that the World Bank has established to promote AI as a tool for economic development, governance, and public service improvement in developing countries. ### Answer:  The World Bank has played a significant role in supporting the integration and development of AI technologies within the public sector, particularly in developing countries. The Bank has established various initiatives, programs, and partnerships to promote AI as a tool for economic development, governance, and public service improvement. For instance, the World Bank's Artificial Intelligence for Development (AI4D) program aims to support developing countries in leveraging AI to address development challenges, such as poverty reduction, healthcare improvement, and environmental sustainability. The program provides technical assistance, capacity building, and funding support to governments, civil society organizations, and the private sector to develop and implement AI-based solutions. Additionally, the World Bank has partnered with leading AI organizations, such as the Allen Institute for Artificial Intelligence and the International Development Association, to promote the ethical and responsible use of AI in the public sector. These partnerships
# <s> ### Question: How can the AI assurance industry contribute to regulatory compliance and AI system improvement?
#  Briefly, in 100 words use this template to answer the questions Examine how the AI assurance industry can play a pivotal role in supporting regulatory compliance and improving AI systems. Discuss the mechanisms through which assurance services can identify and mitigate risks, ensure ethical guidelines are followed, and foster trust among users and regulators. ### Answer:  The AI assurance industry can significantly contribute to regulatory compliance and AI system improvement by providing independent, third-party assessments of AI systems' design, development, and deployment. These assessments can identify potential risks, such as bias, privacy violations, or security vulnerabilities, and provide recommendations for mitigation. Additionally, assurance services can help ensure that AI systems comply with ethical guidelines and standards, such as those related to data privacy, fairness, and accountability. By fostering trust among users and regulators, AI assurance services can help promote the widespread adoption of AI systems while minimizing the risks associated with their use.</s>
# <s> ### Question: What are some of the key principles outlined in the White House's Blueprint for an AI Bill of Rights?
#  Briefly, in 100 words use this template to answer the questions Summarize the key principles outlined in the White House's Blueprint for an AI Bill of Rights. Analyze how each principle aims to protect citizens in the digital age, the implications for AI developers, and the potential impact on shaping future AI governance frameworks. ### Answer:  The White House's Blueprint for an AI Bill of Rights outlines six key principles aimed at protecting citizens' rights in the digital age. These principles include: 1) Transparency and Explainability: Requiring AI systems to be transparent and explainable to users, ensuring accountability and trustworthiness. 2) Safety and Security: Protecting individuals from AI systems that could cause physical or emotional harm, and ensuring secure data practices. 3) Privacy: Respecting individuals' privacy rights and protecting their personal information. 4) Non-Discrimination: Preventing AI systems from perpetuating discrimination or biases, and promoting fairness and equity. 5) Contestability and Criticism: Encouraging openness to criticism and contestability of AI systems, promoting innovation and improvement. 6) Human Overs
# <s> ### Question: What are main concerns in relation to AI policy?
#  Briefly, in 100 words use this template to answer the questions Identify and elaborate on the main concerns currently facing policymakers in the realm of AI policy. Discuss the complexities surrounding issues such as privacy, accountability, transparency, and the ethical use of AI, and how these concerns influence the development of regulatory frameworks. ### Answer:  The main concerns in AI policy are: Privacy: Ensuring that AI systems do not infringe on individuals' right to privacy, particularly in the collection and use of personal data. Accountability: Ensuring that AI systems are transparent and accountable, and that there are mechanisms in place to hold developers and users responsible for any adverse consequences. Transparency: Ensuring that AI systems are understandable and explainable, so that individuals can trust their decisions and actions. Ethical use: Ensuring that AI systems are used ethically and responsibly, and that they do not perpetuate biases or discrimination. These concerns are complex and interrelated, and they influence the development of regulatory frameworks that balance the benefits of AI with the need to protect individuals' rights and well-being.</s>
# <s> ### Question: How is international cooperation on AI currently being pursued?
#  Briefly, in 100 words use this template to answer the questions Describe the various methods through which international cooperation on AI is being pursued. Highlight the roles of international organizations, bilateral agreements, and global forums in facilitating collaboration on AI governance, standards setting, and addressing cross-border challenges. ### Answer:  International cooperation on AI is being pursued through various methods, including:
#
# 1. International organizations: International organizations such as the United Nations, the European Union, and the Organization for Economic Cooperation and Development (OECD) are promoting global dialogue and cooperation on AI governance, standards setting, and ethical considerations.
#
# 2. Bilateral agreements: Countries are entering into bilateral agreements to collaborate on AI research and development, data sharing, and addressing cross-border challenges. For example, the United States and China have signed agreements on AI cooperation.
#
# 3. Global forums: Global forums such as the World Economic Forum, the AI for Good Global Summit, and the AI World Forum provide platforms for countries to discuss and address AI-related issues, including ethical considerations, data privacy, and security.
#
# 4.
# <s> ### Question: What are the basic principles set forth by the Japanese government for AI regulation in 2019?
#  Briefly, in 100 words use this template to answer the questions Outline the basic principles set forth by the Japanese government for AI regulation in 2019. Discuss how these principles reflect Japan's approach to fostering innovation while ensuring ethical standards, user safety, and privacy, and compare these to global trends in AI regulation. ### Answer:  In 2019, the Japanese government set forth basic principles for AI regulation, focusing on ethical standards, user safety, and privacy. These principles include: 1) transparency in AI development and deployment, 2) accountability for AI systems, 3) protection of personal information, 4) cybersecurity measures, and 5) human oversight in AI decision-making. These principles reflect Japan's approach to balancing innovation with ethical standards, safety, and privacy. Compared to global trends, Japan's approach emphasizes a more proactive and comprehensive approach to AI regulation, with a focus on human oversight and accountability. This differs from other countries' approaches, which may prioritize industry self-regulation or rely more heavily on existing laws and regulations.</s>
# <s> ### Question: What is the World Bank's Policy on Access to Information?
#  Briefly, in 100 words use this template to answer the questions Explain the World Bank's Policy on Access to Information and its significance. Discuss how this policy supports transparency, accountability, and public participation in the Bank's operations, and the impact of this policy on promoting good governance and development outcomes. ### Answer:  The World Bank's Policy on Access to Information (ATI) aims to promote transparency, accountability, and public participation in the Bank's operations. The policy provides for the disclosure of information on the Bank's activities, decisions, and operations, including documents, data, and other materials. The significance of this policy lies in its support for good governance, accountability, and development outcomes. By providing access to information, the Bank promotes transparency and accountability, enabling citizens and stakeholders to hold the Bank accountable for its actions and decisions. This, in turn, fosters trust and confidence in the Bank's operations, which is essential for promoting development outcomes. The policy also supports public participation in the Bank's operations, enabling citizens to engage in decision-making processes and to contribute to the Bank's efforts to promote sustainable development. Overall, the ATI policy

# %%
df_test['prompt_engineering_templating_generations']=generations_prompt_engineer_templating
df_test
# Out:
#                                                 input  \
# 0   Why is international cooperation on AI important?
# 1   Can you describe the approach taken by the res...
# 2   What concerns do critics have regarding the EU...
# 3   How does the European Union classify AI system...
# 4   What are the Universal Guidelines for Artifici...
# 5   What role do whistleblowers and complaints pla...
# 6   How's UK's approach different from that of the...
# 7   How does Japan's approach to AI regulation dif...
# 8   What are foundational AI models, and why are t...
# 9   What additional measures are needed for intern...
# 10  What are the focus tasks of China’s New Genera...
# 11  What are the economic, ethical, and strategic ...
# 12  What role has the World Bank played in support...
# 13  How can the AI assurance industry contribute t...
# 14  What are some of the key principles outlined i...
# 15   What are main concerns in relation to AI policy?
# 16  How is international cooperation on AI current...
# 17  What are the basic principles set forth by the...
# 18  What is the World Bank's Policy on Access to I...
#
#                                                output  \
# 0   International cooperation on AI is crucial due...
# 1   The research team prepared generic interview p...
# 2   Critics, including EU businesses, have express...
# 3   The European Union's AI Act classifies AI syst...
# 4   The Universal Guidelines include rights to tra...
# 5   Whistleblowers and individual complaints are c...
# 6   Unlike the European Union (EU), the UK’s appro...
# 7   Japan focuses on a risk-based, agile, and mult...
# 8   Foundational AI models, such as large language...
# 9   The article suggests that more ambitious trade...
# 10  (1) Build open and coordinated AI science and ...
# 11  Issues include the ethical use of AI, strategi...
# 12  The World Bank launched the GovTech Global Par...
# 13  The AI assurance industry, comprising companie...
# 14  The Blueprint emphasizes principles such as th...
# 15  The need for AI policies to protect individual...
# 16  Governments are regulating AI, and internation...
# 17  In 2019, the Japanese government published the...
# 18  The policy outlines the World Bank's commitmen...
#
#             prompt_engineering_templating_generations
# 0   <s> ### Question: Why is international coopera...
# 1   <s> ### Question: Can you describe the approac...
# 2   <s> ### Question: What concerns do critics hav...
# 3   <s> ### Question: How does the European Union ...
# 4   <s> ### Question: What are the Universal Guide...
# 5   <s> ### Question: What role do whistleblowers ...
# 6   <s> ### Question: How's UK's approach differen...
# 7   <s> ### Question: How does Japan's approach to...
# 8   <s> ### Question: What are foundational AI mod...
# 9   <s> ### Question: What additional measures are...
# 10  <s> ### Question: What are the focus tasks of ...
# 11  <s> ### Question: What are the economic, ethic...
# 12  <s> ### Question: What role has the World Bank...
# 13  <s> ### Question: How can the AI assurance ind...
# 14  <s> ### Question: What are some of the key pri...
# 15  <s> ### Question: What are main concerns in re...
# 16  <s> ### Question: How is international coopera...
# 17  <s> ### Question: What are the basic principle...
# 18  <s> ### Question: What is the World Bank's Pol...

# %%
df_test_all = df_test
# df_test_all['original_llama_generations']= df_test_all['original_llama_generations'].apply(lambda x: x.split('Answer:', 1)[-1] if 'Answer:' in x else x)
# df_test_all['original_llama_generations']= df_test_all['original_llama_generations'].apply(lambda x: x.replace('</s>', '').replace('<s>', '').replace('</s>s', '').replace('<s/>', '').replace('s ', ''))
df_test_all['prompt_engineering_templating_generations']= df_test_all['prompt_engineering_templating_generations'].apply(lambda x: x.split('Answer:', 1)[-1] if 'Answer:' in x else x)
df_test_all['prompt_engineering_templating_generations']= df_test_all['prompt_engineering_templating_generations'].apply(lambda x: x.replace('</s>', '').replace('<s>', '').replace('</s>s', '').replace('<s/>', ''))
df_test_all
# Out:
#                                                 input  \
# 0   Why is international cooperation on AI important?
# 1   Can you describe the approach taken by the res...
# 2   What concerns do critics have regarding the EU...
# 3   How does the European Union classify AI system...
# 4   What are the Universal Guidelines for Artifici...
# 5   What role do whistleblowers and complaints pla...
# 6   How's UK's approach different from that of the...
# 7   How does Japan's approach to AI regulation dif...
# 8   What are foundational AI models, and why are t...
# 9   What additional measures are needed for intern...
# 10  What are the focus tasks of China’s New Genera...
# 11  What are the economic, ethical, and strategic ...
# 12  What role has the World Bank played in support...
# 13  How can the AI assurance industry contribute t...
# 14  What are some of the key principles outlined i...
# 15   What are main concerns in relation to AI policy?
# 16  How is international cooperation on AI current...
# 17  What are the basic principles set forth by the...
# 18  What is the World Bank's Policy on Access to I...
#
#                                                output  \
# 0   International cooperation on AI is crucial due...
# 1   The research team prepared generic interview p...
# 2   Critics, including EU businesses, have express...
# 3   The European Union's AI Act classifies AI syst...
# 4   The Universal Guidelines include rights to tra...
# 5   Whistleblowers and individual complaints are c...
# 6   Unlike the European Union (EU), the UK’s appro...
# 7   Japan focuses on a risk-based, agile, and mult...
# 8   Foundational AI models, such as large language...
# 9   The article suggests that more ambitious trade...
# 10  (1) Build open and coordinated AI science and ...
# 11  Issues include the ethical use of AI, strategi...
# 12  The World Bank launched the GovTech Global Par...
# 13  The AI assurance industry, comprising companie...
# 14  The Blueprint emphasizes principles such as th...
# 15  The need for AI policies to protect individual...
# 16  Governments are regulating AI, and internation...
# 17  In 2019, the Japanese government published the...
# 18  The policy outlines the World Bank's commitmen...
#
#             prompt_engineering_templating_generations
# 0     International cooperation on AI is crucial f...
# 1     The research team adopted a multi-stage appr...
# 2     Critics argue that the EU's AI Act may stifl...
# 3     The European Union's AI Act classifies AI sy...
# 4     The Universal Guidelines for Artificial Inte...
# 5     Whistleblowers and complaints play a crucial...
# 6     The UK's approach to regulating AI differs f...
# 7     Japan's approach to AI regulation differs si...
# 8     Foundational AI models are the fundamental b...
# 9     To foster effective international cooperatio...
# 10    China's New Generation Artificial Intelligen...
# 11    Economic issues: China's aggressive pursuit ...
# 12    The World Bank has played a significant role...
# 13    The AI assurance industry can significantly ...
# 14    The White House's Blueprint for an AI Bill o...
# 15    The main concerns in AI policy are: Privacy:...
# 16    International cooperation on AI is being pur...
# 17    In 2019, the Japanese government set forth b...
# 18    The World Bank's Policy on Access to Informa...

# %%
df_test_all.to_csv('prompt_engineering_templating_results.csv')

# %% [markdown]
# ## **Metrics**

# %%
import locale
locale.getpreferredencoding = lambda: "UTF-8"
# !pip install nltk rouge -q
from nltk.translate.bleu_score import sentence_bleu
from rouge import Rouge

# %%
import numpy as np
import warnings
warnings.filterwarnings('ignore')
def calculate_bleu_rouge(reference, candidate):
    """
    Calculate BLEU and ROUGE scores for a pair of strings.

    :param reference: The reference string (ground truth).
    :param candidate: The candidate string (generated text).
    :return: A dictionary containing BLEU and ROUGE scores.
    """
    # Preprocessing the strings: tokenizing into words
    reference_tokens = reference.split()
    candidate_tokens = candidate.split()

    # Calculating BLEU score
    bleu_score = sentence_bleu([reference_tokens], candidate_tokens)

    # Calculating ROUGE score
    rouge = Rouge()
    rouge_score = rouge.get_scores(candidate, reference)[0]

    return np.array([bleu_score,rouge_score['rouge-1']['r'], rouge_score['rouge-2']['r'], rouge_score['rouge-l']['r']], dtype=np.float32)

# Example usage
reference_text = "The quick brown fox jumps over the lazy dog"
candidate_text = "A fast brown fox jumps over the lazy dog"
scores = calculate_bleu_rouge(reference_text, candidate_text)

print(scores)
# Out:
# [0.7259795 0.7777778 0.75      0.7777778]

# %%
raw_model_metrics = df_test_all.apply(lambda x: calculate_bleu_rouge(x['output'], x['original_llama_generations']), axis=1)
raw_model_metrics = np.array(raw_model_metrics).mean(-1)
raw_model_metrics

# %%
fine_tuned_model_metrics = df_test_all.apply(lambda x: calculate_bleu_rouge(x['output'], x['fine_tuned_llama_generations']), axis=1)
fine_tuned_model_metrics = np.array(fine_tuned_model_metrics).mean(-1)
fine_tuned_model_metrics

# %%
df_metrics = pd.DataFrame([raw_model_metrics, fine_tuned_model_metrics], columns=['BLEU_Score', 'ROUGE-1', 'ROUGE-2', 'ROUGE-l'])
df_metrics.index  = ['Raw_llama2', 'Fine_tuned_llama2']
df_metrics
# Out:
#                    BLEU_Score   ROUGE-1   ROUGE-2   ROUGE-l
# Raw_llama2           0.006728  0.213823  0.035865  0.176707
# Fine_tuned_llama2    0.121606  0.395751  0.212141  0.357660

# %%
prompt_engineering_templating_metrics = df_test_all.apply(lambda x: calculate_bleu_rouge(x['output'], x['prompt_engineering_templating_generations']), axis=1)
prompt_engineering_templating_metrics = np.array(prompt_engineering_templating_metrics).mean(-1)
prompt_engineering_templating_metrics
# Out:
# array([0.01284725, 0.3726294 , 0.09197154, 0.31473532], dtype=float32)

# %%
raw_model_metrics = ['0.006728',	'0.213823',	'0.035865',	'0.176707']
df_metrics = pd.DataFrame([raw_model_metrics, prompt_engineering_templating_metrics], columns=['BLEU_Score', 'ROUGE-1', 'ROUGE-2', 'ROUGE-l'])
df_metrics.index  = ['Raw_llama2','templating_prompt_engineering_metrics']
df_metrics
# Out:
#                                       BLEU_Score   ROUGE-1   ROUGE-2   ROUGE-l
# Raw_llama2                              0.006728  0.213823  0.035865  0.176707
# templating_prompt_engineering_metrics   0.012847  0.372629  0.091972  0.314735
