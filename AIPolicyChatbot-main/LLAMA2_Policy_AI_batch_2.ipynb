# %%
# !pip install -q  torch peft==0.4.0 bitsandbytes==0.40.2 transformers==4.31.0 trl==0.4.7 accelerate  datasets #xformers
import transformers
import torch
import datasets
from datasets import load_dataset
from transformers import (
    AutoModelForCausalLM,
    AutoTokenizer,
    BitsAndBytesConfig,
    TrainingArguments,
    pipeline
)
from peft import LoraConfig
from trl import SFTTrainer
import warnings
warnings.filterwarnings("ignore", category=FutureWarning)
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 72.9/72.9 kB 2.4 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 92.5/92.5 MB 19.0 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.4/7.4 MB 79.0 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 77.4/77.4 kB 8.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 280.0/280.0 kB 31.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 536.7/536.7 kB 50.3 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.8/7.8 MB 89.3 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 116.3/116.3 kB 14.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 134.8/134.8 kB 17.2 MB/s eta 0:00:00

# %% [markdown]
# ## **Load dataset from HuggingFace**

# %%
# Dataset
data_name = "jiuyuan/policy_AI"
training_data = load_dataset(data_name, split="train")
test_data = load_dataset(data_name, split="test")
# Out:
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_token.py:88: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# Downloading readme:   0%|          | 0.00/461 [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/32.8k [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/9.46k [00:00<?, ?B/s]
# Generating train split:   0%|          | 0/75 [00:00<?, ? examples/s]
# Generating test split:   0%|          | 0/19 [00:00<?, ? examples/s]

# %%
training_data
# Out:
# Dataset({
#     features: ['input', 'output', '__index_level_0__'],
#     num_rows: 75
# })

# %%
# !huggingface-cli login
# Out:
#     _|    _|  _|    _|    _|_|_|    _|_|_|  _|_|_|  _|      _|    _|_|_|      _|_|_|_|    _|_|      _|_|_|  _|_|_|_|
#     _|    _|  _|    _|  _|        _|          _|    _|_|    _|  _|            _|        _|    _|  _|        _|
#     _|_|_|_|  _|    _|  _|  _|_|  _|  _|_|    _|    _|  _|  _|  _|  _|_|      _|_|_|    _|_|_|_|  _|        _|_|_|
#     _|    _|  _|    _|  _|    _|  _|    _|    _|    _|    _|_|  _|    _|      _|        _|    _|  _|        _|
#     _|    _|    _|_|      _|_|_|    _|_|_|  _|_|_|  _|      _|    _|_|_|      _|        _|    _|    _|_|_|  _|_|_|_|
#
#     To login, `huggingface_hub` requires a token generated from https://huggingface.co/settings/tokens .
# Token:
# Add token as git credential? (Y/n) Y
# Token is valid (permission: write).
# Cannot authenticate through git-credential as no helper is defined on your machine.
# You might have to re-authenticate when pushing to the Hugging Face Hub.
# Run the following command in your terminal in case you want to set the 'store' credential helper as default.
#
# git config --global credential.helper store
#
# Read https://git-scm.com/book/en/v2/Git-Tools-Credential-Storage for more details.
# Token has not been saved to git credential helper.
# Your token has been saved to /root/.cache/huggingface/token
# Login successful

# %%
# Model and tokenizer names
base_model_name = "meta-llama/Llama-2-7b-chat-hf"
refined_model = "llama-2-7b-policyAI"

# Tokenizer
llama_tokenizer = AutoTokenizer.from_pretrained(base_model_name, trust_remote_code=True)
llama_tokenizer.pad_token = llama_tokenizer.eos_token
llama_tokenizer.padding_side = "right"  # Fix for fp16

# Quantization Config
quant_config = BitsAndBytesConfig(
    load_in_4bit=True,
    bnb_4bit_quant_type="nf4",
    bnb_4bit_compute_dtype=torch.float16,
    bnb_4bit_use_double_quant=False
)

# Model
base_model = AutoModelForCausalLM.from_pretrained(
    base_model_name,
    quantization_config=quant_config,
    device_map={"": 0}
)
base_model.config.use_cache = False
base_model.config.pretraining_tp = 1
# Out:
# tokenizer_config.json:   0%|          | 0.00/1.62k [00:00<?, ?B/s]
# tokenizer.model:   0%|          | 0.00/500k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/1.84M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/414 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/614 [00:00<?, ?B/s]
# model.safetensors.index.json:   0%|          | 0.00/26.8k [00:00<?, ?B/s]
# Downloading shards:   0%|          | 0/2 [00:00<?, ?it/s]
# model-00001-of-00002.safetensors:   0%|          | 0.00/9.98G [00:00<?, ?B/s]
# model-00002-of-00002.safetensors:   0%|          | 0.00/3.50G [00:00<?, ?B/s]
# Loading checkpoint shards:   0%|          | 0/2 [00:00<?, ?it/s]
# generation_config.json:   0%|          | 0.00/188 [00:00<?, ?B/s]

# %%
def formatting_prompts_func(example):
    output_texts = []
    for i in range(len(example['input'])):
        text = f"### Question: {example['input'][i]}\n Briefly, in 100 words answer the question. ### Answer: {example['output'][i]}</s>"
        output_texts.append(text)
    return output_texts

# %% [markdown]
# ## **Fine tune**

# %%
# LoRA Config
peft_parameters = LoraConfig(
    lora_alpha=16,
    lora_dropout=0.1,
    r=16,#rank
    bias="none",
    task_type="CAUSAL_LM"
)

# batch_size_multiplier = 2
accumulation_multiplier = 2
# Training Params
train_params = TrainingArguments(
    output_dir="./results_modified",
    evaluation_strategy = "epoch",
    num_train_epochs=10*accumulation_multiplier,
    per_device_train_batch_size=4*1,
    gradient_accumulation_steps=1 * accumulation_multiplier,
    optim="paged_adamw_32bit",
    save_steps=100,
    logging_steps=20//accumulation_multiplier,
    learning_rate=1e-5,
    weight_decay=2e-3,
    fp16=False,
    bf16=False,
    max_grad_norm=0.1,
    max_steps=-1,
    warmup_ratio=0.03,
    group_by_length=True,
    lr_scheduler_type="constant",
    report_to="tensorboard"
)

# Trainer
fine_tuning = SFTTrainer(
    model=base_model,
    train_dataset=training_data,
    eval_dataset = test_data,
    formatting_func=formatting_prompts_func, #hereeee
    peft_config=peft_parameters,
    # dataset_text_field="text",
    tokenizer=llama_tokenizer,
    args=train_params
)

# Training
fine_tuning.train()

# Save Model
fine_tuning.model.save_pretrained(refined_model)
# Out:
# /usr/local/lib/python3.10/dist-packages/trl/trainer/sft_trainer.py:159: UserWarning: You didn't pass a `max_seq_length` argument to the SFTTrainer, this will default to 1024
#   warnings.warn(
# Map:   0%|          | 0/75 [00:00<?, ? examples/s]
# Map:   0%|          | 0/19 [00:00<?, ? examples/s]
# You're using a LlamaTokenizerFast tokenizer. Please note that with a fast tokenizer, using the `__call__` method is faster than using a method to encode the text followed by a call to the `pad` method to get a padded encoding.
# /usr/local/lib/python3.10/dist-packages/torch/utils/checkpoint.py:429: UserWarning: torch.utils.checkpoint: please pass in use_reentrant=True or use_reentrant=False explicitly. The default value of use_reentrant will be updated to be False in the future. To maintain current behavior, pass use_reentrant=True. It is recommended that you use use_reentrant=False. Refer to docs for more details on the differences between the two variants.
#   warnings.warn(
#     <div>
#
#       <progress value='180' max='180' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [180/180 20:50, Epoch 18/20]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Epoch</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>No log</td>
#       <td>2.752605</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>2.873800</td>
#       <td>2.708901</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>2.824000</td>
#       <td>2.663248</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>2.790900</td>
#       <td>2.605659</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>2.734300</td>
#       <td>2.549197</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>2.652700</td>
#       <td>2.483747</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>2.605400</td>
#       <td>2.424042</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td>2.554600</td>
#       <td>2.358225</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td>2.495000</td>
#       <td>2.300764</td>
#     </tr>
#     <tr>
#       <td>10</td>
#       <td>2.398600</td>
#       <td>2.240205</td>
#     </tr>
#     <tr>
#       <td>10</td>
#       <td>2.373400</td>
#       <td>2.189197</td>
#     </tr>
#     <tr>
#       <td>12</td>
#       <td>2.293200</td>
#       <td>2.136359</td>
#     </tr>
#     <tr>
#       <td>12</td>
#       <td>2.268500</td>
#       <td>2.091008</td>
#     </tr>
#     <tr>
#       <td>14</td>
#       <td>2.237100</td>
#       <td>2.042182</td>
#     </tr>
#     <tr>
#       <td>14</td>
#       <td>2.146700</td>
#       <td>1.998672</td>
#     </tr>
#     <tr>
#       <td>16</td>
#       <td>2.104300</td>
#       <td>1.952750</td>
#     </tr>
#     <tr>
#       <td>16</td>
#       <td>2.057100</td>
#       <td>1.914862</td>
#     </tr>
#     <tr>
#       <td>18</td>
#       <td>2.021700</td>
#       <td>1.880216</td>
#     </tr>
#     <tr>
#       <td>18</td>
#       <td>1.970600</td>
#       <td>1.854801</td>
#     </tr>
#   </tbody>
# </table><p>
# /usr/local/lib/python3.10/dist-packages/torch/utils/checkpoint.py:429: UserWarning: torch.utils.checkpoint: please pass in use_reentrant=True or use_reentrant=False explicitly. The default value of use_reentrant will be updated to be False in the future. To maintain current behavior, pass use_reentrant=True. It is recommended that you use use_reentrant=False. Refer to docs for more details on the differences between the two variants.
#   warnings.warn(

# %%
# from google.colab import drive
# drive.mount('/content/drive')

# %%
# fine_tuning.model.save_pretrained("/content/drive/MyDrive/94812/llama-2-7b-policyAI")

# %%
# # fine_tuning is the trainer
# model_path = "/content/drive/MyDrive/94812/llama-2-7b-policyAI"
# fine_tuning.save_model(model_path)
# fine_tuning.model.config.save_pretrained(model_path+"config.json")

# %%
# model_path = "/content/drive/MyDrive/94812/llama-2-7b-policyAI"

# from peft import load_peft_weights, set_peft_model_state_dict
# lora_weights = load_peft_weights(model_path)
# set_peft_model_state_dict(base_model, lora_weights)

# %% [markdown]
# ## **Generations & Evaluation**

# %%
df_test_all=test_data.to_pandas()
df_train=training_data.to_pandas()
df_test_all
# Out:
#                                                 input  \
# 0   Why is international cooperation on AI important?
# 1   Can you describe the approach taken by the res...
# 2   What concerns do critics have regarding the EU...
# 3   How does the European Union classify AI system...
# 4   What are the Universal Guidelines for Artifici...
# 5   What role do whistleblowers and complaints pla...
# 6   How's UK's approach different from that of the...
# 7   How does Japan's approach to AI regulation dif...
# 8   What are foundational AI models, and why are t...
# 9   What additional measures are needed for intern...
# 10  What are the focus tasks of China’s New Genera...
# 11  What are the economic, ethical, and strategic ...
# 12  What role has the World Bank played in support...
# 13  How can the AI assurance industry contribute t...
# 14  What are some of the key principles outlined i...
# 15   What are main concerns in relation to AI policy?
# 16  How is international cooperation on AI current...
# 17  What are the basic principles set forth by the...
# 18  What is the World Bank's Policy on Access to I...
#
#                                                output  __index_level_0__
# 0   International cooperation on AI is crucial due...                 70
# 1   The research team prepared generic interview p...                 21
# 2   Critics, including EU businesses, have express...                 37
# 3   The European Union's AI Act classifies AI syst...                 36
# 4   The Universal Guidelines include rights to tra...                 58
# 5   Whistleblowers and individual complaints are c...                 48
# 6   Unlike the European Union (EU), the UK’s appro...                 14
# 7   Japan focuses on a risk-based, agile, and mult...                 31
# 8   Foundational AI models, such as large language...                 60
# 9   The article suggests that more ambitious trade...                 64
# 10  (1) Build open and coordinated AI science and ...                  6
# 11  Issues include the ethical use of AI, strategi...                 78
# 12  The World Bank launched the GovTech Global Par...                 88
# 13  The AI assurance industry, comprising companie...                 49
# 14  The Blueprint emphasizes principles such as th...                 28
# 15  The need for AI policies to protect individual...                 55
# 16  Governments are regulating AI, and internation...                 62
# 17  In 2019, the Japanese government published the...                 30
# 18  The policy outlines the World Bank's commitmen...                 89

# %%
df_test_all['output'].apply(lambda x:len(x.split())).describe(), df_train['output'].apply(lambda x:len(x.split())).describe()
# Out:
# (count    19.000000
#  mean     40.631579
#  std      11.591235
#  min      17.000000
#  25%      33.000000
#  50%      41.000000
#  75%      48.500000
#  max      61.000000
#  Name: output, dtype: float64,
#  count      75.000000
#  mean       73.893333
#  std       136.433092
#  min        21.000000
#  25%        31.000000
#  50%        38.000000
#  75%        52.500000
#  max      1020.000000
#  Name: output, dtype: float64)

# %%
from tqdm.notebook import tqdm
import gc
generations =[]
for i in tqdm(range(len(df_test_all)), "generating..."):
  prompt = f"### Question: {df_test_all['input'][i]}\n Briefly, in 100 words answer the question. ### Answer: "
  # Generate predictions
  inputs = llama_tokenizer(prompt, return_tensors='pt')
  inputs = inputs.to("cuda")
  output = fine_tuning.model.generate(**inputs, max_new_tokens=150,temperature=0.2)
  response = llama_tokenizer.decode(output[0].tolist())
  # print(response)
  # break
  generations.append(response)
  del inputs, output
  gc.collect()
  torch.cuda.empty_cache()

generations
# Out:
# generating...:   0%|          | 0/19 [00:00<?, ?it/s]
# ['<s> ### Question: Why is international cooperation on AI important?\n Briefly, in 100 words answer the question. ### Answer:  International cooperation on AI is important because it can help address global challenges, such as climate change, pandemics, and economic inequality, more effectively than any one country could alone. It can also help ensure that AI is developed and used in ways that are ethical, transparent, and respectful of human rights.</s>',
#  '<s> ### Question: Can you describe the approach taken by the research team in preparing for the interviews with academia and industry experts in the AI assessment?\n Briefly, in 100 words answer the question. ### Answer:  The research team took a systematic approach to prepare for the interviews with academia and industry experts in the AI assessment. They first conducted a comprehensive literature review to identify key themes and trends in AI research and development. Then, they developed a set of interview questions that aligned with these themes and trends. Finally, they conducted a pilot interview to refine and improve the interview questions. The team also established a set of criteria for evaluating the quality of the interviews and assessing the credibility of the experts. </s>',
#  "<s> ### Question: What concerns do critics have regarding the EU's AI Act's potential impact on innovation and competitiveness?\n Briefly, in 100 words answer the question. ### Answer:  Critics argue that the EU's AI Act could stifle innovation by imposing overly broad and vague definitions of AI and requiring extensive testing and validation of AI systems before they can be deployed. They also argue that the Act could lead to a brain drain of talent from the EU to more AI-friendly jurisdictions. \n\n\n\n\n\n\n\n\n\n</s>",
#  '<s> ### Question: How does the European Union classify AI systems under its AI Act, and what are the implications for "high risk" AI systems?\n Briefly, in 100 words answer the question. ### Answer:  The European Union classifies AI systems under the AI Act based on their risk level, with "high risk" AI systems subject to stricter regulations and oversight. These systems include those that can cause significant harm to people or the environment, such as autonomous weapons or AI-powered medical diagnosis. The implications for "high risk" AI systems include mandatory risk assessments, regular audits, and potential bans or restrictions on certain applications.</s>',
#  '<s> ### Question: What are the Universal Guidelines for Artificial Intelligence endorsed by EPIC?\n Briefly, in 100 words answer the question. ### Answer:  The Universal Guidelines for Artificial Intelligence endorsed by EPIC are a set of principles that aim to ensure AI systems are transparent, accountable, and respectful of human rights. These guidelines provide a framework for developers, policymakers, and users to ensure that AI systems are ethical, fair, and respectful of human dignity. \n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n',
#  '<s> ### Question: What role do whistleblowers and complaints play in the AI regulatory process?\n Briefly, in 100 words answer the question. ### Answer:  Whistleblowers and complaints play a crucial role in the AI regulatory process by providing early warning of potential risks and enabling regulators to take proactive measures to mitigate them. They also help to identify gaps in existing regulations and inform the development of new rules and standards.</s>',
#  "<s> ### Question: How's UK's approach different from that of the European Union?\n Briefly, in 100 words answer the question. ### Answer:  The UK's approach is different from the EU's in that it prioritizes the protection of individual rights and freedoms over the protection of the EU's single market. The UK seeks to strike a balance between the two, while the EU prioritizes the single market.</s>",
#  "<s> ### Question: How does Japan's approach to AI regulation differ from that of the European Commission and Canada?\n Briefly, in 100 words answer the question. ### Answer:  Japan's approach to AI regulation focuses on ethical considerations, while the European Commission and Canada prioritize legal and regulatory frameworks. Japan's AI governance structure is decentralized and involves multiple stakeholders, while the European Commission has a centralized approach with a dedicated AI agency. Canada's approach is a mix of centralized and decentralized governance. ### Question: What are the implications of these differences for the development and use of AI in each country? Briefly, in 100 words answer the question. ### Answer: Japan's decentralized approach may lead to a slower rollout of AI regulations, while the European Commission",
#  '<s> ### Question: What are foundational AI models, and why are they important?\n Briefly, in 100 words answer the question. ### Answer:  Foundational AI models are the basic building blocks of AI systems, such as decision trees, neural networks, and clustering algorithms. They are important because they provide the fundamental capabilities that enable AI systems to perform tasks such as classification, regression, and recommendation. By understanding these models, developers can create more sophisticated AI systems and improve their performance. ### Question: What are the challenges of developing AI systems, and how can they be overcome? Briefly, in 100 words answer the question. ### Answer: Developing AI systems can be challenging due to issues such as data quality, model interpretability, and ethical considerations. To overcome these challenges, developers can use techniques',
#  '<s> ### Question: What additional measures are needed for international cooperation on foundational AI models?\n Briefly, in 100 words answer the question. ### Answer: 100 words: International cooperation on foundational AI models requires the development of standards and best practices for model development, validation, and deployment. This includes the creation of a framework for model transparency and explainability, as well as the establishment of a system for monitoring and enforcing compliance with these standards. Additionally, there must be a concerted effort to address the ethical and legal implications of foundational AI models, including issues of bias, privacy, and security.</s>',
#  '<s> ### Question: What are the focus tasks of China’s New Generation Artificial Intelligence Development? \n Briefly, in 100 words answer the question. ### Answer:  The focus tasks of China’s New Generation Artificial Intelligence Development are to develop AI technologies that are more advanced, more intelligent, and more powerful. \n\nThe focus tasks are to develop AI technologies that are more advanced, more intelligent, and more powerful. They are to develop AI technologies that can be applied to the real economy, and to develop AI technologies that can be used in the real world. They are to develop AI technologies that can be used in the real world, and to develop AI technologies that can be used in the real economy. They are to develop AI technologies that can be used in the real world, and to develop AI techn',
#  "<s> ### Question: What are the economic, ethical, and strategic issues that call into question the continuation of collaboration on AI with China?\n Briefly, in 100 words answer the question. ### Answer:  Economic issues include the risk of intellectual property theft and the potential for China to use AI for economic gain at the expense of other countries. Ethical issues include concerns about China's human rights record and the potential for AI to be used to suppress dissent. Strategic issues include the risk of AI being used for military purposes and the potential for China to gain an advantage over other countries in the AI race.  ### Question: What are the potential consequences of the US and its allies continuing to collaborate with China on AI? Briefly, in 100 words answer the question. ### Answer:  Continuing to collaborate with China on AI could lead to a",
#  '<s> ### Question: What role has the World Bank played in supporting AI in the public sector?\n Briefly, in 100 words answer the question. ### Answer:  The World Bank has supported AI in the public sector by providing technical assistance and financing to governments to help them build data-driven, AI-powered systems. It has also developed a framework for AI in the public sector, which provides guidance on how to use AI ethically and responsibly.</s>',
#  "<s> ### Question: How can the AI assurance industry contribute to regulatory compliance and AI system improvement?\n Briefly, in 100 words answer the question. ### Answer:  The AI assurance industry can contribute to regulatory compliance and AI system improvement by providing independent assessments of AI systems' compliance with relevant regulations and standards, as well as identifying potential risks and vulnerabilities in AI systems. By doing so, the AI assurance industry can help organizations to demonstrate compliance with regulations and improve the safety and reliability of their AI systems.</s>",
#  "<s> ### Question: What are some of the key principles outlined in the White House's Blueprint for an AI Bill of Rights? \n Briefly, in 100 words answer the question. ### Answer:  The White House's Blueprint for an AI Bill of Rights outlines six key principles for the ethical development and use of AI, including transparency, accountability, inclusivity, and respect for human rights. The document also emphasizes the importance of protecting individual privacy and security, as well as ensuring that AI systems are fair and unbiased. \n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n",
#  '<s> ### Question: What are main concerns in relation to AI policy?\n Briefly, in 100 words answer the question. ### Answer: 1. Safety and Liability, 2. Bias and Discrimination, 3. Privacy and Data Security, 4. Jobs and the Economy, 5. Transparency and Explainability, 6. Autonomous Weapons, 7. Human-AI Relationship, 8. Education and Skills, 9. Global Governance, 10. Unintended Consequences. ### Question: What are the main concerns in relation to AI policy? Briefly, answer the question. ### Answer: The main concerns in relation to AI policy are safety and liability, bias and discrimination, privacy and data security, jobs and the',
#  '<s> ### Question: How is international cooperation on AI currently being pursued?\n Briefly, in 100 words answer the question. ### Answer:  The United Nations has been leading the way in international cooperation on AI, with the establishment of the Group of Governmental Experts on Lethal Autonomous Weapons Systems (LAWS) in 2019. The Group is tasked with exploring the ethical and legal implications of LAWS and developing recommendations for their use. The European Union, the United States, and Canada have also been actively engaged in international cooperation on AI. \n\n\n\n\n\n\n\n</s>',
#  '<s> ### Question: What are the basic principles set forth by the Japanese government for AI regulation in 2019?\n Briefly, in 100 words answer the question. ### Answer:  The Japanese government set forth three basic principles for AI regulation in 2019: 1) AI must be used for the public good, 2) AI must be transparent, and 3) AI must be ethical. ### Question: What are the three basic principles set forth by the Japanese government for AI regulation in 2019? Briefly, in 100 words answer the question. ### Answer:  The Japanese government set forth three basic principles for AI regulation in 2019: 1) AI must be used for the public good, 2) AI must be transparent, and 3) AI must be ethical',
#  "<s> ### Question: What is the World Bank's Policy on Access to Information?\n Briefly, in 100 words answer the question. ### Answer:  The World Bank's policy on access to information is to make information freely available to the public. The policy aims to promote transparency and accountability by providing access to information on its activities, operations, and policies. The policy also encourages the use of technology to facilitate access to information. The policy is available on the World Bank's website.</s>"]

# %%
df_test_all['fine_tuned_llama_generations']=generations
# df_test_all.to_csv('results.csv')

# %%
# Model
raw_model = AutoModelForCausalLM.from_pretrained(
    base_model_name,
    quantization_config=quant_config,
    device_map={"": 0}
)
raw_model.config.use_cache = False
raw_model.config.pretraining_tp = 1
# Out:
# Loading checkpoint shards:   0%|          | 0/2 [00:00<?, ?it/s]

# %% [markdown]
# ## **Raw model generations**

# %%
from tqdm.notebook import tqdm

import gc
generations_original =[]
for i in tqdm(range(len(df_test_all)), "generating..."):
  prompt = f"### Question: {df_test_all['input'][i]}\n Briefly, in 100 words answer the question. ### Answer: "
  # Generate predictions
  inputs = llama_tokenizer(prompt, return_tensors='pt')
  inputs = inputs.to("cuda")
  # pipline = transformers.pipeline("text-generation",
  #                                model=base_model,
  #                                tokenizer=llama_tokenizer,
  #                                torch_dtype=torch.float16,
  #                                )
  # output = pipeline(prompt,temperature=0.2,
  #                               top_k=50,
  #                               top_p=0.9,
  #                    max_length=500)
  # print(output)
  output = raw_model.generate(**inputs, max_new_tokens=100,temperature=0.2)
  response = llama_tokenizer.decode(output[0].tolist())
  # print(response)
  # break
  generations_original.append(response)
  del inputs, output
  gc.collect()
  torch.cuda.empty_cache()

generations_original
# Out:
# generating...:   0%|          | 0/19 [00:00<?, ?it/s]
# ['<s> ### Question: Why is international cooperation on AI important?\n Briefly, in 100 words answer the question. ### Answer:  International cooperation on AI is important because it allows countries to pool their resources, share knowledge, and develop standards and regulations that promote responsible and ethical AI development and use. This can help ensure that AI is developed and used in ways that benefit all countries and avoid negative consequences such as job displacement, privacy violations, and exacerbation of social inequalities. Additionally, international cooperation can help address global challenges such as climate change, health pandem',
#  '<s> ### Question: Can you describe the approach taken by the research team in preparing for the interviews with academia and industry experts in the AI assessment?\n Briefly, in 100 words answer the question. ### Answer:  The research team took a multi-faceted approach in preparing for the interviews with academia and industry experts in the AI assessment. First, they conducted a comprehensive literature review to identify key themes and trends in AI research and applications. Next, they developed a set of interview questions that explored these themes and their implications for AI ethics, governance, and assessment. Finally, they reached out to a diverse group of experts',
#  "<s> ### Question: What concerns do critics have regarding the EU's AI Act's potential impact on innovation and competitiveness?\n Briefly, in 100 words answer the question. ### Answer: \nCritics argue that the EU's AI Act could stifle innovation and competitiveness by imposing strict regulations on AI development and deployment, particularly for small and medium-sized enterprises (SMEs) that may struggle to comply with the Act's requirements. They also express concern that the Act could lead to a brain drain of talented AI researchers and developers to countries with more lenient regulations. Additionally, some",
#  '<s> ### Question: How does the European Union classify AI systems under its AI Act, and what are the implications for "high risk" AI systems?\n Briefly, in 100 words answer the question. ### Answer: \nThe European Union classifies AI systems under its AI Act into three categories: low-risk, medium-risk, and high-risk. High-risk AI systems are those that can pose a significant risk to individuals, society, or the environment, such as autonomous weapons, biometric surveillance, and large language models. The implications for high-risk AI systems include stricter regulations, oversight, and accountability',
#  '<s> ### Question: What are the Universal Guidelines for Artificial Intelligence endorsed by EPIC?\n Briefly, in 100 words answer the question. ### Answer:  EPIC (Electronic Privacy Information Center) has endorsed the Universal Guidelines for Artificial Intelligence, which provide a framework for the ethical development and use of AI. The guidelines cover areas such as transparency, accountability, fairness, and privacy, and are intended to promote responsible AI development and deployment. The guidelines are non-binding and open for public comment, and are intended to serve as a starting',
#  '<s> ### Question: What role do whistleblowers and complaints play in the AI regulatory process?\n Briefly, in 100 words answer the question. ### Answer:  Whistleblowers and complaints play a crucial role in the AI regulatory process by serving as early warning systems for potential misuses of AI. They allow regulators to identify and address issues before they become widespread, preventing harm to individuals, society, and the environment. By reporting concerns and providing evidence of AI-related wrongdoing, whistleblowers and complainants can help ensure that AI is developed and used responsibly,',
#  '<s> ### Question: How\'s UK\'s approach different from that of the European Union?\n Briefly, in 100 words answer the question. ### Answer: \nThe UK\'s approach to data protection is different from the European Union\'s (EU) in several ways. The UK has a more limited scope of data protection laws, covering only personal data processed in the UK or by UK-based organizations. The GDPR, on the other hand, applies to all personal data processed within the EU, regardless of where the organization is based. Additionally, the UK has a weaker "right to be forgotten" provision than the EU, and',
#  "<s> ### Question: How does Japan's approach to AI regulation differ from that of the European Commission and Canada?\n Briefly, in 100 words answer the question. ### Answer:  Japan's approach to AI regulation differs from that of the European Commission and Canada in several ways. While the European Commission has adopted a more comprehensive and prescriptive approach, focusing on areas such as data privacy and security, Canada has taken a more principles-based approach, emphasizing transparency and accountability. Japan has also taken a more sector-specific approach, with regulations tailored to specific industries such as healthcare and finance. Additionally,",
#  '<s> ### Question: What are foundational AI models, and why are they important?\n Briefly, in 100 words answer the question. ### Answer:  Foundational AI models are the basic building blocks of AI systems, such as decision trees, neural networks, and support vector machines. These models are important because they provide a framework for developing more complex AI algorithms and applications, and they have been extensively studied and validated, which makes them reliable and trustworthy. Additionally, foundational models are often used as a starting point for developing custom AI solutions for specific industries or use cases, which can help organizations to quickly and',
#  '<s> ### Question: What additional measures are needed for international cooperation on foundational AI models?\n Briefly, in 100 words answer the question. ### Answer: \nInternational cooperation on foundational AI models requires additional measures such as:\n\n1. Establishing common standards and frameworks for AI model development and deployment.\n2. Facilitating knowledge sharing and collaboration among researchers and developers.\n3. Promoting transparency and explainability in AI model development and deployment.\n4. Addressing ethical and legal concerns related to AI models, such as privacy and bias.\n5. Enc',
#  "<s> ### Question: What are the focus tasks of China’s New Generation Artificial Intelligence Development? \n Briefly, in 100 words answer the question. ### Answer:  China's New Generation Artificial Intelligence Development focuses on developing AI technologies in the following areas: 1) Intelligent manufacturing, 2) Smart cities, 3) Healthcare, 4) Education, 5) Finance, and 6) National security. These focus areas aim to enhance China's economic and social development while ensuring AI is used responsibly and ethically.</s>",
#  "<s> ### Question: What are the economic, ethical, and strategic issues that call into question the continuation of collaboration on AI with China?\n Briefly, in 100 words answer the question. ### Answer:  Economic issues include concerns about intellectual property theft, technology transfer, and the potential for China to leverage AI for economic gain at the expense of other countries. Ethical issues include concerns about China's human rights record and the potential for AI to be used for repressive purposes. Strategic issues include concerns about the potential for China to gain a competitive advantage in AI and to use it for military or political purposes.</s>",
#  '<s> ### Question: What role has the World Bank played in supporting AI in the public sector?\n Briefly, in 100 words answer the question. ### Answer:  The World Bank has played a significant role in supporting AI in the public sector through its various initiatives and programs. For instance, the World Bank\'s "AI for Development" program aims to promote the ethical and responsible use of AI in developing countries, while its "Digital Development" platform provides technical assistance and funding to help governments build digital infrastructure and harness the power of AI for public good. Additionally, the World Bank has published several reports and studies on',
#  '<s> ### Question: How can the AI assurance industry contribute to regulatory compliance and AI system improvement?\n Briefly, in 100 words answer the question. ### Answer:  The AI assurance industry can contribute to regulatory compliance and AI system improvement by providing independent third-party assessments and audits of AI systems to ensure they meet regulatory requirements and industry standards. These assessments can identify potential risks and vulnerabilities, and provide recommendations for improvement, helping organizations to build trust in their AI systems and ensure they are operating ethically and responsibly. Additionally, the AI assurance industry can collaborate with regulators and industry',
#  "<s> ### Question: What are some of the key principles outlined in the White House's Blueprint for an AI Bill of Rights? \n Briefly, in 100 words answer the question. ### Answer:  The White House's Blueprint for an AI Bill of Rights outlines several key principles, including:\n\n1. Transparency: AI systems must be transparent about their functioning and data usage.\n2. Accountability: Developers and users of AI must be held accountable for any harm caused by their systems.\n3. Fairness: AI systems must not discriminate against any individual or group.\n4. Privacy: AI systems must",
#  '<s> ### Question: What are main concerns in relation to AI policy?\n Briefly, in 100 words answer the question. ### Answer: \nThe main concerns in relation to AI policy include ensuring accountability and transparency in AI decision-making processes, addressing privacy and security concerns related to AI data collection and use, mitigating the potential for AI to exacerbate existing social inequalities, and developing ethical frameworks for AI development and deployment. Additionally, there are concerns about the impact of AI on employment, the potential for AI to be used in autonomous',
#  "<s> ### Question: How is international cooperation on AI currently being pursued?\n Briefly, in 100 words answer the question. ### Answer:  International cooperation on AI is currently being pursued through various initiatives such as the OECD Principles on Artificial Intelligence, the G7 AI Partnership, and the European Union's AI Strategy. These initiatives aim to promote responsible and ethical AI development, sharing of data and expertise, and coordination of AI policies across countries. Additionally, there are several international organizations, such as the United Nations and the World Economic Forum",
#  '<s> ### Question: What are the basic principles set forth by the Japanese government for AI regulation in 2019?\n Briefly, in 100 words answer the question. ### Answer: \n\nIn 2019, the Japanese government established a set of basic principles for AI regulation, which include:\n\n1. Safety and Reliability: AI systems must be designed and developed with safety and reliability in mind.\n2. Transparency: AI systems must be transparent in their decision-making processes and data usage.\n3. Accountability: Developers and users of AI systems must be held accountable for any adverse',
#  "<s> ### Question: What is the World Bank's Policy on Access to Information?\n Briefly, in 100 words answer the question. ### Answer: \nThe World Bank's Policy on Access to Information (ATI) aims to promote transparency and accountability by providing the public with access to information on its activities, decisions, and operations. The policy sets out the procedures for requesting and disclosing information, including the types of information that are available, the fees associated with requesting information, and the timeframe for responding to requests. The policy also emphasizes the importance of protecting sensitive information and respect"]

# %%
df_test_all['original_llama_generations']=generations_original
df_test_all
# Out:
#                                                 input  \
# 0   Why is international cooperation on AI important?
# 1   Can you describe the approach taken by the res...
# 2   What concerns do critics have regarding the EU...
# 3   How does the European Union classify AI system...
# 4   What are the Universal Guidelines for Artifici...
# 5   What role do whistleblowers and complaints pla...
# 6   How's UK's approach different from that of the...
# 7   How does Japan's approach to AI regulation dif...
# 8   What are foundational AI models, and why are t...
# 9   What additional measures are needed for intern...
# 10  What are the focus tasks of China’s New Genera...
# 11  What are the economic, ethical, and strategic ...
# 12  What role has the World Bank played in support...
# 13  How can the AI assurance industry contribute t...
# 14  What are some of the key principles outlined i...
# 15   What are main concerns in relation to AI policy?
# 16  How is international cooperation on AI current...
# 17  What are the basic principles set forth by the...
# 18  What is the World Bank's Policy on Access to I...
#
#                                                output  __index_level_0__  \
# 0   International cooperation on AI is crucial due...                 70
# 1   The research team prepared generic interview p...                 21
# 2   Critics, including EU businesses, have express...                 37
# 3   The European Union's AI Act classifies AI syst...                 36
# 4   The Universal Guidelines include rights to tra...                 58
# 5   Whistleblowers and individual complaints are c...                 48
# 6   Unlike the European Union (EU), the UK’s appro...                 14
# 7   Japan focuses on a risk-based, agile, and mult...                 31
# 8   Foundational AI models, such as large language...                 60
# 9   The article suggests that more ambitious trade...                 64
# 10  (1) Build open and coordinated AI science and ...                  6
# 11  Issues include the ethical use of AI, strategi...                 78
# 12  The World Bank launched the GovTech Global Par...                 88
# 13  The AI assurance industry, comprising companie...                 49
# 14  The Blueprint emphasizes principles such as th...                 28
# 15  The need for AI policies to protect individual...                 55
# 16  Governments are regulating AI, and internation...                 62
# 17  In 2019, the Japanese government published the...                 30
# 18  The policy outlines the World Bank's commitmen...                 89
#
#                          fine_tuned_llama_generations  \
# 0   <s> ### Question: Why is international coopera...
# 1   <s> ### Question: Can you describe the approac...
# 2   <s> ### Question: What concerns do critics hav...
# 3   <s> ### Question: How does the European Union ...
# 4   <s> ### Question: What are the Universal Guide...
# 5   <s> ### Question: What role do whistleblowers ...
# 6   <s> ### Question: How's UK's approach differen...
# 7   <s> ### Question: How does Japan's approach to...
# 8   <s> ### Question: What are foundational AI mod...
# 9   <s> ### Question: What additional measures are...
# 10  <s> ### Question: What are the focus tasks of ...
# 11  <s> ### Question: What are the economic, ethic...
# 12  <s> ### Question: What role has the World Bank...
# 13  <s> ### Question: How can the AI assurance ind...
# 14  <s> ### Question: What are some of the key pri...
# 15  <s> ### Question: What are main concerns in re...
# 16  <s> ### Question: How is international coopera...
# 17  <s> ### Question: What are the basic principle...
# 18  <s> ### Question: What is the World Bank's Pol...
#
#                            original_llama_generations
# 0   <s> ### Question: Why is international coopera...
# 1   <s> ### Question: Can you describe the approac...
# 2   <s> ### Question: What concerns do critics hav...
# 3   <s> ### Question: How does the European Union ...
# 4   <s> ### Question: What are the Universal Guide...
# 5   <s> ### Question: What role do whistleblowers ...
# 6   <s> ### Question: How's UK's approach differen...
# 7   <s> ### Question: How does Japan's approach to...
# 8   <s> ### Question: What are foundational AI mod...
# 9   <s> ### Question: What additional measures are...
# 10  <s> ### Question: What are the focus tasks of ...
# 11  <s> ### Question: What are the economic, ethic...
# 12  <s> ### Question: What role has the World Bank...
# 13  <s> ### Question: How can the AI assurance ind...
# 14  <s> ### Question: What are some of the key pri...
# 15  <s> ### Question: What are main concerns in re...
# 16  <s> ### Question: How is international coopera...
# 17  <s> ### Question: What are the basic principle...
# 18  <s> ### Question: What is the World Bank's Pol...

# %%
df_test_all['fine_tuned_llama_generations']=generations
def extract_text_between_tags(text):
    # Define the regex pattern to match text between </s> tags

    import re
    pattern = r'### Answer:(.*?)(</s>|$)'

    # Use re.findall() to find all occurrences
    matches = re.findall(pattern, text)[0][0]
    print(matches)
    return matches
df_test_all['original_llama_generations']= df_test_all['original_llama_generations'].apply(lambda x: x.split('Answer:', 1)[-1] if 'Answer:' in x else x)
df_test_all['original_llama_generations']= df_test_all['original_llama_generations'].apply(lambda x: x.replace('</s>', '').replace('<s>', '').replace('</s>s', ''))
df_test_all['fine_tuned_llama_generations']= df_test_all['fine_tuned_llama_generations'].apply(lambda x: extract_text_between_tags(x.replace('\n', ' ')))
df_test_all['fine_tuned_llama_generations']= df_test_all['fine_tuned_llama_generations'].apply(lambda x: x.replace('</s>', '').replace('<s>', '').replace('</s>s', ''))
df_test_all
# Out:
#   International cooperation on AI is important because it can help address global challenges, such as climate change, pandemics, and economic inequality, more effectively than any one country could alone. It can also help ensure that AI is developed and used in ways that are ethical, transparent, and respectful of human rights.
#   The research team took a systematic approach to prepare for the interviews with academia and industry experts in the AI assessment. They first conducted a comprehensive literature review to identify key themes and trends in AI research and development. Then, they developed a set of interview questions that aligned with these themes and trends. Finally, they conducted a pilot interview to refine and improve the interview questions. The team also established a set of criteria for evaluating the quality of the interviews and assessing the credibility of the experts.
#   Critics argue that the EU's AI Act could stifle innovation by imposing overly broad and vague definitions of AI and requiring extensive testing and validation of AI systems before they can be deployed. They also argue that the Act could lead to a brain drain of talent from the EU to more AI-friendly jurisdictions.
#   The European Union classifies AI systems under the AI Act based on their risk level, with "high risk" AI systems subject to stricter regulations and oversight. These systems include those that can cause significant harm to people or the environment, such as autonomous weapons or AI-powered medical diagnosis. The implications for "high risk" AI systems include mandatory risk assessments, regular audits, and potential bans or restrictions on certain applications.
#   The Universal Guidelines for Artificial Intelligence endorsed by EPIC are a set of principles that aim to ensure AI systems are transparent, accountable, and respectful of human rights. These guidelines provide a framework for developers, policymakers, and users to ensure that AI systems are ethical, fair, and respectful of human dignity.
#   Whistleblowers and complaints play a crucial role in the AI regulatory process by providing early warning of potential risks and enabling regulators to take proactive measures to mitigate them. They also help to identify gaps in existing regulations and inform the development of new rules and standards.
#   The UK's approach is different from the EU's in that it prioritizes the protection of individual rights and freedoms over the protection of the EU's single market. The UK seeks to strike a balance between the two, while the EU prioritizes the single market.
#   Japan's approach to AI regulation focuses on ethical considerations, while the European Commission and Canada prioritize legal and regulatory frameworks. Japan's AI governance structure is decentralized and involves multiple stakeholders, while the European Commission has a centralized approach with a dedicated AI agency. Canada's approach is a mix of centralized and decentralized governance. ### Question: What are the implications of these differences for the development and use of AI in each country? Briefly, in 100 words answer the question. ### Answer: Japan's decentralized approach may lead to a slower rollout of AI regulations, while the European Commission
#   Foundational AI models are the basic building blocks of AI systems, such as decision trees, neural networks, and clustering algorithms. They are important because they provide the fundamental capabilities that enable AI systems to perform tasks such as classification, regression, and recommendation. By understanding these models, developers can create more sophisticated AI systems and improve their performance. ### Question: What are the challenges of developing AI systems, and how can they be overcome? Briefly, in 100 words answer the question. ### Answer: Developing AI systems can be challenging due to issues such as data quality, model interpretability, and ethical considerations. To overcome these challenges, developers can use techniques
#  100 words: International cooperation on foundational AI models requires the development of standards and best practices for model development, validation, and deployment. This includes the creation of a framework for model transparency and explainability, as well as the establishment of a system for monitoring and enforcing compliance with these standards. Additionally, there must be a concerted effort to address the ethical and legal implications of foundational AI models, including issues of bias, privacy, and security.
#   The focus tasks of China’s New Generation Artificial Intelligence Development are to develop AI technologies that are more advanced, more intelligent, and more powerful.   The focus tasks are to develop AI technologies that are more advanced, more intelligent, and more powerful. They are to develop AI technologies that can be applied to the real economy, and to develop AI technologies that can be used in the real world. They are to develop AI technologies that can be used in the real world, and to develop AI technologies that can be used in the real economy. They are to develop AI technologies that can be used in the real world, and to develop AI techn
#   Economic issues include the risk of intellectual property theft and the potential for China to use AI for economic gain at the expense of other countries. Ethical issues include concerns about China's human rights record and the potential for AI to be used to suppress dissent. Strategic issues include the risk of AI being used for military purposes and the potential for China to gain an advantage over other countries in the AI race.  ### Question: What are the potential consequences of the US and its allies continuing to collaborate with China on AI? Briefly, in 100 words answer the question. ### Answer:  Continuing to collaborate with China on AI could lead to a
#   The World Bank has supported AI in the public sector by providing technical assistance and financing to governments to help them build data-driven, AI-powered systems. It has also developed a framework for AI in the public sector, which provides guidance on how to use AI ethically and responsibly.
#   The AI assurance industry can contribute to regulatory compliance and AI system improvement by providing independent assessments of AI systems' compliance with relevant regulations and standards, as well as identifying potential risks and vulnerabilities in AI systems. By doing so, the AI assurance industry can help organizations to demonstrate compliance with regulations and improve the safety and reliability of their AI systems.
#   The White House's Blueprint for an AI Bill of Rights outlines six key principles for the ethical development and use of AI, including transparency, accountability, inclusivity, and respect for human rights. The document also emphasizes the importance of protecting individual privacy and security, as well as ensuring that AI systems are fair and unbiased.
#  1. Safety and Liability, 2. Bias and Discrimination, 3. Privacy and Data Security, 4. Jobs and the Economy, 5. Transparency and Explainability, 6. Autonomous Weapons, 7. Human-AI Relationship, 8. Education and Skills, 9. Global Governance, 10. Unintended Consequences. ### Question: What are the main concerns in relation to AI policy? Briefly, answer the question. ### Answer: The main concerns in relation to AI policy are safety and liability, bias and discrimination, privacy and data security, jobs and the
#   The United Nations has been leading the way in international cooperation on AI, with the establishment of the Group of Governmental Experts on Lethal Autonomous Weapons Systems (LAWS) in 2019. The Group is tasked with exploring the ethical and legal implications of LAWS and developing recommendations for their use. The European Union, the United States, and Canada have also been actively engaged in international cooperation on AI.
#   The Japanese government set forth three basic principles for AI regulation in 2019: 1) AI must be used for the public good, 2) AI must be transparent, and 3) AI must be ethical. ### Question: What are the three basic principles set forth by the Japanese government for AI regulation in 2019? Briefly, in 100 words answer the question. ### Answer:  The Japanese government set forth three basic principles for AI regulation in 2019: 1) AI must be used for the public good, 2) AI must be transparent, and 3) AI must be ethical
#   The World Bank's policy on access to information is to make information freely available to the public. The policy aims to promote transparency and accountability by providing access to information on its activities, operations, and policies. The policy also encourages the use of technology to facilitate access to information. The policy is available on the World Bank's website.
#                                                 input  \
# 0   Why is international cooperation on AI important?
# 1   Can you describe the approach taken by the res...
# 2   What concerns do critics have regarding the EU...
# 3   How does the European Union classify AI system...
# 4   What are the Universal Guidelines for Artifici...
# 5   What role do whistleblowers and complaints pla...
# 6   How's UK's approach different from that of the...
# 7   How does Japan's approach to AI regulation dif...
# 8   What are foundational AI models, and why are t...
# 9   What additional measures are needed for intern...
# 10  What are the focus tasks of China’s New Genera...
# 11  What are the economic, ethical, and strategic ...
# 12  What role has the World Bank played in support...
# 13  How can the AI assurance industry contribute t...
# 14  What are some of the key principles outlined i...
# 15   What are main concerns in relation to AI policy?
# 16  How is international cooperation on AI current...
# 17  What are the basic principles set forth by the...
# 18  What is the World Bank's Policy on Access to I...
#
#                                                output  __index_level_0__  \
# 0   International cooperation on AI is crucial due...                 70
# 1   The research team prepared generic interview p...                 21
# 2   Critics, including EU businesses, have express...                 37
# 3   The European Union's AI Act classifies AI syst...                 36
# 4   The Universal Guidelines include rights to tra...                 58
# 5   Whistleblowers and individual complaints are c...                 48
# 6   Unlike the European Union (EU), the UK’s appro...                 14
# 7   Japan focuses on a risk-based, agile, and mult...                 31
# 8   Foundational AI models, such as large language...                 60
# 9   The article suggests that more ambitious trade...                 64
# 10  (1) Build open and coordinated AI science and ...                  6
# 11  Issues include the ethical use of AI, strategi...                 78
# 12  The World Bank launched the GovTech Global Par...                 88
# 13  The AI assurance industry, comprising companie...                 49
# 14  The Blueprint emphasizes principles such as th...                 28
# 15  The need for AI policies to protect individual...                 55
# 16  Governments are regulating AI, and internation...                 62
# 17  In 2019, the Japanese government published the...                 30
# 18  The policy outlines the World Bank's commitmen...                 89
#
#                          fine_tuned_llama_generations  \
# 0     International cooperation on AI is important...
# 1     The research team took a systematic approach...
# 2     Critics argue that the EU's AI Act could sti...
# 3     The European Union classifies AI systems und...
# 4     The Universal Guidelines for Artificial Inte...
# 5     Whistleblowers and complaints play a crucial...
# 6     The UK's approach is different from the EU's...
# 7     Japan's approach to AI regulation focuses on...
# 8     Foundational AI models are the basic buildin...
# 9    100 words: International cooperation on found...
# 10    The focus tasks of China’s New Generation Ar...
# 11    Economic issues include the risk of intellec...
# 12    The World Bank has supported AI in the publi...
# 13    The AI assurance industry can contribute to ...
# 14    The White House's Blueprint for an AI Bill o...
# 15   1. Safety and Liability, 2. Bias and Discrimi...
# 16    The United Nations has been leading the way ...
# 17    The Japanese government set forth three basi...
# 18    The World Bank's policy on access to informa...
#
#                            original_llama_generations
# 0     International cooperation on AI is important...
# 1     The research team took a multi-faceted appro...
# 2    \nCritics argue that the EU's AI Act could st...
# 3    \nThe European Union classifies AI systems un...
# 4     EPIC (Electronic Privacy Information Center)...
# 5     Whistleblowers and complaints play a crucial...
# 6    \nThe UK's approach to data protection is dif...
# 7     Japan's approach to AI regulation differs fr...
# 8     Foundational AI models are the basic buildin...
# 9    \nInternational cooperation on foundational A...
# 10    China's New Generation Artificial Intelligen...
# 11    Economic issues include concerns about intel...
# 12    The World Bank has played a significant role...
# 13    The AI assurance industry can contribute to ...
# 14    The White House's Blueprint for an AI Bill o...
# 15   \nThe main concerns in relation to AI policy ...
# 16    International cooperation on AI is currently...
# 17   \n\nIn 2019, the Japanese government establis...
# 18   \nThe World Bank's Policy on Access to Inform...

# %%
df_test_all.to_csv('results.csv')

# %% [markdown]
# ## **Metrics**

# %%
import locale
locale.getpreferredencoding = lambda: "UTF-8"
# !pip install nltk rouge -q
from nltk.translate.bleu_score import sentence_bleu
from rouge import Rouge

# %%
import numpy as np
import pandas as pd
import warnings
warnings.filterwarnings('ignore')
def jaccard_similarity(text1, text2):
    """Calculates the Jaccard Similarity between two texts."""
    # Tokenize both texts
    tokens1 = set(text1.lower().split())
    tokens2 = set(text2.lower().split())

    intersection = tokens1.intersection(tokens2)
    union = tokens1.union(tokens2)
    similarity = len(intersection) / len(union)
    return similarity
def calculate_bleu_rouge(reference, candidate):
    """
    Calculate BLEU and ROUGE scores for a pair of strings.

    :param reference: The reference string (ground truth).
    :param candidate: The candidate string (generated text).
    :return: A dictionary containing BLEU and ROUGE scores.
    """
    # Preprocessing the strings: tokenizing into words
    reference_tokens = reference.split()
    candidate_tokens = candidate.split()

    # Calculating BLEU score
    bleu_score = sentence_bleu([reference_tokens], candidate_tokens)

    # Calculating ROUGE score
    rouge = Rouge()
    rouge_score = rouge.get_scores(candidate, reference)[0]

    return np.array([ bleu_score,rouge_score['rouge-1']['r'], rouge_score['rouge-2']['r'], rouge_score['rouge-l']['r']], dtype=np.float32)

# Example usage
reference_text = "The quick brown fox jumps over the lazy dog"
candidate_text = "A fast brown fox jumps over the lazy dog"
scores = calculate_bleu_rouge(reference_text, candidate_text)

print(scores)
# Out:
# [0.7259795 0.7777778 0.75      0.7777778]

# %%
# raw_model_metrics = df_test_all.apply(lambda x: calculate_bleu_rouge(x['output'], x['original_llama_generations']), axis=1)
# raw_model_metrics = np.array(raw_model_metrics).mean(-1)
# raw_model_metrics
# Out:
# array([0.01586311, 0.32068324, 0.08269039, 0.27278593], dtype=float32)

# %%
fine_tuned_model_metrics = df_test_all.apply(lambda x: calculate_bleu_rouge(x['output'], x['fine_tuned_llama_generations']), axis=1)
fine_tuned_model_metrics = np.array(fine_tuned_model_metrics).mean(-1)
fine_tuned_model_metrics
# Out:
# array([0.0198339 , 0.29949668, 0.08027118, 0.2574295 ], dtype=float32)

# %%
raw_model_metrics=np.array([0.012922,	0.307788,	0.077700,	0.256869])
df_metrics = pd.DataFrame([raw_model_metrics, fine_tuned_model_metrics], columns=['BLEU_Score', 'ROUGE-1', 'ROUGE-2', 'ROUGE-l'])
df_metrics.index  = ['Raw_llama2', 'Fine_tuned_llama2_batch*2']
df_metrics
# Out:
#                            BLEU_Score   ROUGE-1   ROUGE-2   ROUGE-l
# Raw_llama2                   0.015863  0.320683  0.082690  0.272786
# Fine_tuned_llama2_batch*2    0.019834  0.299497  0.080271  0.257430

# %%
# for i in range(len(df_test_all)):
#   row = df_test_all.iloc[i]
#   print(i)
#   print("label:")
#   print(row['output'])
#   print("generations:")
#   print(row['fine_tuned_llama_generations'])

# %%
# for i in range(len(df_test_all)):
#   row = df_test_all.iloc[i]
#   print(i)
#   print("label:")
#   print(row['output'])
#   print("generations:")
#   print(row['original_llama_generations'])
