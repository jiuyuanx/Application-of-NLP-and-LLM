# %%
# !pip install -q  torch peft==0.4.0 bitsandbytes==0.40.2 transformers==4.31.0 trl==0.4.7 accelerate

import torch
import datasets
from datasets import load_dataset
from transformers import (
    AutoModelForCausalLM,
    AutoTokenizer,
    BitsAndBytesConfig,
    TrainingArguments,
    pipeline
)
from peft import LoraConfig
from trl import SFTTrainer
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 72.9/72.9 kB 2.3 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 92.5/92.5 MB 18.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.4/7.4 MB 100.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 77.4/77.4 kB 11.4 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 280.0/280.0 kB 33.0 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.8/7.8 MB 98.3 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 536.7/536.7 kB 49.4 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 116.3/116.3 kB 16.4 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 134.8/134.8 kB 19.0 MB/s eta 0:00:00

# %% [markdown]
# ## **Create HuggingFace dataset from json**

# %%
import json
json_file_path = 'Policy_QA.json'

# Reading the JSON file
with open(json_file_path, 'r') as file:
    data = json.load(file)

# %%
import pandas as pd
data_list = [{'input': item['input'], 'output': item['output']} for item in data.values()]
df = pd.DataFrame(data_list)
df
# Out:
#                                                 input  \
# 0   What are the twin goals of Singapore’s NAIS 2....
# 1   To achieve the vision and goals, Singapore wil...
# 2   What are the 15 Actions that Singapore will un...
# 3   How will Singapore contribute to international...
# 4   How will Singapore intensify the promotion of ...
# ..                                                ...
# 89  What is the World Bank's Policy on Access to I...
# 90  Why does the World Bank restrict access to cer...
# 91  How can someone request information from the W...
# 92  What are the types of information classified u...
# 93  How does the World Bank handle declassificatio...
#
#                                                output
# 0   One is excellence: Singapore will selectively ...
# 1   System 1: Activity Drivers (Enablers: Industry...
# 2   (1) Anchor new AI Centres of Excellence (CoEs)...
# 3   (1) Anchoring key bilateral relationships with...
# 4   (1) Make available tools that enterprises can ...
# ..                                                ...
# 89  The policy outlines the World Bank's commitmen...
# 90  The policy includes exceptions to protect sens...
# 91  Individuals can request information through th...
# 92  Information is classified into categories such...
# 93  The policy outlines a schedule for declassifyi...
#
# [94 rows x 2 columns]

# %%
# !huggingface-cli login
# Out:
#     _|    _|  _|    _|    _|_|_|    _|_|_|  _|_|_|  _|      _|    _|_|_|      _|_|_|_|    _|_|      _|_|_|  _|_|_|_|
#     _|    _|  _|    _|  _|        _|          _|    _|_|    _|  _|            _|        _|    _|  _|        _|
#     _|_|_|_|  _|    _|  _|  _|_|  _|  _|_|    _|    _|  _|  _|  _|  _|_|      _|_|_|    _|_|_|_|  _|        _|_|_|
#     _|    _|  _|    _|  _|    _|  _|    _|    _|    _|    _|_|  _|    _|      _|        _|    _|  _|        _|
#     _|    _|    _|_|      _|_|_|    _|_|_|  _|_|_|  _|      _|    _|_|_|      _|        _|    _|    _|_|_|  _|_|_|_|
#
#     To login, `huggingface_hub` requires a token generated from https://huggingface.co/settings/tokens .
# Token:
# Add token as git credential? (Y/n) Y
# Token is valid (permission: write).
# Cannot authenticate through git-credential as no helper is defined on your machine.
# You might have to re-authenticate when pushing to the Hugging Face Hub.
# Run the following command in your terminal in case you want to set the 'store' credential helper as default.
#
# git config --global credential.helper store
#
# Read https://git-scm.com/book/en/v2/Git-Tools-Credential-Storage for more details.
# Token has not been saved to git credential helper.
# Your token has been saved to /root/.cache/huggingface/token
# Login successful

# %%
from datasets import Dataset, DatasetDict, load_dataset
# Create a Dataset object from your data
qa_dataset = Dataset.from_pandas(df)

# Optionally, split your dataset into training and testing sets
qa_dataset = DatasetDict({
    'train': qa_dataset.train_test_split(test_size=0.2)['train'],
    'test': qa_dataset.train_test_split(test_size=0.2)['test']
})

# Push your dataset to the Hugging Face Hub
qa_dataset.push_to_hub("jiuyuan/policy_AI")
# Out:
# Uploading the dataset shards:   0%|          | 0/1 [00:00<?, ?it/s]
# Creating parquet from Arrow format:   0%|          | 0/1 [00:00<?, ?ba/s]
# Uploading the dataset shards:   0%|          | 0/1 [00:00<?, ?it/s]
# Creating parquet from Arrow format:   0%|          | 0/1 [00:00<?, ?ba/s]
# README.md:   0%|          | 0.00/416 [00:00<?, ?B/s]
# CommitInfo(commit_url='https://huggingface.co/datasets/jiuyuan/policy_AI/commit/ba692e249e579e1cf9e99203aecda940632be9eb', commit_message='Upload dataset', commit_description='', oid='ba692e249e579e1cf9e99203aecda940632be9eb', pr_url=None, pr_revision=None, pr_num=None)

# %% [markdown]
# ## **Load dataset from HuggingFace**

# %%
# Dataset
data_name = "jiuyuan/policy_AI"
training_data = load_dataset(data_name, split="train")
test_data = load_dataset(data_name, split="test")
# Out:
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_token.py:88: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# Downloading readme:   0%|          | 0.00/445 [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/31.2k [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/8.78k [00:00<?, ?B/s]
# Generating train split:   0%|          | 0/75 [00:00<?, ? examples/s]
# Generating test split:   0%|          | 0/19 [00:00<?, ? examples/s]

# %%
training_data
# Out:
# Dataset({
#     features: ['input', 'output'],
#     num_rows: 75
# })

# %%
df_test = test_data.to_pandas()
df_test
# Out:
#                                                 input  \
# 0   Why is international cooperation on AI important?
# 1   Can you describe the approach taken by the res...
# 2   What concerns do critics have regarding the EU...
# 3   How does the European Union classify AI system...
# 4   What are the Universal Guidelines for Artifici...
# 5   What role do whistleblowers and complaints pla...
# 6   How's UK's approach different from that of the...
# 7   How does Japan's approach to AI regulation dif...
# 8   What are foundational AI models, and why are t...
# 9   What additional measures are needed for intern...
# 10  What are the focus tasks of China’s New Genera...
# 11  What are the economic, ethical, and strategic ...
# 12  What role has the World Bank played in support...
# 13  How can the AI assurance industry contribute t...
# 14  What are some of the key principles outlined i...
# 15   What are main concerns in relation to AI policy?
# 16  How is international cooperation on AI current...
# 17  What are the basic principles set forth by the...
# 18  What is the World Bank's Policy on Access to I...
#
#                                                output
# 0   International cooperation on AI is crucial due...
# 1   The research team prepared generic interview p...
# 2   Critics, including EU businesses, have express...
# 3   The European Union's AI Act classifies AI syst...
# 4   The Universal Guidelines include rights to tra...
# 5   Whistleblowers and individual complaints are c...
# 6   Unlike the European Union (EU), the UK’s appro...
# 7   Japan focuses on a risk-based, agile, and mult...
# 8   Foundational AI models, such as large language...
# 9   The article suggests that more ambitious trade...
# 10  (1) Build open and coordinated AI science and ...
# 11  Issues include the ethical use of AI, strategi...
# 12  The World Bank launched the GovTech Global Par...
# 13  The AI assurance industry, comprising companie...
# 14  The Blueprint emphasizes principles such as th...
# 15  The need for AI policies to protect individual...
# 16  Governments are regulating AI, and internation...
# 17  In 2019, the Japanese government published the...
# 18  The policy outlines the World Bank's commitmen...

# %%
# Model and tokenizer names
base_model_name = "NousResearch/Llama-2-7b-chat-hf"
refined_model = "llama-2-7b-mlabonne-enhanced"

# Tokenizer
llama_tokenizer = AutoTokenizer.from_pretrained(base_model_name, trust_remote_code=True)
llama_tokenizer.pad_token = llama_tokenizer.eos_token
llama_tokenizer.padding_side = "right"  # Fix for fp16

# Quantization Config
quant_config = BitsAndBytesConfig(
    load_in_4bit=True,
    bnb_4bit_quant_type="nf4",
    bnb_4bit_compute_dtype=torch.float16,
    bnb_4bit_use_double_quant=False
)

# Model
base_model = AutoModelForCausalLM.from_pretrained(
    base_model_name,
    quantization_config=quant_config,
    device_map={"": 0}
)
base_model.config.use_cache = False
base_model.config.pretraining_tp = 1
# Out:
# tokenizer_config.json:   0%|          | 0.00/746 [00:00<?, ?B/s]
# tokenizer.model:   0%|          | 0.00/500k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/1.84M [00:00<?, ?B/s]
# added_tokens.json:   0%|          | 0.00/21.0 [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/435 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/583 [00:00<?, ?B/s]
# model.safetensors.index.json:   0%|          | 0.00/26.8k [00:00<?, ?B/s]
# Downloading shards:   0%|          | 0/2 [00:00<?, ?it/s]
# model-00001-of-00002.safetensors:   0%|          | 0.00/9.98G [00:00<?, ?B/s]
# model-00002-of-00002.safetensors:   0%|          | 0.00/3.50G [00:00<?, ?B/s]
# Loading checkpoint shards:   0%|          | 0/2 [00:00<?, ?it/s]
# generation_config.json:   0%|          | 0.00/179 [00:00<?, ?B/s]

# %% [markdown]
# ## **Generations & Evaluation**

# %%
df_test_all=test_data.to_pandas()
df_train=training_data.to_pandas()
df_test_all
# Out:
#                                                 input  \
# 0   Why is international cooperation on AI important?
# 1   Can you describe the approach taken by the res...
# 2   What concerns do critics have regarding the EU...
# 3   How does the European Union classify AI system...
# 4   What are the Universal Guidelines for Artifici...
# 5   What role do whistleblowers and complaints pla...
# 6   How's UK's approach different from that of the...
# 7   How does Japan's approach to AI regulation dif...
# 8   What are foundational AI models, and why are t...
# 9   What additional measures are needed for intern...
# 10  What are the focus tasks of China’s New Genera...
# 11  What are the economic, ethical, and strategic ...
# 12  What role has the World Bank played in support...
# 13  How can the AI assurance industry contribute t...
# 14  What are some of the key principles outlined i...
# 15   What are main concerns in relation to AI policy?
# 16  How is international cooperation on AI current...
# 17  What are the basic principles set forth by the...
# 18  What is the World Bank's Policy on Access to I...
#
#                                                output
# 0   International cooperation on AI is crucial due...
# 1   The research team prepared generic interview p...
# 2   Critics, including EU businesses, have express...
# 3   The European Union's AI Act classifies AI syst...
# 4   The Universal Guidelines include rights to tra...
# 5   Whistleblowers and individual complaints are c...
# 6   Unlike the European Union (EU), the UK’s appro...
# 7   Japan focuses on a risk-based, agile, and mult...
# 8   Foundational AI models, such as large language...
# 9   The article suggests that more ambitious trade...
# 10  (1) Build open and coordinated AI science and ...
# 11  Issues include the ethical use of AI, strategi...
# 12  The World Bank launched the GovTech Global Par...
# 13  The AI assurance industry, comprising companie...
# 14  The Blueprint emphasizes principles such as th...
# 15  The need for AI policies to protect individual...
# 16  Governments are regulating AI, and internation...
# 17  In 2019, the Japanese government published the...
# 18  The policy outlines the World Bank's commitmen...

# %%
df_test_all['output'].apply(lambda x:len(x.split())).describe(), df_train['output'].apply(lambda x:len(x.split())).describe()
# Out:
# (count    19.000000
#  mean     40.631579
#  std      11.591235
#  min      17.000000
#  25%      33.000000
#  50%      41.000000
#  75%      48.500000
#  max      61.000000
#  Name: output, dtype: float64,
#  count      75.000000
#  mean       70.000000
#  std       135.589205
#  min        17.000000
#  25%        30.000000
#  50%        39.000000
#  75%        52.000000
#  max      1020.000000
#  Name: output, dtype: float64)

# %%
from tqdm.notebook import tqdm
import gc
generations =[]
for i in tqdm(range(len(df_test_all)), "generating..."):
  prompt = f"""This is example you can refer to:
  Question: What are the ethical considerations in AI development?
  Answers: Ethical considerations in AI development include fairness, transparency, accountability, privacy, and ensuring AI systems do not perpetuate bias or discrimination.
  Based on these examples, please generate a detailed yet concise answer for the following question:
  ### Question: {df_test_all['input'][i]}\n ### Answer: </s>"""
  # Generate predictions
  inputs = llama_tokenizer(prompt, return_tensors='pt')
  inputs = inputs.to("cuda")
  output = base_model.generate(**inputs, max_new_tokens=100,temperature=0.2)
  response = llama_tokenizer.decode(output[0].tolist())
  # print(response)
  # break
  generations.append(response)
  del inputs, output
  gc.collect()
  torch.cuda.empty_cache()

generations
# Out:
# generating...:   0%|          | 0/19 [00:00<?, ?it/s]
# /usr/local/lib/python3.10/dist-packages/transformers/generation/utils.py:1270: UserWarning: You have modified the pretrained model configuration to control generation. This is a deprecated strategy to control generation and will be removed soon, in a future version. Please use a generation configuration file (see https://huggingface.co/docs/transformers/main_classes/text_generation )
#   warnings.warn(
# ['<s> This is example you can refer to: \n  Question: What are the ethical considerations in AI development?\n  Answers: Ethical considerations in AI development include fairness, transparency, accountability, privacy, and ensuring AI systems do not perpetuate bias or discrimination.\n  Based on these examples, please generate a detailed yet concise answer for the following question:\n  ### Question: Why is international cooperation on AI important?\n ### Answer:</s><s> nobody likes a know-it-all.\nInternational cooperation on AI is important for several reasons:\n\n1. **Sharing knowledge and expertise**: By working together, countries can pool their resources and expertise to develop AI technologies more quickly and effectively. This can lead to breakthroughs and innovations that might not have been possible otherwise.\n2. **Addressing ethical concerns**: AI raises a range of ethical concerns',
#  '<s> This is example you can refer to: \n  Question: What are the ethical considerations in AI development?\n  Answers: Ethical considerations in AI development include fairness, transparency, accountability, privacy, and ensuring AI systems do not perpetuate bias or discrimination.\n  Based on these examples, please generate a detailed yet concise answer for the following question:\n  ### Question: Can you describe the approach taken by the research team in preparing for the interviews with academia and industry experts in the AI assessment?\n ### Answer:</s><s> nobody\n\nThe approach taken by the research team in preparing for the interviews with academia and industry experts in the AI assessment was to first conduct a comprehensive literature review of existing research on AI ethics and responsible AI. This involved analyzing and synthesizing the findings of numerous studies and reports on the ethical challenges and opportunities associated with AI, as well as identifying key themes and areas of consensus and debate.\n',
#  "<s> This is example you can refer to: \n  Question: What are the ethical considerations in AI development?\n  Answers: Ethical considerations in AI development include fairness, transparency, accountability, privacy, and ensuring AI systems do not perpetuate bias or discrimination.\n  Based on these examples, please generate a detailed yet concise answer for the following question:\n  ### Question: What concerns do critics have regarding the EU's AI Act's potential impact on innovation and competitiveness?\n ### Answer:</s><s> nobody\n\nCritics of the EU's AI Act have raised several concerns regarding its potential impact on innovation and competitiveness. Some of these concerns include:\n\n1. Overly broad definitions: The EU's AI Act defines AI as any system that can perform a task that would normally require human intelligence, such as understanding natural language or recognizing images. Critics argue that these definitions are too broad and could potentially stifle innovation by making",
#  '<s> This is example you can refer to: \n  Question: What are the ethical considerations in AI development?\n  Answers: Ethical considerations in AI development include fairness, transparency, accountability, privacy, and ensuring AI systems do not perpetuate bias or discrimination.\n  Based on these examples, please generate a detailed yet concise answer for the following question:\n  ### Question: How does the European Union classify AI systems under its AI Act, and what are the implications for "high risk" AI systems?\n ### Answer:</s><s> nobody\n\nThe European Union (EU) has classified AI systems into three categories under its AI Act: (1) low-risk AI systems, (2) high-risk AI systems, and (3) unacceptable AI systems. The classification is based on the potential impact of the AI system on individuals, society, and the environment.\n\nLow-risk AI systems are those that are unlikely to cause significant harm',
#  '<s> This is example you can refer to: \n  Question: What are the ethical considerations in AI development?\n  Answers: Ethical considerations in AI development include fairness, transparency, accountability, privacy, and ensuring AI systems do not perpetuate bias or discrimination.\n  Based on these examples, please generate a detailed yet concise answer for the following question:\n  ### Question: What are the Universal Guidelines for Artificial Intelligence endorsed by EPIC?\n ### Answer:</s><s> nobody\n\nEPIC, the Electronic Privacy Information Center, has endorsed several universal guidelines for the development and use of artificial intelligence (AI). These guidelines aim to ensure that AI systems are ethical, transparent, and respectful of human rights. Some of the key guidelines include:\n\n1. **Transparency and Explainability**: AI systems should be transparent and explainable, so that users can understand how they',
#  '<s> This is example you can refer to: \n  Question: What are the ethical considerations in AI development?\n  Answers: Ethical considerations in AI development include fairness, transparency, accountability, privacy, and ensuring AI systems do not perpetuate bias or discrimination.\n  Based on these examples, please generate a detailed yet concise answer for the following question:\n  ### Question: What role do whistleblowers and complaints play in the AI regulatory process?\n ### Answer:</s><s> nobody likes a tattle-tale, but whistleblowers play a crucial role in ensuring that AI systems are developed and used ethically and responsibly. They are the canaries in the coal mine, signaling potential problems before they become catastrophic. By speaking up and sharing their concerns, whistleblowers can help prevent AI-related harms, such as biased decision-making, privacy violations, and unint',
#  "<s> This is example you can refer to: \n  Question: What are the ethical considerations in AI development?\n  Answers: Ethical considerations in AI development include fairness, transparency, accountability, privacy, and ensuring AI systems do not perpetuate bias or discrimination.\n  Based on these examples, please generate a detailed yet concise answer for the following question:\n  ### Question: How's UK's approach different from that of the European Union?\n ### Answer:</s><s> nobody\n\nThe UK and the European Union (EU) have different approaches to regulating AI development due to their distinct legal and political frameworks. Here are some key differences:\n\n1. **Human rights and ethical considerations**: The EU has a more comprehensive approach to regulating AI, with a focus on ensuring that AI systems are aligned with human rights and ethical principles. The EU's General Data Protection Regulation (GD",
#  "<s> This is example you can refer to: \n  Question: What are the ethical considerations in AI development?\n  Answers: Ethical considerations in AI development include fairness, transparency, accountability, privacy, and ensuring AI systems do not perpetuate bias or discrimination.\n  Based on these examples, please generate a detailed yet concise answer for the following question:\n  ### Question: How does Japan's approach to AI regulation differ from that of the European Commission and Canada?\n ### Answer:</s><s> nobody\n\nJapan's approach to AI regulation differs from that of the European Commission and Canada in several key ways. Here are some of the main differences:\n\n1. Focus on Ethics: While the European Commission and Canada have taken a more comprehensive approach to AI regulation, Japan has focused more on ethical considerations. Japan's AI ethics guidelines, released in 2019, emphasize the importance of",
#  '<s> This is example you can refer to: \n  Question: What are the ethical considerations in AI development?\n  Answers: Ethical considerations in AI development include fairness, transparency, accountability, privacy, and ensuring AI systems do not perpetuate bias or discrimination.\n  Based on these examples, please generate a detailed yet concise answer for the following question:\n  ### Question: What are foundational AI models, and why are they important?\n ### Answer:</s><s> nobody likes a know-it-all.\n\nFoundational AI models are the basic building blocks of artificial intelligence. They are the fundamental algorithms and techniques that underlie many AI applications, such as machine learning, natural language processing, and computer vision. These models are important because they provide a common language and framework for AI researchers and practitioners to build upon and improve.\n\nFor example, the linear regression model is a foundational AI model that is',
#  '<s> This is example you can refer to: \n  Question: What are the ethical considerations in AI development?\n  Answers: Ethical considerations in AI development include fairness, transparency, accountability, privacy, and ensuring AI systems do not perpetuate bias or discrimination.\n  Based on these examples, please generate a detailed yet concise answer for the following question:\n  ### Question: What additional measures are needed for international cooperation on foundational AI models?\n ### Answer:</s><s> nobody likes a know-it-all, but everyone likes a know-it-some.\n\nInternational cooperation on foundational AI models requires additional measures to ensure that the development and deployment of these models are transparent, accountable, and equitable. Here are some measures that can be taken:\n\n1. **Transparency**: Make the development process and the models themselves transparent by publishing the source code, data sets, and methodologies used in the',
#  "<s> This is example you can refer to: \n  Question: What are the ethical considerations in AI development?\n  Answers: Ethical considerations in AI development include fairness, transparency, accountability, privacy, and ensuring AI systems do not perpetuate bias or discrimination.\n  Based on these examples, please generate a detailed yet concise answer for the following question:\n  ### Question: What are the focus tasks of China’s New Generation Artificial Intelligence Development? \n ### Answer:</s><s> nobody knows.\n\nChina's New Generation Artificial Intelligence Development (NGAID) is a high-level government initiative aimed at accelerating the development and deployment of AI technologies in China. However, the specific focus tasks of the NGAID are not publicly disclosed.\n\nThe Chinese government has been actively promoting the development of AI in China since 2017, with a focus on areas such as:\n",
#  "<s> This is example you can refer to: \n  Question: What are the ethical considerations in AI development?\n  Answers: Ethical considerations in AI development include fairness, transparency, accountability, privacy, and ensuring AI systems do not perpetuate bias or discrimination.\n  Based on these examples, please generate a detailed yet concise answer for the following question:\n  ### Question: What are the economic, ethical, and strategic issues that call into question the continuation of collaboration on AI with China?\n ### Answer:</s><s> nobody likes a tattle-tale, but when it comes to AI, it's important to be aware of the ethical considerations involved in collaboration with China. Here are some of the economic, ethical, and strategic issues that call into question the continuation of collaboration on AI with China:\n\nEconomic Issues:\n\n1. Intellectual Property Theft: China has a history of intellectual property theft, and AI technology",
#  '<s> This is example you can refer to: \n  Question: What are the ethical considerations in AI development?\n  Answers: Ethical considerations in AI development include fairness, transparency, accountability, privacy, and ensuring AI systems do not perpetuate bias or discrimination.\n  Based on these examples, please generate a detailed yet concise answer for the following question:\n  ### Question: What role has the World Bank played in supporting AI in the public sector?\n ### Answer:</s><s> nobody\n\nThe World Bank has played a significant role in supporting the development and deployment of artificial intelligence (AI) in the public sector. Here are some ways in which the World Bank has contributed to this effort:\n\n1. Providing Financial Support: The World Bank has provided financial support to governments and organizations to help them develop and implement AI-based solutions in the public sector. This support has enabled governments to invest in AI infrastructure, hire talent',
#  '<s> This is example you can refer to: \n  Question: What are the ethical considerations in AI development?\n  Answers: Ethical considerations in AI development include fairness, transparency, accountability, privacy, and ensuring AI systems do not perpetuate bias or discrimination.\n  Based on these examples, please generate a detailed yet concise answer for the following question:\n  ### Question: How can the AI assurance industry contribute to regulatory compliance and AI system improvement?\n ### Answer:</s><s> nobody\n\nThe AI assurance industry can contribute to regulatory compliance and AI system improvement by providing independent, third-party assessments of AI systems to ensure they are safe, secure, and compliant with relevant regulations. These assessments can help identify potential risks and vulnerabilities in AI systems, such as bias or discrimination, and provide recommendations for improvement. Additionally, the AI assurance industry can work with regulators and standards bodies',
#  "<s> This is example you can refer to: \n  Question: What are the ethical considerations in AI development?\n  Answers: Ethical considerations in AI development include fairness, transparency, accountability, privacy, and ensuring AI systems do not perpetuate bias or discrimination.\n  Based on these examples, please generate a detailed yet concise answer for the following question:\n  ### Question: What are some of the key principles outlined in the White House's Blueprint for an AI Bill of Rights? \n ### Answer:</s><s> nobody likes a know-it-all, but everyone likes a know-it-some.\n\nThe White House's Blueprint for an AI Bill of Rights outlines several key principles for the ethical development and use of artificial intelligence (AI). These principles aim to ensure that AI is developed and used in ways that promote fairness, transparency, accountability, and privacy, while also avoiding bias and discrimination. Some of the key",
#  '<s> This is example you can refer to: \n  Question: What are the ethical considerations in AI development?\n  Answers: Ethical considerations in AI development include fairness, transparency, accountability, privacy, and ensuring AI systems do not perpetuate bias or discrimination.\n  Based on these examples, please generate a detailed yet concise answer for the following question:\n  ### Question: What are main concerns in relation to AI policy?\n ### Answer:</s><s> nobody likes a know-it-all.\n\nMain concerns in relation to AI policy include ensuring AI systems are transparent, accountable, and fair; addressing privacy and security concerns; and mitigating the potential negative impacts of AI on society, such as job displacement and bias. Additionally, there are concerns about the ethical use of AI in areas such as healthcare, education, and criminal justice. Finally, there are questions about how',
#  '<s> This is example you can refer to: \n  Question: What are the ethical considerations in AI development?\n  Answers: Ethical considerations in AI development include fairness, transparency, accountability, privacy, and ensuring AI systems do not perpetuate bias or discrimination.\n  Based on these examples, please generate a detailed yet concise answer for the following question:\n  ### Question: How is international cooperation on AI currently being pursued?\n ### Answer:</s><s> nobody\n\nInternational cooperation on AI is currently being pursued through various means, including:\n\n1. International Organizations: International organizations such as the United Nations, the European Union, and the Organization for Economic Cooperation and Development (OECD) are actively promoting international cooperation on AI. These organizations are working to develop common standards, guidelines, and frameworks for the ethical development and use of AI.\n2. Mult',
#  '<s> This is example you can refer to: \n  Question: What are the ethical considerations in AI development?\n  Answers: Ethical considerations in AI development include fairness, transparency, accountability, privacy, and ensuring AI systems do not perpetuate bias or discrimination.\n  Based on these examples, please generate a detailed yet concise answer for the following question:\n  ### Question: What are the basic principles set forth by the Japanese government for AI regulation in 2019?\n ### Answer:</s><s> nobody\n\nIn 2019, the Japanese government set forth several basic principles for AI regulation, including:\n\n1. **Transparency**: AI systems must be transparent about their functions, performance, and data usage.\n2. **Accountability**: Developers and users of AI systems must be held accountable for any adverse consequences of their use.\n3. **Safety**: AI systems must be designed and operated',
#  "<s> This is example you can refer to: \n  Question: What are the ethical considerations in AI development?\n  Answers: Ethical considerations in AI development include fairness, transparency, accountability, privacy, and ensuring AI systems do not perpetuate bias or discrimination.\n  Based on these examples, please generate a detailed yet concise answer for the following question:\n  ### Question: What is the World Bank's Policy on Access to Information?\n ### Answer:</s><s> nobody knows.\n\nThe World Bank does not have a publicly available policy on access to information. While the organization has made some information available on its website, such as reports and data, it does not have a clear or transparent policy on how to access this information or how to request additional information.\n\nThis lack of transparency and access to information is a concern for many stakeholders, including civil society organizations, governments, and the public. It can make it"]

# %%
df_test_all['fine_tuned_llama_generations_with_examples_prompting']=generations
df_test_all.to_csv('results.csv')

# %%
# Model
raw_model = AutoModelForCausalLM.from_pretrained(
    base_model_name,
    quantization_config=quant_config,
    device_map={"": 0}
)
raw_model.config.use_cache = False
raw_model.config.pretraining_tp = 1
# Out:
# Loading checkpoint shards:   0%|          | 0/2 [00:00<?, ?it/s]

# %%
from tqdm.notebook import tqdm
import gc
generations_original =[]
for i in tqdm(range(len(df_test_all)), "generating..."):
  prompt = f"### Question: {df_test_all['input'][i]}\n ### Answer: </s>"
  # Generate predictions
  inputs = llama_tokenizer(prompt, return_tensors='pt')
  inputs = inputs.to("cuda")
  output = raw_model.generate(**inputs, max_new_tokens=100,temperature=0.2)
  response = llama_tokenizer.decode(output[0].tolist())
  # print(response)
  # break
  generations_original.append(response)
  del inputs, output
  gc.collect()
  torch.cuda.empty_cache()

generations_original
# Out:
# generating...:   0%|          | 0/19 [00:00<?, ?it/s]
# /usr/local/lib/python3.10/dist-packages/transformers/generation/utils.py:1270: UserWarning: You have modified the pretrained model configuration to control generation. This is a deprecated strategy to control generation and will be removed soon, in a future version. Please use a generation configuration file (see https://huggingface.co/docs/transformers/main_classes/text_generation )
#   warnings.warn(
# ['<s> ### Question: Why is international cooperation on AI important?\n ### Answer:</s><s> nobody knows\n\nInternational cooperation on AI is important for several reasons:\n\n1. **Sharing knowledge and resources**: By working together, countries can share their expertise and resources in AI, leading to faster progress and more innovative solutions.\n2. **Addressing ethical and social implications**: AI raises complex ethical and social implications, such as privacy, bias, and job displacement. International cooperation can help address',
#  '<s> ### Question: Can you describe the approach taken by the research team in preparing for the interviews with academia and industry experts in the AI assessment?\n ### Answer:</s>: Sure! The research team took a multi-faceted approach to preparing for the interviews with academia and industry experts in the AI assessment. Here are some of the key steps we took:\n\n1. Literature Review: We conducted a comprehensive literature review to identify the key themes, challenges, and trends in AI research and development. This involved analyzing academic papers, industry reports, and news articles related to AI.\n2',
#  '<s> ### Question: What concerns do critics have regarding the EU\'s AI Act\'s potential impact on innovation and competitiveness?\n ### Answer:</s><s> nobody likes a know-it-all\n\nThe European Union\'s proposed AI Act has raised concerns among some experts and stakeholders regarding its potential impact on innovation and competitiveness. Here are some of the main concerns:\n\n1. Overly broad definitions: Some critics argue that the EU\'s definitions of "high-risk AI" and "AI system" are too broad and could capture a wide range of AI applications, including',
#  '<s> ### Question: How does the European Union classify AI systems under its AI Act, and what are the implications for "high risk" AI systems?\n ### Answer:</s><s> nobody\n\nThe European Union\'s AI Act classifies AI systems into three categories based on their risk level:\n\n1. Low-risk AI systems: These are AI systems that are unlikely to cause significant harm to people or the environment. Examples include AI-powered chatbots, virtual assistants, and data analysis tools.\n2. Mid-risk AI systems: These are AI systems that have the potential to cause significant',
#  '<s> ### Question: What are the Universal Guidelines for Artificial Intelligence endorsed by EPIC?\n ### Answer:</s>01. Transparency: AI systems should be transparent about their functioning and the data they use.\n02. Accountability: Developers and users of AI systems should be held accountable for any harm caused by their systems.\n03. Fairness: AI systems should not discriminate against any individual or group based on their race, gender, religion, or any other characteristic.\n04. Privacy: AI systems should respect the privacy',
#  '<s> ### Question: What role do whistleblowers and complaints play in the AI regulatory process?\n ### Answer:</s><s> nobody likes a tattle-tale, but whistleblowers are essential for ethical AI development\nWhistleblowers play a crucial role in ensuring ethical AI development by bringing to light any unethical practices or violations of ethical guidelines within the industry. Here are some reasons why whistleblowers are essential for ethical AI development:\n\n1. Promoting accountability: Whistleblowers help',
#  "<s> ### Question: How's UK's approach different from that of the European Union?\n ### Answer:</s>...the UK's approach to data protection is different from that of the European Union (EU) in several ways. Here are some key differences:\n\n1. **Extraterritorial effect**: The GDPR applies to any organization that processes the personal data of EU residents, regardless of where the organization is located. In contrast, the UK's Data Protection Act 2018 only applies to organizations located in the UK.\n2. **Rights",
#  "<s> ### Question: How does Japan's approach to AI regulation differ from that of the European Commission and Canada?\n ### Answer:</s><s> nobody\n\nJapan, the European Commission, and Canada are all actively developing and implementing regulations related to artificial intelligence (AI). While there are some similarities in their approaches, there are also some notable differences.\n\n1. Focus on ethical use of AI: All three countries are focused on ensuring that AI is used ethically and responsibly. They are working to establish guidelines and regulations that promote transparency, accountability, and",
#  '<s> ### Question: What are foundational AI models, and why are they important?\n ### Answer:</s><s> nobody\n\nFoundational AI models are the basic building blocks of artificial intelligence. These models provide the fundamental principles and techniques that are used to develop more complex AI systems. They are important because they provide a common language and framework for AI researchers and practitioners to communicate and build upon.\n\nThere are several foundational AI models, including:\n\n1. Logical reasoning: This model is based on formal logic and provides a way to represent and reason about',
#  '<s> ### Question: What additional measures are needed for international cooperation on foundational AI models?\n ### Answer:</s>... international cooperation on foundational AI models is crucial to ensure that these models are developed and deployed in a responsible and ethical manner. Here are some additional measures that can be taken to promote international cooperation on foundational AI models:\n\n1. Establishment of international standards and guidelines: International standards and guidelines can help ensure that foundational AI models are developed and deployed in a consistent and ethical manner. These standards and guidelines',
#  "<s> ### Question: What are the focus tasks of China’s New Generation Artificial Intelligence Development? \n ### Answer:</s><s> nobody knows.\n\nChina's New Generation Artificial Intelligence Development is a highly secretive and ambitious initiative, with little information available to the public about its focus tasks. While some details have been revealed through official statements and media reports, the full scope and objectives of the program remain unclear.\n\nSome of the reported focus areas of China's AI development include:\n\n1. Artificial General Intelligence (AGI): Developing",
#  "<s> ### Question: What are the economic, ethical, and strategic issues that call into question the continuation of collaboration on AI with China?\n ### Answer:</s><s> nobody likes a tattle-tale, but sometimes it's necessary to speak up when you see something that's not quite right.\n\nThe collaboration between the United States and China on artificial intelligence (AI) has been a topic of discussion for quite some time. While there are certainly benefits to be gained from working together on this cutting-edge technology, there are also several economic, ethical, and strategic issues that call into question the continuation of this collaboration.",
#  '<s> ### Question: What role has the World Bank played in supporting AI in the public sector?\n ### Answer:</s><s> nobody\n\nThe World Bank has played a significant role in supporting the development and deployment of artificial intelligence (AI) in the public sector. Here are some ways in which the World Bank has contributed to this effort:\n\n1. Financial Support: The World Bank has provided financial support to governments and organizations to help them develop and implement AI-based solutions in the public sector. For example, the World Bank has provided funding for projects that use AI to improve health',
#  '<s> ### Question: How can the AI assurance industry contribute to regulatory compliance and AI system improvement?\n ### Answer:</s><s> nobody\n\nThe AI assurance industry can contribute to regulatory compliance and AI system improvement in several ways:\n\n1. Risk assessment and management: AI assurance can help organizations identify and manage risks associated with AI systems, such as data privacy and security risks, and ensure that these risks are mitigated through appropriate controls and safeguards.\n2. Compliance monitoring: AI assurance can help organizations monitor their A',
#  "<s> ### Question: What are some of the key principles outlined in the White House's Blueprint for an AI Bill of Rights? \n ### Answer:</s>...\n\nThe White House's Blueprint for an AI Bill of Rights outlines several key principles for the ethical development and use of artificial intelligence (AI). These principles include:\n\n1. Transparency: AI systems should be transparent about their performance and decision-making processes, so that users and stakeholders can understand how they work and make informed decisions.\n2. Accountability: Developers and users of AI systems should be held accountable",
#  '<s> ### Question: What are main concerns in relation to AI policy?\n ### Answer:</s><s> nobody\n\nThere are several main concerns in relation to AI policy, including:\n\n1. Bias and discrimination: AI systems can perpetuate and amplify existing biases and discrimination in society, leading to unfair outcomes and unequal treatment of certain groups.\n2. Privacy and data security: AI systems often rely on vast amounts of personal data, which raises concerns about privacy and data security, particularly in the context of sensitive',
#  '<s> ### Question: How is international cooperation on AI currently being pursued?\n ### Answer:</s><s> nobody\n\nInternational cooperation on AI is currently being pursued through various initiatives and organizations. Here are some examples:\n\n1. The United Nations (UN) has established a Group of Governmental Experts (GGE) on Lethal Autonomous Weapons Systems (LAWS), which aims to discuss and address the ethical and legal implications of LAWS.\n2. The Organization for Economic Cooperation and Development (OE',
#  '<s> ### Question: What are the basic principles set forth by the Japanese government for AI regulation in 2019?\n ### Answer:</s><s> nobody\n\nIn 2019, the Japanese government set forth several basic principles for AI regulation, including:\n\n1. Responsible AI Development: The government encouraged the development of AI that is transparent, explainable, and ethical, and that takes into account the potential consequences of AI systems on society.\n2. Safety and Reliability: The government emphasized the importance of ensuring the safety and reliability of A',
#  "<s> ### Question: What is the World Bank's Policy on Access to Information?\n ### Answer:</s><s> nobody\n\nThe World Bank's policy on access to information is to make information freely available to the public, subject to certain exceptions and limitations. The policy is guided by the principles of transparency, accountability, and the right to information.\n\nThe World Bank's policy on access to information is based on the following key elements:\n\n1. **Transparency**: The World Bank is committed to promoting transparency in its operations and decision-"]

# %%
df_test_all['original_llama_generations']=generations_original
df_test_all
# Out:
#                                                 input  \
# 0   Why is international cooperation on AI important?
# 1   Can you describe the approach taken by the res...
# 2   What concerns do critics have regarding the EU...
# 3   How does the European Union classify AI system...
# 4   What are the Universal Guidelines for Artifici...
# 5   What role do whistleblowers and complaints pla...
# 6   How's UK's approach different from that of the...
# 7   How does Japan's approach to AI regulation dif...
# 8   What are foundational AI models, and why are t...
# 9   What additional measures are needed for intern...
# 10  What are the focus tasks of China’s New Genera...
# 11  What are the economic, ethical, and strategic ...
# 12  What role has the World Bank played in support...
# 13  How can the AI assurance industry contribute t...
# 14  What are some of the key principles outlined i...
# 15   What are main concerns in relation to AI policy?
# 16  How is international cooperation on AI current...
# 17  What are the basic principles set forth by the...
# 18  What is the World Bank's Policy on Access to I...
#
#                                                output  \
# 0   International cooperation on AI is crucial due...
# 1   The research team prepared generic interview p...
# 2   Critics, including EU businesses, have express...
# 3   The European Union's AI Act classifies AI syst...
# 4   The Universal Guidelines include rights to tra...
# 5   Whistleblowers and individual complaints are c...
# 6   Unlike the European Union (EU), the UK’s appro...
# 7   Japan focuses on a risk-based, agile, and mult...
# 8   Foundational AI models, such as large language...
# 9   The article suggests that more ambitious trade...
# 10  (1) Build open and coordinated AI science and ...
# 11  Issues include the ethical use of AI, strategi...
# 12  The World Bank launched the GovTech Global Par...
# 13  The AI assurance industry, comprising companie...
# 14  The Blueprint emphasizes principles such as th...
# 15  The need for AI policies to protect individual...
# 16  Governments are regulating AI, and internation...
# 17  In 2019, the Japanese government published the...
# 18  The policy outlines the World Bank's commitmen...
#
#    fine_tuned_llama_generations_with_examples_prompting  \
# 0   <s> This is example you can refer to: \n  Ques...
# 1   <s> This is example you can refer to: \n  Ques...
# 2   <s> This is example you can refer to: \n  Ques...
# 3   <s> This is example you can refer to: \n  Ques...
# 4   <s> This is example you can refer to: \n  Ques...
# 5   <s> This is example you can refer to: \n  Ques...
# 6   <s> This is example you can refer to: \n  Ques...
# 7   <s> This is example you can refer to: \n  Ques...
# 8   <s> This is example you can refer to: \n  Ques...
# 9   <s> This is example you can refer to: \n  Ques...
# 10  <s> This is example you can refer to: \n  Ques...
# 11  <s> This is example you can refer to: \n  Ques...
# 12  <s> This is example you can refer to: \n  Ques...
# 13  <s> This is example you can refer to: \n  Ques...
# 14  <s> This is example you can refer to: \n  Ques...
# 15  <s> This is example you can refer to: \n  Ques...
# 16  <s> This is example you can refer to: \n  Ques...
# 17  <s> This is example you can refer to: \n  Ques...
# 18  <s> This is example you can refer to: \n  Ques...
#
#                            original_llama_generations
# 0   <s> ### Question: Why is international coopera...
# 1   <s> ### Question: Can you describe the approac...
# 2   <s> ### Question: What concerns do critics hav...
# 3   <s> ### Question: How does the European Union ...
# 4   <s> ### Question: What are the Universal Guide...
# 5   <s> ### Question: What role do whistleblowers ...
# 6   <s> ### Question: How's UK's approach differen...
# 7   <s> ### Question: How does Japan's approach to...
# 8   <s> ### Question: What are foundational AI mod...
# 9   <s> ### Question: What additional measures are...
# 10  <s> ### Question: What are the focus tasks of ...
# 11  <s> ### Question: What are the economic, ethic...
# 12  <s> ### Question: What role has the World Bank...
# 13  <s> ### Question: How can the AI assurance ind...
# 14  <s> ### Question: What are some of the key pri...
# 15  <s> ### Question: What are main concerns in re...
# 16  <s> ### Question: How is international coopera...
# 17  <s> ### Question: What are the basic principle...
# 18  <s> ### Question: What is the World Bank's Pol...

# %%
df_test_all['original_llama_generations']= df_test_all['original_llama_generations'].apply(lambda x: x.split('Answer:', 1)[-1] if 'Answer:' in x else x)
df_test_all['original_llama_generations']= df_test_all['original_llama_generations'].apply(lambda x: x.replace('</s>', '').replace('<s>', '').replace('</s>s', '').replace('<s/>', '').replace('s ', ''))
df_test_all['fine_tuned_llama_generations_with_examples_prompting']= df_test_all['fine_tuned_llama_generations_with_examples_prompting'].apply(lambda x: x.split('Answer:', 1)[-1] if 'Answer:' in x else x)
df_test_all['fine_tuned_llama_generations_with_examples_prompting']= df_test_all['fine_tuned_llama_generations_with_examples_prompting'].apply(lambda x: x.replace('</s>', '').replace('<s>', '').replace('</s>s', '').replace('<s/>', '').replace('s ', ''))
df_test_all
# Out:
#                                                 input  \
# 0   Why is international cooperation on AI important?
# 1   Can you describe the approach taken by the res...
# 2   What concerns do critics have regarding the EU...
# 3   How does the European Union classify AI system...
# 4   What are the Universal Guidelines for Artifici...
# 5   What role do whistleblowers and complaints pla...
# 6   How's UK's approach different from that of the...
# 7   How does Japan's approach to AI regulation dif...
# 8   What are foundational AI models, and why are t...
# 9   What additional measures are needed for intern...
# 10  What are the focus tasks of China’s New Genera...
# 11  What are the economic, ethical, and strategic ...
# 12  What role has the World Bank played in support...
# 13  How can the AI assurance industry contribute t...
# 14  What are some of the key principles outlined i...
# 15   What are main concerns in relation to AI policy?
# 16  How is international cooperation on AI current...
# 17  What are the basic principles set forth by the...
# 18  What is the World Bank's Policy on Access to I...
#
#                                                output  \
# 0   International cooperation on AI is crucial due...
# 1   The research team prepared generic interview p...
# 2   Critics, including EU businesses, have express...
# 3   The European Union's AI Act classifies AI syst...
# 4   The Universal Guidelines include rights to tra...
# 5   Whistleblowers and individual complaints are c...
# 6   Unlike the European Union (EU), the UK’s appro...
# 7   Japan focuses on a risk-based, agile, and mult...
# 8   Foundational AI models, such as large language...
# 9   The article suggests that more ambitious trade...
# 10  (1) Build open and coordinated AI science and ...
# 11  Issues include the ethical use of AI, strategi...
# 12  The World Bank launched the GovTech Global Par...
# 13  The AI assurance industry, comprising companie...
# 14  The Blueprint emphasizes principles such as th...
# 15  The need for AI policies to protect individual...
# 16  Governments are regulating AI, and internation...
# 17  In 2019, the Japanese government published the...
# 18  The policy outlines the World Bank's commitmen...
#
#    fine_tuned_llama_generations_with_examples_prompting  \
# 0    nobody likea know-it-all.\nInternational coop...
# 1    nobody\n\nThe approach taken by the research ...
# 2    nobody\n\nCriticof the EU'AI Act have raised ...
# 3    nobody\n\nThe European Union (EU) haclassifie...
# 4    nobody\n\nEPIC, the Electronic Privacy Inform...
# 5    nobody likea tattle-tale, but whistleblowerpl...
# 6    nobody\n\nThe UK and the European Union (EU) ...
# 7    nobody\n\nJapan'approach to AI regulation dif...
# 8    nobody likea know-it-all.\n\nFoundational AI ...
# 9    nobody likea know-it-all, but everyone likea ...
# 10   nobody knows.\n\nChina'New Generation Artific...
# 11   nobody likea tattle-tale, but when it cometo ...
# 12   nobody\n\nThe World Bank haplayed a significa...
# 13   nobody\n\nThe AI assurance industry can contr...
# 14   nobody likea know-it-all, but everyone likea ...
# 15   nobody likea know-it-all.\n\nMain concernin r...
# 16   nobody\n\nInternational cooperation on AI icu...
# 17   nobody\n\nIn 2019, the Japanese government se...
# 18   nobody knows.\n\nThe World Bank doenot have a...
#
#                            original_llama_generations
# 0    nobody knows\n\nInternational cooperation on ...
# 1   : Sure! The research team took a multi-faceted...
# 2    nobody likea know-it-all\n\nThe European Unio...
# 3    nobody\n\nThe European Union'AI Act classifie...
# 4   01. Transparency: AI systemshould be transpare...
# 5    nobody likea tattle-tale, but whistleblowerar...
# 6   ...the UK'approach to data protection idiffere...
# 7    nobody\n\nJapan, the European Commission, and...
# 8    nobody\n\nFoundational AI modelare the basic ...
# 9   ... international cooperation on foundational ...
# 10   nobody knows.\n\nChina'New Generation Artific...
# 11   nobody likea tattle-tale, but sometimeit'nece...
# 12   nobody\n\nThe World Bank haplayed a significa...
# 13   nobody\n\nThe AI assurance industry can contr...
# 14  ...\n\nThe White House'Blueprint for an AI Bil...
# 15   nobody\n\nThere are several main concernin re...
# 16   nobody\n\nInternational cooperation on AI icu...
# 17   nobody\n\nIn 2019, the Japanese government se...
# 18   nobody\n\nThe World Bank'policy on accesto in...

# %% [markdown]
# ## **Metrics**

# %%
import locale
locale.getpreferredencoding = lambda: "UTF-8"
# !pip install nltk rouge -q
from nltk.translate.bleu_score import sentence_bleu
from rouge import Rouge

# %%
import numpy as np
import warnings
warnings.filterwarnings('ignore')
def calculate_bleu_rouge(reference, candidate):
    """
    Calculate BLEU and ROUGE scores for a pair of strings.

    :param reference: The reference string (ground truth).
    :param candidate: The candidate string (generated text).
    :return: A dictionary containing BLEU and ROUGE scores.
    """
    # Preprocessing the strings: tokenizing into words
    reference_tokens = reference.split()
    candidate_tokens = candidate.split()

    # Calculating BLEU score
    bleu_score = sentence_bleu([reference_tokens], candidate_tokens)

    # Calculating ROUGE score
    rouge = Rouge()
    rouge_score = rouge.get_scores(candidate, reference)[0]

    return np.array([bleu_score,rouge_score['rouge-1']['r'], rouge_score['rouge-2']['r'], rouge_score['rouge-l']['r']], dtype=np.float32)

# Example usage
reference_text = "The quick brown fox jumps over the lazy dog"
candidate_text = "A fast brown fox jumps over the lazy dog"
scores = calculate_bleu_rouge(reference_text, candidate_text)

print(scores)
# Out:
# [0.7259795 0.7777778 0.75      0.7777778]

# %%
raw_model_metrics = df_test_all.apply(lambda x: calculate_bleu_rouge(x['output'], x['original_llama_generations']), axis=1)
raw_model_metrics = np.array(raw_model_metrics).mean(-1)
raw_model_metrics
# Out:
# array([0.00672832, 0.21382335, 0.03586512, 0.17670654], dtype=float32)

# %%
fine_tuned_model_metrics = df_test_all.apply(lambda x: calculate_bleu_rouge(x['output'], x['fine_tuned_llama_generations_with_examples_prompting']), axis=1)
fine_tuned_model_metrics = np.array(fine_tuned_model_metrics).mean(-1)
fine_tuned_model_metrics
# Out:
# array([0.00717518, 0.23718782, 0.04003384, 0.18678199], dtype=float32)

# %%
import pandas as pd
df_metrics = pd.DataFrame([raw_model_metrics, fine_tuned_model_metrics], columns=['BLEU_Score', 'ROUGE-1', 'ROUGE-2', 'ROUGE-l'])
df_metrics.index  = ['Raw_llama2', 'llama2_examples_prompting']
df_metrics
# Out:
#                            BLEU_Score   ROUGE-1   ROUGE-2   ROUGE-l
# Raw_llama2                   0.006728  0.213823  0.035865  0.176707
# llama2_examples_prompting    0.007175  0.237188  0.040034  0.186782

# %% [markdown]
# ## **Fine tune**

# %%
static_example_input = "What are the ethical considerations in AI development?"
static_example_output = "Ethical considerations in AI development include fairness, transparency, accountability, privacy, and ensuring AI systems do not perpetuate bias or discrimination."

def formatting_prompts_with_examples(examples):
    output_texts = []
    for i in range(len(examples['input'])):
        # Incorporate the static example with the actual Q&A for each item
        text = (f"### Example Question: {static_example_input}\n"
                f"### Example Answer: {static_example_output}\n"
                f"---\n"
                f"### Question: {examples['input'][i]}\n"
                f"### Answer: {examples['output'][i]}</s>")
        output_texts.append(text)
    return output_texts

# %%
# LoRA Config
peft_parameters = LoraConfig(
    lora_alpha=16,
    lora_dropout=0.1,
    r=8,
    bias="none",
    task_type="CAUSAL_LM"
)

# Training Params
train_params = TrainingArguments(
    output_dir="./results_modified",
    num_train_epochs=30,
    per_device_train_batch_size=4,
    gradient_accumulation_steps=1,
    optim="paged_adamw_32bit",
    save_steps=100,
    logging_steps=25,
    learning_rate=1e-4,
    weight_decay=0.001,
    fp16=False,
    bf16=False,
    max_grad_norm=0.3,
    max_steps=-1,
    warmup_ratio=0.03,
    group_by_length=True,
    lr_scheduler_type="constant",
    report_to="tensorboard"
)

# Trainer
fine_tuning = SFTTrainer(
    model=base_model,
    train_dataset=training_data,
    formatting_func=formatting_prompts_with_examples, #hereeee
    peft_config=peft_parameters,
    # dataset_text_field="text",
    tokenizer=llama_tokenizer,
    args=train_params
)

# Training
fine_tuning.train()

# Save Model
fine_tuning.model.save_pretrained(refined_model)
# Out:
# Map:   0%|          | 0/75 [00:00<?, ? examples/s]
#     <div>
#
#       <progress value='570' max='570' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [570/570 39:42, Epoch 30/30]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>25</td>
#       <td>1.849000</td>
#     </tr>
#     <tr>
#       <td>50</td>
#       <td>1.266100</td>
#     </tr>
#     <tr>
#       <td>75</td>
#       <td>1.109500</td>
#     </tr>
#     <tr>
#       <td>100</td>
#       <td>1.003100</td>
#     </tr>
#     <tr>
#       <td>125</td>
#       <td>0.888000</td>
#     </tr>
#     <tr>
#       <td>150</td>
#       <td>0.834700</td>
#     </tr>
#     <tr>
#       <td>175</td>
#       <td>0.670300</td>
#     </tr>
#     <tr>
#       <td>200</td>
#       <td>0.563400</td>
#     </tr>
#     <tr>
#       <td>225</td>
#       <td>0.457100</td>
#     </tr>
#     <tr>
#       <td>250</td>
#       <td>0.398100</td>
#     </tr>
#     <tr>
#       <td>275</td>
#       <td>0.317000</td>
#     </tr>
#     <tr>
#       <td>300</td>
#       <td>0.244200</td>
#     </tr>
#     <tr>
#       <td>325</td>
#       <td>0.255500</td>
#     </tr>
#     <tr>
#       <td>350</td>
#       <td>0.165300</td>
#     </tr>
#     <tr>
#       <td>375</td>
#       <td>0.193500</td>
#     </tr>
#     <tr>
#       <td>400</td>
#       <td>0.166100</td>
#     </tr>
#     <tr>
#       <td>425</td>
#       <td>0.129300</td>
#     </tr>
#     <tr>
#       <td>450</td>
#       <td>0.132800</td>
#     </tr>
#     <tr>
#       <td>475</td>
#       <td>0.099400</td>
#     </tr>
#     <tr>
#       <td>500</td>
#       <td>0.110100</td>
#     </tr>
#     <tr>
#       <td>525</td>
#       <td>0.084700</td>
#     </tr>
#     <tr>
#       <td>550</td>
#       <td>0.092400</td>
#     </tr>
#   </tbody>
# </table><p>
# /usr/local/lib/python3.10/dist-packages/torch/utils/checkpoint.py:429: UserWarning: torch.utils.checkpoint: please pass in use_reentrant=True or use_reentrant=False explicitly. The default value of use_reentrant will be updated to be False in the future. To maintain current behavior, pass use_reentrant=True. It is recommended that you use use_reentrant=False. Refer to docs for more details on the differences between the two variants.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/torch/utils/checkpoint.py:429: UserWarning: torch.utils.checkpoint: please pass in use_reentrant=True or use_reentrant=False explicitly. The default value of use_reentrant will be updated to be False in the future. To maintain current behavior, pass use_reentrant=True. It is recommended that you use use_reentrant=False. Refer to docs for more details on the differences between the two variants.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/torch/utils/checkpoint.py:429: UserWarning: torch.utils.checkpoint: please pass in use_reentrant=True or use_reentrant=False explicitly. The default value of use_reentrant will be updated to be False in the future. To maintain current behavior, pass use_reentrant=True. It is recommended that you use use_reentrant=False. Refer to docs for more details on the differences between the two variants.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/torch/utils/checkpoint.py:429: UserWarning: torch.utils.checkpoint: please pass in use_reentrant=True or use_reentrant=False explicitly. The default value of use_reentrant will be updated to be False in the future. To maintain current behavior, pass use_reentrant=True. It is recommended that you use use_reentrant=False. Refer to docs for more details on the differences between the two variants.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/torch/utils/checkpoint.py:429: UserWarning: torch.utils.checkpoint: please pass in use_reentrant=True or use_reentrant=False explicitly. The default value of use_reentrant will be updated to be False in the future. To maintain current behavior, pass use_reentrant=True. It is recommended that you use use_reentrant=False. Refer to docs for more details on the differences between the two variants.
#   warnings.warn(

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
fine_tuning.model.save_pretrained("/content/drive/MyDrive/94812")

# %%
# fine_tuning is the trainer
model_path = "/content/drive/MyDrive/94812"
fine_tuning.save_model(model_path)
fine_tuning.model.config.save_pretrained(model_path+"config.json")

# %%
# model_path = "/content/drive/MyDrive/94812/llama-2-7b-policyAI"

# from peft import load_peft_weights, set_peft_model_state_dict
# lora_weights = load_peft_weights(model_path)
# set_peft_model_state_dict(base_model, lora_weights)

# %% [markdown]
# ### Fine-tune 1.1

# %%
# LoRA Config
peft_parameters = LoraConfig(
    lora_alpha=16,
    lora_dropout=0.1,
    r=8,
    bias="none",
    task_type="CAUSAL_LM"
)

# Training Params
train_params = TrainingArguments(
    output_dir="./results_modified",
    num_train_epochs=30,
    per_device_train_batch_size=4,
    gradient_accumulation_steps=1,
    optim="paged_adamw_32bit",
    save_steps=100,
    logging_steps=25,
    learning_rate=2e-4,
    weight_decay=0.001,
    fp16=False,
    bf16=False,
    max_grad_norm=0.3,
    max_steps=-1,
    warmup_ratio=0.03,
    group_by_length=True,
    lr_scheduler_type="constant",
    report_to="tensorboard"
)

# Trainer
fine_tuning = SFTTrainer(
    model=base_model,
    train_dataset=training_data,
    formatting_func=formatting_prompts_with_examples, #hereeee
    peft_config=peft_parameters,
    # dataset_text_field="text",
    tokenizer=llama_tokenizer,
    args=train_params
)

# Training
fine_tuning.train()

# Save Model
fine_tuning.model.save_pretrained(refined_model)
# Out:
# Map:   0%|          | 0/75 [00:00<?, ? examples/s]
#     <div>
#
#       <progress value='570' max='570' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [570/570 39:36, Epoch 30/30]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>25</td>
#       <td>1.647000</td>
#     </tr>
#     <tr>
#       <td>50</td>
#       <td>1.068400</td>
#     </tr>
#     <tr>
#       <td>75</td>
#       <td>0.962200</td>
#     </tr>
#     <tr>
#       <td>100</td>
#       <td>0.788300</td>
#     </tr>
#     <tr>
#       <td>125</td>
#       <td>0.608000</td>
#     </tr>
#     <tr>
#       <td>150</td>
#       <td>0.501900</td>
#     </tr>
#     <tr>
#       <td>175</td>
#       <td>0.334000</td>
#     </tr>
#     <tr>
#       <td>200</td>
#       <td>0.253800</td>
#     </tr>
#     <tr>
#       <td>225</td>
#       <td>0.210600</td>
#     </tr>
#     <tr>
#       <td>250</td>
#       <td>0.187800</td>
#     </tr>
#     <tr>
#       <td>275</td>
#       <td>0.169900</td>
#     </tr>
#     <tr>
#       <td>300</td>
#       <td>0.134200</td>
#     </tr>
#     <tr>
#       <td>325</td>
#       <td>0.142400</td>
#     </tr>
#     <tr>
#       <td>350</td>
#       <td>0.094200</td>
#     </tr>
#     <tr>
#       <td>375</td>
#       <td>0.093700</td>
#     </tr>
#     <tr>
#       <td>400</td>
#       <td>0.091700</td>
#     </tr>
#     <tr>
#       <td>425</td>
#       <td>0.073700</td>
#     </tr>
#     <tr>
#       <td>450</td>
#       <td>0.072400</td>
#     </tr>
#     <tr>
#       <td>475</td>
#       <td>0.062500</td>
#     </tr>
#     <tr>
#       <td>500</td>
#       <td>0.062500</td>
#     </tr>
#     <tr>
#       <td>525</td>
#       <td>0.057000</td>
#     </tr>
#     <tr>
#       <td>550</td>
#       <td>0.053200</td>
#     </tr>
#   </tbody>
# </table><p>

# %%
from tqdm.notebook import tqdm
import gc
generations =[]
for i in tqdm(range(len(df_test_all)), "generating..."):
  prompt = f"### Question: {df_test_all['input'][i]}\n ### Answer: </s>"
  # Generate predictions
  inputs = llama_tokenizer(prompt, return_tensors='pt')
  inputs = inputs.to("cuda")
  output = fine_tuning.model.generate(**inputs, max_new_tokens=100,temperature=0.2)
  response = llama_tokenizer.decode(output[0].tolist())
  # print(response)
  # break
  generations.append(response)
  del inputs, output
  gc.collect()
  torch.cuda.empty_cache()

generations
# Out:
# generating...:   0%|          | 0/19 [00:00<?, ?it/s]
# ['<s> ### Question: Why is international cooperation on AI important?\n ### Answer:</s> ### Question: What are the economic, ethical, and strategic issues that call into question the future of international cooperation on AI?\n### Answer: Issues such as the unequal distribution of AI benefits and burdens, ethical concerns around privacy and bias, and strategic concerns related to trade and geopolitical competition may undermine the future of international AI cooperation.</s>\n---\n### Question: What are the main challenges',
#  "<s> ### Question: Can you describe the approach taken by the research team in preparing for the interviews with academia and industry experts in the AI assessment?\n ### Answer:</s>sure, here's the approach taken by the research team in preparing for interviews with academia and industry experts in the AI assessment:\n1. Research and background: The research team conducted in-depth research on AI, including current trends, challenges, and future directions. This involved reviewing academic papers, industry reports, and government documents to gain a thorough understanding of the field.\n2. Identification of interviewees: The research team identified potential",
#  "<s> ### Question: What concerns do critics have regarding the EU's AI Act's potential impact on innovation and competitiveness?\n ### Answer:</s>s Critics argue that the EU's AI Act could hinder innovation and competitiveness in the region by imposing excessive and complex regulatory burdens, stifling innovation in the process. They point to provisions such as the requirement for high-risk AI systems to be subject to a rigorous assessment before being placed on the market, which could delay the introduction of innovative AI technologies.\n---\n### Question: What is",
#  '<s> ### Question: How does the European Union classify AI systems under its AI Act, and what are the implications for "high risk" AI systems?\n ### Answer:</s>s the AI Act, the European Union (EU) classifies AI systems into four tiers based on the risk they pose to the public. Tier 1 are AI systems with minimal risk, while Tiers 2, 3, and 4 cover progressively higher-risk AI systems. Providers of AI systems for general use in the EU must comply with obligations for each tier, such as proper documentation, data quality management, and human o',
#  '<s> ### Question: What are the Universal Guidelines for Artificial Intelligence endorsed by EPIC?\n ### Answer:</s>s The guidelines focus on ensuring AI systems are safe, secure, and respectful of human rights, with emphasis on transparency, accountability, and ensuring AI systems do not perpetuate discrimination or bias.\n---\n### Question: What are the key areas for collaboration in international AI governance?\n### Answer: The key areas for collaboration include regulatory policies, standard-setting, and joint research and development (R&D',
#  '<s> ### Question: What role do whistleblowers and complaints play in the AI regulatory process?\n ### Answer:</s> ### Question: What are the key areas for collaboration in AI governance?\n### Answer: The key areas for collaboration in AI governance include:\n1. Tech development and deployment\n2. Policy and regulation\n3. Economic incentives and market dynamics\n4. International cooperation and data flows\n5. Civil society and public engagement\n6. Research and development with human rights and ethical considerations\n7. Education and workforce development\n',
#  "<s> ### Question: How's UK's approach different from that of the European Union?\n ### Answer:</s>s UK's approach focuses on maximizing economic advantage through a broad trade agreement, while the European Union prioritizes protecting social, environmental, and labor standards through a more restrictive regulatory framework.\n---\n### Question: What are the main areas of cooperation between the UK and the European Union as outlined in the agreement?\n### Answer: The agreement highlights the importance of cooperation in economic policies, international trade, research, and innovation, as",
#  "<s> ### Question: How does Japan's approach to AI regulation differ from that of the European Commission and Canada?\n ### Answer:</s>s Japan's approach to AI regulation focuses on maximizing AI's positive impact on society, while the European Commission and Canada prioritize protecting individual privacy and ensuring AI systems are accountable and transparent.</s>\nJapan's recently introduced AI governance framework stands out due to its emphasis on maximizing the positive impact of AI on society, rather than just regulating potential negative effects. In contrast, the European Commission and Canada",
#  '<s> ### Question: What are foundational AI models, and why are they important?\n ### Answer:</s> ### Question: What are the key components of foundational AI models, and how do these components impact model performance?\n### Answer: Foundational AI models are composed of several key components, including algorithms, data, and evaluation methods. These components play a crucial role in determining model performance, with algorithmic choices influencing model behavior, data quality impacting model performance, and evaluation methods setting the basis for model assessment.</s>  Question: What are the main challeng',
#  '<s> ### Question: What additional measures are needed for international cooperation on foundational AI models?\n ### Answer:</s> ### Question: What are the key areas for collaboration in foundational AI models?\n### Answer: Essential technologies, basic research, and development of foundational AI models for widespread and durable economic growth and improved living standards.\n---\n### Question: What are the key areas of collaboration in foundational AI models?\n### Answer: Essential technologies, basic research, and development of foundational AI models for widespread',
#  '<s> ### Question: What are the focus tasks of China’s New Generation Artificial Intelligence Development? \n ### Answer:</s>s The focus tasks of China’s New Generation Artificial Intelligence Development (NG-AID) are to enhance the development of AI for economic growth, to improve the efficiency of public services, to enhance national security, and to address social concerns.\n---\n### Question: What are the three systems of China’s New Generation Artificial Intelligence Development (NG-AID)? \n### Answer: The three systems of NG-A',
#  '<s> ### Question: What are the economic, ethical, and strategic issues that call into question the continuation of collaboration on AI with China?\n ### Answer:</s> ### Question: What are the main concerns regarding collaboration on AI with China?\n### Answer: The main concerns include the ethical considerations of AI, the strategic implications for economic competition and national security, and the potential for China to leapfrog or reverse technological advances in areas like privacy and data governance</s>\n---\n### Question: What are the main concerns regarding AI regulation in the United States?\n### Answer',
#  "<s> ### Question: What role has the World Bank played in supporting AI in the public sector?\n ### Answer:</s> ### Question: What are the key areas of focus for the World Bank's AI in Public Sector Initiative?\n### Answer: The initiative focuses on legal, ethical, and governance frameworks for AI, AI innovation and development, and public sector implementation and adoption of AI technologies.\n---\n### Question: What is the main goal of the EU AI Act (AIA)?\n### Answer: The main goal",
#  '<s> ### Question: How can the AI assurance industry contribute to regulatory compliance and AI system improvement?\n ### Answer:</s> ### Question: What are the key areas of focus in the AI assurance framework for regulatory compliance and AI system improvement?\n### Answer: The framework emphasizes the importance of a risk-based approach, technical adequacy, and governance as essential areas of focus for AI assurance. These areas include the assessment of AI system risks, the evaluation of AI assurance practices against regulatory requirements, and the implementation of governance structures to manage',
#  "<s> ### Question: What are some of the key principles outlined in the White House's Blueprint for an AI Bill of Rights? \n ### Answer:</s>s the Blueprint for an AI Bill of Rights, the White House outlines 10 key principles to guide the development, use, and regulation of artificial intelligence (AI). These principles aim to protect the rights of AI users and ensures that AI technologies are aligned with human values and rights. Here are the 10 key principles:\n1. Safe and Reliable AI: AI systems must be designed and deployed in a manner that ensures",
#  '<s> ### Question: What are main concerns in relation to AI policy?\n ### Answer:</s> ### Question: What are the key areas for collaboration in AI governance?\n### Answer: International, cross-sector, and civil society collaboration are crucial for AI governance, focusing on setting global standards, addressing global challenges, and representing the interests of diverse stakeholders.</s>\n---\n### Question: What are the key areas of collaboration in AI governance as proposed by the European Commission?\n### Answer: The areas',
#  '<s> ### Question: How is international cooperation on AI currently being pursued?\n ### Answer:</s> ### Question: What are the key areas of collaboration in AI that the US and EU are focusing on?\n### Answer: The US and EU are collaborating on AI regulation, data governance, and developing international AI standards.\n---\n### Question: What is the main goal of the AI Act and AI Assessment?\n### Answer: The AI Act aims to regulate high-risk AI systems, while the',
#  '<s> ### Question: What are the basic principles set forth by the Japanese government for AI regulation in 2019?\n ### Answer:</s>s the basic principles for AI regulation in 2019, the Japanese government emphasized transparency, accountability, and ensuring AI systems do not infringe on human rights. These principles aim to guide AI development and use in a responsible and ethical manner.</s>  In 2019, the Japanese government published the "Principles for Regulation of Artificial Intelligence," outlining the basic principles for AI reg',
#  "<s> ### Question: What is the World Bank's Policy on Access to Information?\n ### Answer:</s>s The World Bank's Policy on Access to Information (ATI) aims to promote transparency, accountability, and good governance by providing the public with access to a significant portion of the Bank's documents and information.\n---\n### Question: What are the key principles of the European Commission's AI Policy?\n### Answer: The policy emphasizes human oversight, high-risk AI use, and transparency as key principles"]

# %%
df_test_all['fine_tuned_llama_generations_with_examples_prompting_origin_lr']=generations

# %%
df_test_all['fine_tuned_llama_generations_with_examples_prompting_origin_lr']= df_test_all['fine_tuned_llama_generations_with_examples_prompting_origin_lr'].apply(lambda x: x.split('Answer:', 1)[-1] if 'Answer:' in x else x)
df_test_all['fine_tuned_llama_generations_with_examples_prompting_origin_lr']= df_test_all['fine_tuned_llama_generations_with_examples_prompting_origin_lr'].apply(lambda x: x.replace('</s>', '').replace('<s>', '').replace('</s>s', '').replace('<s/>', '').replace('s ', ''))
df_test_all
# Out:
#                                                 input  \
# 0   Why is international cooperation on AI important?
# 1   Can you describe the approach taken by the res...
# 2   What concerns do critics have regarding the EU...
# 3   How does the European Union classify AI system...
# 4   What are the Universal Guidelines for Artifici...
# 5   What role do whistleblowers and complaints pla...
# 6   How's UK's approach different from that of the...
# 7   How does Japan's approach to AI regulation dif...
# 8   What are foundational AI models, and why are t...
# 9   What additional measures are needed for intern...
# 10  What are the focus tasks of China’s New Genera...
# 11  What are the economic, ethical, and strategic ...
# 12  What role has the World Bank played in support...
# 13  How can the AI assurance industry contribute t...
# 14  What are some of the key principles outlined i...
# 15   What are main concerns in relation to AI policy?
# 16  How is international cooperation on AI current...
# 17  What are the basic principles set forth by the...
# 18  What is the World Bank's Policy on Access to I...
#
#                                                output  \
# 0   International cooperation on AI is crucial due...
# 1   The research team prepared generic interview p...
# 2   Critics, including EU businesses, have express...
# 3   The European Union's AI Act classifies AI syst...
# 4   The Universal Guidelines include rights to tra...
# 5   Whistleblowers and individual complaints are c...
# 6   Unlike the European Union (EU), the UK’s appro...
# 7   Japan focuses on a risk-based, agile, and mult...
# 8   Foundational AI models, such as large language...
# 9   The article suggests that more ambitious trade...
# 10  (1) Build open and coordinated AI science and ...
# 11  Issues include the ethical use of AI, strategi...
# 12  The World Bank launched the GovTech Global Par...
# 13  The AI assurance industry, comprising companie...
# 14  The Blueprint emphasizes principles such as th...
# 15  The need for AI policies to protect individual...
# 16  Governments are regulating AI, and internation...
# 17  In 2019, the Japanese government published the...
# 18  The policy outlines the World Bank's commitmen...
#
#    fine_tuned_llama_generations_with_examples_prompting  \
# 0    ### Question: What are the riskassociated wit...
# 1   sure, the research team took a systematic and ...
# 2   Critics, including businesseand trade associat...
# 3   the European Union'(EU) AI Act classifieAI sys...
# 4   the Guidelineaim to ensure that AI systemare e...
# 5   Whistleblowerand complaintplay a crucial role ...
# 6   UK'approach differfrom that of the European Un...
# 7   Japan focuseon maximizing AI'benefits, while t...
# 8    ### Question: What are the key challengein de...
# 9   scientific publication, conference, and worksh...
# 10  The focutaskof China’New Generation Artificial...
# 11  The economic, ethical, and strategic issuethat...
# 12  the World Bank haplayed a crucial role in supp...
# 13  the AI assurance industry contributeto regulat...
# 14  the Blueprint for an AI Bill of Rights, the Wh...
# 15   ### Question: Why iinternational cooperation ...
# 16   ### Question: What are the challengeand conce...
# 17  the basic principleset forth by the Japanese g...
# 18  the World Bank'Policy on Accesto Information, ...
#
#                            original_llama_generations  \
# 0    nobody knows\n\nInternational cooperation on ...
# 1   : Sure! The research team took a multi-faceted...
# 2    nobody likea know-it-all\n\nThe European Unio...
# 3    nobody\n\nThe European Union'AI Act classifie...
# 4   01. Transparency: AI systemshould be transpare...
# 5    nobody likea tattle-tale, but whistleblowerar...
# 6   ...the UK'approach to data protection idiffere...
# 7    nobody\n\nJapan, the European Commission, and...
# 8    nobody\n\nFoundational AI modelare the basic ...
# 9   ... international cooperation on foundational ...
# 10   nobody knows.\n\nChina'New Generation Artific...
# 11   nobody likea tattle-tale, but sometimeit'nece...
# 12   nobody\n\nThe World Bank haplayed a significa...
# 13   nobody\n\nThe AI assurance industry can contr...
# 14  ...\n\nThe White House'Blueprint for an AI Bil...
# 15   nobody\n\nThere are several main concernin re...
# 16   nobody\n\nInternational cooperation on AI icu...
# 17   nobody\n\nIn 2019, the Japanese government se...
# 18   nobody\n\nThe World Bank'policy on accesto in...
#
#    fine_tuned_llama_generations_with_examples_prompting_origin_lr
# 0    ### Question: What are the economic, ethical,...
# 1   sure, here'the approach taken by the research ...
# 2   Criticargue that the EU'AI Act could hinder in...
# 3   the AI Act, the European Union (EU) classifieA...
# 4   The guidelinefocuon ensuring AI systemare safe...
# 5    ### Question: What are the key areafor collab...
# 6   UK'approach focuseon maximizing economic advan...
# 7   Japan'approach to AI regulation focuseon maxim...
# 8    ### Question: What are the key componentof fo...
# 9    ### Question: What are the key areafor collab...
# 10  The focutaskof China’New Generation Artificial...
# 11   ### Question: What are the main concernregard...
# 12   ### Question: What are the key areaof focufor...
# 13   ### Question: What are the key areaof focuin ...
# 14  the Blueprint for an AI Bill of Rights, the Wh...
# 15   ### Question: What are the key areafor collab...
# 16   ### Question: What are the key areaof collabo...
# 17  the basic principlefor AI regulation in 2019, ...
# 18  The World Bank'Policy on Accesto Information (...

# %%
fine_tuned_model_lr_metrics = df_test_all.apply(lambda x: calculate_bleu_rouge(x['output'], x['fine_tuned_llama_generations_with_examples_prompting_origin_lr']), axis=1)
fine_tuned_model_lr_metrics = np.array(fine_tuned_model_lr_metrics).mean(-1)
fine_tuned_model_lr_metrics
# Out:
# array([0.0117026 , 0.23608132, 0.0491501 , 0.19075066], dtype=float32)

# %%
df_metrics = pd.DataFrame([raw_model_metrics, fine_tuned_model_metrics, fine_tuned_model_lr_metrics], columns=['BLEU_Score', 'ROUGE-1', 'ROUGE-2', 'ROUGE-l'])
df_metrics.index  = ['Raw_llama2', 'Fine_tuned_llama2_examples_prompting', 'Fine_tuned_llama2_examples_prompting_origin_lr']
df_metrics
# Out:
#                                                 BLEU_Score   ROUGE-1  \
# Raw_llama2                                        0.006728  0.213823
# Fine_tuned_llama2_examples_prompting              0.012010  0.250690
# Fine_tuned_llama2_examples_prompting_origin_lr    0.011703  0.236081
#
#                                                  ROUGE-2   ROUGE-l
# Raw_llama2                                      0.035865  0.176707
# Fine_tuned_llama2_examples_prompting            0.057230  0.209890
# Fine_tuned_llama2_examples_prompting_origin_lr  0.049150  0.190751
